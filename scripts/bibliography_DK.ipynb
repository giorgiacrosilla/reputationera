# %% [markdown]
# webscraping collections data and general bibliography
#
#
# ### query on data.bnf
#
# it's not possible to do a query directly using python, so this query was performed here <a href="https://data.bnf.fr/sparql/">data.bnf</a>:
# ```
# PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX bnf-onto: <http://data.bnf.fr/ontology/bnf-onto/>
# SELECT *
# WHERE {
#   ?work dct:title ?title ;
#         dct:publisher ?publisher;
#         dct:date ?date;
#
#         rdfs:seeAlso ?uri ;
#         bnf-onto:isbn ?isbn;
#         dct:creator ?creator.
# ?creator foaf:name ?name.
#   FILTER (bif:contains(?title, "De_Kooning"))}
#
# ```
#
# has been done on the web endpoint and then the CSV was downloaded, this query is ok but NO AUTHOR is found.
#
#
# ```
# PREFIX rdarelationships: <http://rdvocab.info/RDARelationshipsWEMI/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX bnf-onto: <http://data.bnf.fr/ontology/bnf-onto/>
# SELECT distinct ?work ?title ?creatorname ?date ?isbn
# WHERE {
#   ?work dct:title ?title;
#         dct:creator ?creator.
# 		?creator foaf:name ?creatorname.
#   ?work dct:date ?date.
#   ?work rdarelationships:expressionOfWork ?expression.
# ?manifestation rdarelationships:expressionManifested ?expression.
# ?work bnf-onto:isbn ?isbn.
#   FILTER (bif:contains(?title, "De_Kooning"))}
# ```
#
# questa query ritorna anche l'autore, assieme ad ISBN, il problema è che i risultati tra la prima e la seconda query non corrispondono. Penso perchè si lavora a livello di expression (?)

# %%
import pandas as pd
query1 = pd.read_csv("databnf_DK.csv")
# pd.set_option('display.max_rows', None)
query1
# Out:
#                                                work  \
# 0   http://data.bnf.fr/ark:/12148/cb45692271m#about
# 1   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 2   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 3   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 4   http://data.bnf.fr/ark:/12148/cb45292173b#about
# ..                                              ...
# 65  http://data.bnf.fr/ark:/12148/cb47124975c#about
# 66  http://data.bnf.fr/ark:/12148/cb399985699#about
# 67  http://data.bnf.fr/ark:/12148/cb46970628b#about
# 68  http://data.bnf.fr/ark:/12148/cb41066822t#about
# 69  http://data.bnf.fr/ark:/12148/cb41040899j#about
#
#                                                 title  \
# 0                               Le rire de De Kooning
# 1      A way of living : the art of Willem De Kooning
# 2      A way of living : the art of Willem De Kooning
# 3      A way of living : the art of Willem De Kooning
# 4      A way of living : the art of Willem De Kooning
# ..                                                ...
# 65                                  Willem de Kooning
# 66                     Willem de Kooning, een portret
# 67  Chaïm Soutine, Willem de Kooning, La peinture ...
# 68  Willem De Kooning : works, writings and interv...
# 69                                  Willem de Kooning
#
#                                    publisher  date  \
# 0                Bordeaux : Olympique , 2019  2019
# 1      London : Phaidon Press Limited , 2017  2014
# 2      London : Phaidon Press Limited , 2017  2014
# 3      London : Phaidon Press Limited , 2017  2014
# 4      London : Phaidon Press Limited , 2017  2014
# ..                                       ...   ...
# 65            Lyon : Fage éditions , DL 2022  2022
# 66  Leiden : Menken Kasander & Wigman , 2005  2005
# 67   Paris : "Beaux-arts" éditions , DL 2021  2021
# 68          Barcelona : Ed. Polígrafa , 2007  2007
# 69                   Paris : Hazan , DL 2006  2007
#
#                                                 uri               isbn
# 0   https://catalogue.bnf.fr/ark:/12148/cb45692271m  978-2-9557550-6-8
# 1   https://catalogue.bnf.fr/ark:/12148/cb45292173b         0714845817
# 2   https://catalogue.bnf.fr/ark:/12148/cb45292173b         0714873160
# 3   https://catalogue.bnf.fr/ark:/12148/cb45292173b      9780714845814
# 4   https://catalogue.bnf.fr/ark:/12148/cb45292173b      9780714873169
# ..                                              ...                ...
# 65  https://catalogue.bnf.fr/ark:/12148/cb47124975c  978-2-84975-687-4
# 66  https://catalogue.bnf.fr/ark:/12148/cb399985699      90-74622-53-4
# 67  https://catalogue.bnf.fr/ark:/12148/cb46970628b  979-10-204-0639-2
# 68  https://catalogue.bnf.fr/ark:/12148/cb41066822t  978-84-343-1138-1
# 69  https://catalogue.bnf.fr/ark:/12148/cb41040899j  978-2-7541-0176-9
#
# [70 rows x 6 columns]

# %%
for column_name in query1.columns:
    if column_name == "isbn":
        for i, value in enumerate(query1[column_name]):
            if "-" in value:
                # Replacing hyphens with empty string
                query1.at[i, column_name] = value.replace("-", "")
query1.head()
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45692271m#about
# 1  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 2  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 3  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 4  http://data.bnf.fr/ark:/12148/cb45292173b#about
#
#                                             title  \
# 0                           Le rire de De Kooning
# 1  A way of living : the art of Willem De Kooning
# 2  A way of living : the art of Willem De Kooning
# 3  A way of living : the art of Willem De Kooning
# 4  A way of living : the art of Willem De Kooning
#
#                                publisher  date  \
# 0            Bordeaux : Olympique , 2019  2019
# 1  London : Phaidon Press Limited , 2017  2014
# 2  London : Phaidon Press Limited , 2017  2014
# 3  London : Phaidon Press Limited , 2017  2014
# 4  London : Phaidon Press Limited , 2017  2014
#
#                                                uri           isbn
# 0  https://catalogue.bnf.fr/ark:/12148/cb45692271m  9782955755068
# 1  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714845817
# 2  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714873160
# 3  https://catalogue.bnf.fr/ark:/12148/cb45292173b  9780714845814
# 4  https://catalogue.bnf.fr/ark:/12148/cb45292173b  9780714873169

# %% [markdown]
# ### query on google books api

# %%
import requests
import json

def fetch_books(query, max_results=40):
    base_url = "https://www.googleapis.com/books/v1/volumes"
    start_index = 0
    all_results = []

    while True:
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results
        }
        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])
            if not items:
                break
            all_results.extend(items)
            start_index += max_results
        else:
            print("Failed to retrieve data. Status code:", response.status_code)
            break

    return all_results

cezanne_books = fetch_books("De Kooning")

# Saving JSON data to a file
with open("dkbooks.json", "w") as json_file:
    json.dump(cezanne_books, json_file, indent=4)

print("JSON data saved to dkbooks.json")
# Out:
# JSON data saved to dkbooks.json

# %%
import json
import pandas as pd

# Load JSON data from file
with open("dkbooks.json", "r") as json_file:
    cezanne_books_data = json.load(json_file)

# Extract relevant fields from each book item
books_list = []
for book in cezanne_books_data:
    book_info = {
        "Title": book["volumeInfo"].get("title", "N/A"),
        "Subtitle": book["volumeInfo"].get("subtitle", "N/A"),
        "Authors": ", ".join(book["volumeInfo"].get("authors", ["N/A"])),
        "Publisher": book["volumeInfo"].get("publisher", "N/A"),
        "PublishedDate": book["volumeInfo"].get("publishedDate", "N/A"),
        "isbn": book["volumeInfo"].get("industryIdentifiers", [{}])[0].get("identifier", "N/A"),  # Retrieving ISBN
    }
    books_list.append(book_info)

# Create DataFrame
books_df = pd.DataFrame(books_list)

# Display DataFrame
books_df.head()
# Out:
#                                     Title         Subtitle  \
# 0  De Kooning, dipinti, disegni, sculture              N/A
# 1                              De Kooning              N/A
# 2                       Willem De Kooning   late paintings
# 3                              De Kooning  A Retrospective
# 4                       Willem de Kooning              N/A
#
#                                              Authors  \
# 0                                  Willem De Kooning
# 1                                                N/A
# 2             Willem De Kooning, Museo Carlo Bilotti
# 3  Willem De Kooning, John Elderfield, Lauren Mah...
# 4                                   Carolyn Lanchner
#
#                   Publisher PublishedDate                isbn
# 0                       N/A          1985  UOM:39015015825683
# 1                       N/A          1985       OCLC:12250843
# 2          Mondadori Electa          2006  UOM:39015066851935
# 3  The Museum of Modern Art          2011       9780870707971
# 4  The Museum of Modern Art          2011       9780870707889

# %%
liss = []
for column_name in books_df.columns:
    if column_name == "Title":
        for value in books_df[column_name]:
            if "de Kooning" in value or "De Kooning" in value:
                liss.append(value)
print(len(liss))
# Out:
# 151

# %%
import pandas as pd

# Assuming books_df is your DataFrame
new_dataframe = books_df[books_df["Title"].str.contains("de Kooning", case=False) & ~books_df["Title"].str.contains("Elaine de Kooning", case=False)].copy()

new_dataframe.reset_index(drop=True, inplace=True)

new_dataframe.head()
# Out:
#                                     Title         Subtitle  \
# 0  De Kooning, dipinti, disegni, sculture              N/A
# 1                              De Kooning              N/A
# 2                       Willem De Kooning   late paintings
# 3                              De Kooning  A Retrospective
# 4                       Willem de Kooning              N/A
#
#                                              Authors  \
# 0                                  Willem De Kooning
# 1                                                N/A
# 2             Willem De Kooning, Museo Carlo Bilotti
# 3  Willem De Kooning, John Elderfield, Lauren Mah...
# 4                                   Carolyn Lanchner
#
#                   Publisher PublishedDate                isbn
# 0                       N/A          1985  UOM:39015015825683
# 1                       N/A          1985       OCLC:12250843
# 2          Mondadori Electa          2006  UOM:39015066851935
# 3  The Museum of Modern Art          2011       9780870707971
# 4  The Museum of Modern Art          2011       9780870707889

# %%
import pandas as pd

# Merge the two DataFrames on the 'ISBN' column
df_combined = pd.merge(query1, new_dataframe, on='isbn', how='inner')

# Display the new DataFrame with rows where ISBN is found in both DataFrames
df_combined
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 1  http://data.bnf.fr/ark:/12148/cb37526494b#about
# 2  http://data.bnf.fr/ark:/12148/cb37526494b#about
# 3  http://data.bnf.fr/ark:/12148/cb45288067c#about
# 4  http://data.bnf.fr/ark:/12148/cb42265321b#about
# 5  http://data.bnf.fr/ark:/12148/cb35710872j#about
# 6  http://data.bnf.fr/ark:/12148/cb34982520m#about
# 7  http://data.bnf.fr/ark:/12148/cb347686735#about
# 8  http://data.bnf.fr/ark:/12148/cb38841654h#about
# 9  http://data.bnf.fr/ark:/12148/cb356992193#about
#
#                                                title  \
# 0     A way of living : the art of Willem De Kooning
# 1  Willem de Kooning : drawings, paintings, sculp...
# 2  Willem de Kooning : drawings, paintings, sculp...
# 3  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 4         Willem de Kooning : the artist's materials
# 5  Willem De Kooning : paintings, [exhibition, Na...
# 6  Willem de Kooning, recent paintings, 1983-1986...
# 7  De Kooning : petit journal de l'exposition, 28...
# 8  Willem de Kooning : tracing the figure, [exhib...
# 9                                  Willem De Kooning
#
#                                            publisher  date  \
# 0              London : Phaidon Press Limited , 2017  2014
# 1  New York : Whitney museum of American art ; Mu...  1983
# 2  New York : Whitney museum of American art ; Mu...  1983
# 3                              New York : Lévy Gorvy  2017
# 4  Los Angeles : Getty conservation institute , c...  2010
# 5  Washington : National gallery of art ; New Hav...  1994
# 6            London : Anthony d'Offay gallery , 1986  1986
# 7             Paris : Centre Georges Pompidou , 1984  1984
# 8  Los Angeles : Museum of contemporary art ; Pri...  2002
# 9                           Paris : l'Échoppe , 1994  1994
#
#                                                uri           isbn  \
# 0  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714873160
# 1  https://catalogue.bnf.fr/ark:/12148/cb37526494b     0393018407
# 2  https://catalogue.bnf.fr/ark:/12148/cb37526494b     0393018407
# 3  https://catalogue.bnf.fr/ark:/12148/cb45288067c     1944379126
# 4  https://catalogue.bnf.fr/ark:/12148/cb42265321b  9781606060216
# 5  https://catalogue.bnf.fr/ark:/12148/cb35710872j     0894682040
# 6  https://catalogue.bnf.fr/ark:/12148/cb34982520m     094756408X
# 7  https://catalogue.bnf.fr/ark:/12148/cb347686735     285850234X
# 8  https://catalogue.bnf.fr/ark:/12148/cb38841654h     069109618X
# 9  https://catalogue.bnf.fr/ark:/12148/cb356992193     2840680297
#
#                      Title                                           Subtitle  \
# 0        Willem de Kooning                                    A Way of Living
# 1        Willem de Kooning  Drawings, Paintings, Sculpture, [mostra Itiner...
# 2        Willem de Kooning  Drawings, Paintings, Sculpture, [mostra Itiner...
# 3  De Kooning - Zao Wou-KI                                                N/A
# 4        Willem de Kooning                             The Artist's Materials
# 5        Willem de Kooning                                          Paintings
# 6        Willem de Kooning                        Recent Paintings, 1983-1986
# 7               De Kooning  petit journal de l'exposition : Musee national...
# 8        Willem de Kooning                                 Tracing the Figure
# 9        Willem De Kooning                                                N/A
#
#                                              Authors  \
# 0                                     Judith Zilczer
# 1                   Paul Cummings, Willem De Kooning
# 2                   Paul Cummings, Willem De Kooning
# 3                                                N/A
# 4                                         Susan Lake
# 5  Marla Prather, Willem De Kooning, David Sylves...
# 6                                  Willem De Kooning
# 7  Musée national d'art moderne (Paris), Whitney ...
# 8  Willem De Kooning, Cornelia H. Butler, Paul Sc...
# 9                                        Edwin Denby
#
#                     Publisher PublishedDate
# 0               Phaidon Press    2017-05-22
# 1                         N/A          1983
# 2                         N/A          1983
# 3      Dominique Levy Gallery    2017-03-28
# 4          Getty Publications          2010
# 5                         N/A    1994-01-01
# 6     Anthony D'Offay Gallery    1986-01-01
# 7                         N/A          1984
# 8  Princeton University Press          2002
# 9                         N/A          1994

# %%
import pandas as pd

# Assuming df1 and df2 are your two DataFrames

# Rename the 'Title' column in df2 to 'title'
new_dataframe.rename(columns={'Title': 'title'}, inplace=True)
new_dataframe.rename(columns={'PublishedDate': 'date'}, inplace=True)
new_dataframe.rename(columns={'Publisher': 'publisher'}, inplace=True)
# Concatenate the DataFrames vertically
combined_df = pd.concat([query1, new_dataframe], ignore_index=True)

# Drop duplicates based on 'isbn' column
new_df = combined_df.drop_duplicates(subset='isbn')
new_df = combined_df.drop_duplicates(subset=['title', 'publisher', 'date'], keep='first')
# Reset index of the new DataFrame
new_df.reset_index(drop=True, inplace=True)
new_df.drop(columns=['work', 'uri'], inplace=True)
index_column = new_df.columns.get_loc('Subtitle')

# Move the column to position 2
new_column_order = list(new_df.columns)
new_column_order.insert(1, new_column_order.pop(index_column))
new_df = new_df[new_column_order]

# Display the new DataFrame with unique rows based on ISBN and consistent column name 'title'
new_df
# Out:
# C:\Users\crosi\AppData\Local\Temp\ipykernel_16068\45211595.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['work', 'uri'], inplace=True)
#                                                  title  \
# 0                                Le rire de De Kooning
# 1       A way of living : the art of Willem De Kooning
# 2    Hartung et les peintres lyriques : Schneider, ...
# 3    Willem de Kooning : drawing seeing-seeing draw...
# 4    Les irascibles : Pollock, De Kooning, Rothko e...
# ..                                                 ...
# 172              Écrits et propos de Willem De Kooning
# 173  Six Painters: Mondrian, Guston, Kline, De Koon...
# 174     Piet Mondrian, Hans Hofmann, Willem de Kooning
# 175                                  Willem De Kooning
# 176                                         De Kooning
#
#                                               Subtitle  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 172                Les Fiches de lecture d'Universalis
# 173  Exhibition. Catalogue. Houston, Texas, Februar...
# 174  europäische Künstler in den USA - amerikanisch...
# 175                 die späten Gemälde, die 80er Jahre
# 176                                                N/A
#
#                                              publisher        date  \
# 0                          Bordeaux : Olympique , 2019        2019
# 1                London : Phaidon Press Limited , 2017        2014
# 2    Landerneau : Fonds Hélène & Édouard Leclerc po...        2016
# 3                              New York : Arena , 1998        1998
# 4                    Paris : le Cherche midi , DL 2023        2023
# ..                                                 ...         ...
# 172                          Encyclopaedia Universalis  2015-11-10
# 173                                                N/A        1967
# 174                                                N/A        2003
# 175                                                N/A        1996
# 176                                                N/A        1960
#
#                    isbn                                            Authors
# 0         9782955755068                                                NaN
# 1            0714845817                                                NaN
# 2         9791096209002                                                NaN
# 3            0965728080                                                NaN
# 4         9782749176703                                                NaN
# ..                  ...                                                ...
# 172       9782852296558                         Encyclopaedia Universalis,
# 173     OCLC:1414760875                                                N/A
# 174          3793093239                                      Tobias Lander
# 175          9069181681                                                N/A
# 176  UOM:39015010988510  Harriet Grossman Janis, Harriet Janis, Rudi Blesh
#
# [177 rows x 6 columns]

# %% [markdown]
# Check how many bibliographic records are actually exhibition catalogues.

# %%
import pandas as pd

# Assuming df is your DataFrame

# Count total rows of the DataFrame
total_rows = len(new_df)

# Count rows where 'title', 'subtitle', or 'description' contain specified keywords
keyword_rows = new_df[new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) |
                  new_df['Subtitle'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) ]

# Get the count of rows containing the specified keywords
keyword_rows_count = len(keyword_rows)

print("Total rows in DataFrame:", total_rows)
print("Rows containing specified keywords:", keyword_rows_count)
# Out:
# Total rows in DataFrame: 177
# Rows containing specified keywords: 32

# %%
import pandas as pd

# Assuming df is your original DataFrame

# Create a mask for rows containing specified keywords in 'title', 'subtitle', or 'description' columns
mask = new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue |catalogo|exposition|retrospective|Ausstellung', case=False, na=False) | \
       new_df['Subtitle'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) 

# Create the exhibitions DataFrame containing rows where keywords are present
exhibitions_dataframe = new_df[mask]

# Remove the rows where keywords are present from the original DataFrame
dfbooks = new_df[~mask]

# Reset index of the original DataFrame
dfbooks.reset_index(drop=True, inplace=True)

# Reset index of the exhibitions DataFrame
exhibitions_dataframe.reset_index(drop=True, inplace=True)


# Display the exhibitions DataFrame containing rows where keywords are present
print("\nExhibitions DataFrame:")
exhibitions_dataframe
# Out:
# Exhibitions DataFrame:
#                                                 title  \
# 0   Hartung et les peintres lyriques : Schneider, ...
# 1   Willem de Kooning : drawing seeing-seeing draw...
# 2   École de New York : expressionnisme abstrait a...
# 3   Action/abstraction : Pollock, de Kooning, and ...
# 4   Burri : lo spazio di materia - tra Europa e US...
# 5   Willem De Kooning : the late paintings, the 19...
# 6   American vanguards : Graham, Davis, Gorky, De ...
# 7   The impact of Chaim Soutine (1893-1943) : de K...
# 8   Willem de Kooning : Retrospektive, Zeichnungen...
# 9   Willem de Kooning : drawings, paintings, sculp...
# 10  Willem De Kooning : late paintings, [mostra, R...
# 11  L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 12  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 13  Willem De Kooning : paintings, [exhibition, Na...
# 14  De Kooning : a retrospective, [exhibition, Mus...
# 15  Willem de Kooning, recent paintings, 1983-1986...
# 16  Deadline : Martin Kippenberger, Absalon, Hans ...
# 17  De Kooning : petit journal de l'exposition, 28...
# 18  Chaïm Soutine, Willem de Kooning, La peinture ...
# 19  Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 20  Willem de Kooning : tracing the figure, [exhib...
# 21                                         De Kooning
# 22                                  Willem de Kooning
# 23     Willem de Kooning : an Exhibition of Paintings
# 24                                  Willem de Kooning
# 25                                  Willem de Kooning
# 26                                  Willem de Kooning
# 27                                         De Kooning
# 28                De Kooning, January 1968-March 1969
# 29  Drawings by Five Abstract Expressionist Painte...
# 30                                         De Kooning
# 31  Six Painters: Mondrian, Guston, Kline, De Koon...
#
#                                              Subtitle  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                    A Retrospective
# 22                         An Exhibition of Paintings
# 23                                                N/A
# 24                            A Centennial Exhibition
# 25  An Exhibition Organized Under the Auspices of ...
# 26  The Last Beginning : Exhibition in Cooperation...
# 27  Drawings, Sculptures : an Exhibition Organized...
# 28  Exhibition M. Knoedler & Co., Inc., March 4-Ma...
# 29                                                N/A
# 30  petit journal de l'exposition : Musee national...
# 31  Exhibition. Catalogue. Houston, Texas, Februar...
#
#                                             publisher  date  \
# 0   Landerneau : Fonds Hélène & Édouard Leclerc po...  2016
# 1                             New York : Arena , 1998  1998
# 2                   [Nice] : Nice musées , impr. 2005  2005
# 3            New York : the Jewish museum , cop. 2008  2008
# 4   Città di Castello : Fondazione Palazzo Albizzi...  2016
# 5   San Francisco : San Francisco museum of modern...  1995
# 6   Andover (Mass.) : Addison gallery of American ...  2011
# 7           Ostfildern-Ruit : Hatje Cantz , cop. 2002  2002
# 8                       München : Prestel , cop. 1984  1984
# 9   New York : Whitney museum of American art ; Mu...  1983
# 10                        Milano : Electa , cop. 2006  2006
# 11                            Paris : B. Lebon , 1991  1991
# 12                              New York : Lévy Gorvy  2017
# 13  Washington : National gallery of art ; New Hav...  1994
# 14             New York : Museum of modern art , 2011  2011
# 15            London : Anthony d'Offay gallery , 1986  1986
# 16  Paris : Musée d'art moderne de la Ville de Par...  2009
# 17             Paris : Centre Georges Pompidou , 1984  1984
# 18            Paris : Musée d'Orsay : Hazan , DL 2021  2021
# 19                      München : Hirmer , cop. 2012  2012
# 20  Los Angeles : Museum of contemporary art ; Pri...  2002
# 21                           The Museum of Modern Art  2011
# 22                                                N/A  1990
# 23                                                N/A  1990
# 24                                                N/A  2004
# 25                                                N/A  1968
# 26                                                N/A  2007
# 27                                       Dutton Adult  1974
# 28                                                N/A  1969
# 29                                                N/A  1976
# 30                                                N/A  1984
# 31                                                N/A  1967
#
#                        isbn                                            Authors
# 0             9791096209002                                                NaN
# 1                0965728080                                                NaN
# 2                2913548695                                                NaN
# 3             9780300122152                                                NaN
# 4                8894063984                                                NaN
# 5                0935640479                                                NaN
# 6                0300121679                                                NaN
# 7                3775791035                                                NaN
# 8                3791306596                                                NaN
# 9                0393018407                                                NaN
# 10               8837049404                                                NaN
# 11               2876880148                                                NaN
# 12               1944379126                                                NaN
# 13               0894682040                                                NaN
# 14            9780500093634                                                NaN
# 15               094756408X                                                NaN
# 16            9782759601080                                                NaN
# 17               285850234X                                                NaN
# 18            9782354333331                                                NaN
# 19               3777455210                                                NaN
# 20               069109618X                                                NaN
# 21            9780870707971  Willem De Kooning, John Elderfield, Lauren Mah...
# 22  STANFORD:36105001689053  Willem De Kooning, Klaus Kertess, Robert Rosen...
# 23          OCLC:1334620202                                  Willem De Kooning
# 24      UCSD:31822034289066                                  Willem De Kooning
# 25             OCLC:1284557                  Thomas B. Hess, Willem De Kooning
# 26               1932598510                                  Willem De Kooning
# 27       UOM:39015006749876  Willem De Kooning, Philip Larson, Peter Schjel...
# 28            UCAL:B4116838                   M. Knoedler & Co, Thomas B. Hess
# 29       UOM:39015041096390         Museum of Contemporary Art (Chicago, Ill.)
# 30               285850234X  Musée national d'art moderne (Paris), Whitney ...
# 31          OCLC:1414760875                                                N/A
