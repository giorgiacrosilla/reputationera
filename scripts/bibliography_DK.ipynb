# %% [markdown]
# webscraping collections data and general bibliography
#
#
# # query on data.bnf
#
# it's not possible to do a query directly using python, so this query:
# ```PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX bnf-onto: <http://data.bnf.fr/ontology/bnf-onto/>
# SELECT *
# WHERE {
#   ?work dct:title ?title ;
#         dct:publisher ?publisher;
#         dct:date ?date;
#         rdfs:seeAlso ?uri ;
#         bnf-onto:isbn ?isbn
#   FILTER (bif:contains(?title, "De_Kooning"))}```
#
# has been done on the web endpoint and then the CSV was downloaded.

# %%
import pandas as pd
getty2 = pd.read_csv("databnf.csv")

getty2.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 2
#       1 import pandas as pd
# ----> 2 getty2 = pd.read_csv("databnf.csv")
#       4 getty2.head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'databnf.csv'

# %%
for column_name in getty2.columns:
    if column_name == "isbn":
        for i, value in enumerate(getty2[column_name]):
            if "-" in value:
                # Replacing hyphens with empty string
                getty2.at[i, column_name] = value.replace("-", "")
getty2.head()
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45692271m#about
# 1  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 2  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 3  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 4  http://data.bnf.fr/ark:/12148/cb45292173b#about
#
#                                             title  \
# 0                           Le rire de De Kooning
# 1  A way of living : the art of Willem De Kooning
# 2  A way of living : the art of Willem De Kooning
# 3  A way of living : the art of Willem De Kooning
# 4  A way of living : the art of Willem De Kooning
#
#                                publisher  date  \
# 0            Bordeaux : Olympique , 2019  2019
# 1  London : Phaidon Press Limited , 2017  2014
# 2  London : Phaidon Press Limited , 2017  2014
# 3  London : Phaidon Press Limited , 2017  2014
# 4  London : Phaidon Press Limited , 2017  2014
#
#                                                uri           isbn
# 0  https://catalogue.bnf.fr/ark:/12148/cb45692271m  9782955755068
# 1  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714845817
# 2  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714873160
# 3  https://catalogue.bnf.fr/ark:/12148/cb45292173b  9780714845814
# 4  https://catalogue.bnf.fr/ark:/12148/cb45292173b  9780714873169

# %% [markdown]
# # query on google books api

# %%
import requests
import json

def fetch_books(query, max_results=40):
    base_url = "https://www.googleapis.com/books/v1/volumes"
    start_index = 0
    all_results = []

    while True:
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results
        }
        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])
            if not items:
                break
            all_results.extend(items)
            start_index += max_results
        else:
            print("Failed to retrieve data. Status code:", response.status_code)
            break

    return all_results

# Search for books related to Cezanne
cezanne_books = fetch_books("De Kooning")

# Saving JSON data to a file
with open("dkbooks.json", "w") as json_file:
    json.dump(cezanne_books, json_file, indent=4)

print("JSON data saved to dkbooks.json")
# Out:
# JSON data saved to cezanne_books.json

# %%
import json
import pandas as pd

# Load JSON data from file
with open("dkbooks.json", "r") as json_file:
    cezanne_books_data = json.load(json_file)

# Extract relevant fields from each book item
books_list = []
for book in cezanne_books_data:
    book_info = {
        "Title": book["volumeInfo"].get("title", "N/A"),
        "Subtitle": book["volumeInfo"].get("subtitle", "N/A"),
        "Authors": ", ".join(book["volumeInfo"].get("authors", ["N/A"])),
        "Publisher": book["volumeInfo"].get("publisher", "N/A"),
        "PublishedDate": book["volumeInfo"].get("publishedDate", "N/A"),
        "Description": book["volumeInfo"].get("description", "N/A"),
        "isbn": book["volumeInfo"].get("industryIdentifiers", [{}])[0].get("identifier", "N/A"),  # Retrieving ISBN
    }
    books_list.append(book_info)

# Create DataFrame
books_df = pd.DataFrame(books_list)

# Display DataFrame
books_df.head()
# Out:
#                                     Title         Subtitle  \
# 0  De Kooning, dipinti, disegni, sculture              N/A
# 1                              De Kooning              N/A
# 2                       Willem De Kooning   late paintings
# 3                              De Kooning  A Retrospective
# 4                       Willem de Kooning              N/A
#
#                                              Authors  \
# 0                                  Willem De Kooning
# 1                                                N/A
# 2             Willem De Kooning, Museo Carlo Bilotti
# 3  Willem De Kooning, John Elderfield, Lauren Mah...
# 4                                   Carolyn Lanchner
#
#                   Publisher PublishedDate  \
# 0                       N/A          1985
# 1                       N/A          1985
# 2          Mondadori Electa          2006
# 3  The Museum of Modern Art          2011
# 4  The Museum of Modern Art          2011
#
#                                          Description                isbn
# 0                                                N/A  UOM:39015015825683
# 1                                                N/A       OCLC:12250843
# 2  A publication displaying the late works of one...  UOM:39015066851935
# 3  This publication offers an unparalleled opport...       9780870707971
# 4  Willem de Kooning was a pioneering figure amon...       9780870707889

# %%
liss = []
for column_name in books_df.columns:
    if column_name == "Title":
        for value in books_df[column_name]:
            if "de Kooning" in value or "De Kooning" in value:
                liss.append(value)
print(len(liss))
# Out:
# 149

# %%
import pandas as pd

# Assuming books_df is your DataFrame
new_dataframe = books_df[books_df["Title"].str.contains("de Kooning", case=False) & ~books_df["Title"].str.contains("Elaine de Kooning", case=False)].copy()

new_dataframe.reset_index(drop=True, inplace=True)

new_dataframe.head()
# Out:
#                                     Title         Subtitle  \
# 0  De Kooning, dipinti, disegni, sculture              N/A
# 1                              De Kooning              N/A
# 2                       Willem De Kooning   late paintings
# 3                              De Kooning  A Retrospective
# 4                       Willem de Kooning              N/A
#
#                                              Authors  \
# 0                                  Willem De Kooning
# 1                                                N/A
# 2             Willem De Kooning, Museo Carlo Bilotti
# 3  Willem De Kooning, John Elderfield, Lauren Mah...
# 4                                   Carolyn Lanchner
#
#                   Publisher PublishedDate  \
# 0                       N/A          1985
# 1                       N/A          1985
# 2          Mondadori Electa          2006
# 3  The Museum of Modern Art          2011
# 4  The Museum of Modern Art          2011
#
#                                          Description                isbn
# 0                                                N/A  UOM:39015015825683
# 1                                                N/A       OCLC:12250843
# 2  A publication displaying the late works of one...  UOM:39015066851935
# 3  This publication offers an unparalleled opport...       9780870707971
# 4  Willem de Kooning was a pioneering figure amon...       9780870707889

# %%
import pandas as pd

# Assuming df1 and df2 are your two DataFrames with the same column header 'ISBN'

# Merge the two DataFrames on the 'ISBN' column
df_combined = pd.merge(getty2, new_dataframe, on='isbn', how='inner')

# Display the new DataFrame with rows where ISBN is found in both DataFrames
df_combined
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 1  http://data.bnf.fr/ark:/12148/cb347640459#about
# 2  http://data.bnf.fr/ark:/12148/cb37526494b#about
# 3  http://data.bnf.fr/ark:/12148/cb45288067c#about
# 4  http://data.bnf.fr/ark:/12148/cb42265321b#about
# 5  http://data.bnf.fr/ark:/12148/cb347686735#about
# 6  http://data.bnf.fr/ark:/12148/cb38841654h#about
# 7  http://data.bnf.fr/ark:/12148/cb356992193#about
#
#                                                title  \
# 0     A way of living : the art of Willem De Kooning
# 1  Willem De Kooning : Whitney museum of American...
# 2  Willem de Kooning : drawings, paintings, sculp...
# 3  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 4         Willem de Kooning : the artist's materials
# 5  De Kooning : petit journal de l'exposition, 28...
# 6  Willem de Kooning : tracing the figure, [exhib...
# 7                                  Willem De Kooning
#
#                                            publisher  date  \
# 0              London : Phaidon Press Limited , 2017  2014
# 1             Paris : Centre Georges-Pompidou , 1984  1984
# 2  New York : Whitney museum of American art ; Mu...  1983
# 3                              New York : Lévy Gorvy  2017
# 4  Los Angeles : Getty conservation institute , c...  2010
# 5             Paris : Centre Georges Pompidou , 1984  1984
# 6  Los Angeles : Museum of contemporary art ; Pri...  2002
# 7                           Paris : l'Échoppe , 1994  1994
#
#                                                uri           isbn  \
# 0  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714873160
# 1  https://catalogue.bnf.fr/ark:/12148/cb347640459     2858502552
# 2  https://catalogue.bnf.fr/ark:/12148/cb37526494b     0393018407
# 3  https://catalogue.bnf.fr/ark:/12148/cb45288067c     1944379126
# 4  https://catalogue.bnf.fr/ark:/12148/cb42265321b  9781606060216
# 5  https://catalogue.bnf.fr/ark:/12148/cb347686735     285850234X
# 6  https://catalogue.bnf.fr/ark:/12148/cb38841654h     069109618X
# 7  https://catalogue.bnf.fr/ark:/12148/cb356992193     2840680297
#
#                      Title                                           Subtitle  \
# 0        Willem de Kooning                                    A Way of Living
# 1               De Kooning
# 2        Willem de Kooning  Drawings, Paintings, Sculpture, [mostra Itiner...
# 3  De Kooning - Zao Wou-KI                                                N/A
# 4        Willem de Kooning                             The Artist's Materials
# 5               De Kooning  petit journal de l'exposition : Musee national...
# 6        Willem de Kooning                                 Tracing the Figure
# 7        Willem De Kooning                                                N/A
#
#                                              Authors  \
# 0                                     Judith Zilczer
# 1  Claire Stoullig, Catherine Bompuis, Akademie d...
# 2                   Paul Cummings, Willem De Kooning
# 3                                                N/A
# 4                                         Susan Lake
# 5  Musée national d'art moderne (Paris), Whitney ...
# 6  Willem De Kooning, Cornelia H. Butler, Paul Sc...
# 7                                        Edwin Denby
#
#                     Publisher PublishedDate  \
# 0               Phaidon Press    2017-05-22
# 1                         N/A          1984
# 2                         N/A          1983
# 3      Dominique Levy Gallery    2017-03-28
# 4          Getty Publications          2010
# 5                         N/A          1984
# 6  Princeton University Press          2002
# 7                         N/A          1994
#
#                                          Description
# 0  In a new format, the bestselling monograph on ...
# 1                                                N/A
# 2                                                N/A
# 3  This volume explores the parallel careers of t...
# 4  This in-depth study of the paintings of Willem...
# 5                                                N/A
# 6  Willem de Kooning, one of the great pioneers o...
# 7                                                N/A

# %%
import pandas as pd

# Assuming df1 and df2 are your two DataFrames

# Rename the 'Title' column in df2 to 'title'
new_dataframe.rename(columns={'Title': 'title'}, inplace=True)
new_dataframe.rename(columns={'PublishedDate': 'date'}, inplace=True)
new_dataframe.rename(columns={'Publisher': 'publisher'}, inplace=True)
# Concatenate the DataFrames vertically
combined_df = pd.concat([getty2, new_dataframe], ignore_index=True)

# Drop duplicates based on 'isbn' column
new_df = combined_df.drop_duplicates(subset='isbn')
new_df = combined_df.drop_duplicates(subset=['title', 'publisher', 'date'], keep='first')
# Reset index of the new DataFrame
new_df.reset_index(drop=True, inplace=True)
new_df.drop(columns=['work', 'uri'], inplace=True)
index_column = new_df.columns.get_loc('Subtitle')

# Move the column to position 2
new_column_order = list(new_df.columns)
new_column_order.insert(1, new_column_order.pop(index_column))
new_df = new_df[new_column_order]

# Display the new DataFrame with unique rows based on ISBN and consistent column name 'title'
new_df
# Out:
# C:\Users\crosi\AppData\Local\Temp\ipykernel_2816\627457357.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['work', 'uri'], inplace=True)
#                                                  title  \
# 0                                Le rire de De Kooning
# 1       A way of living : the art of Willem De Kooning
# 2    Hartung et les peintres lyriques : Schneider, ...
# 3    Willem de Kooning : drawing seeing-seeing draw...
# 4    Les irascibles : Pollock, De Kooning, Rothko e...
# 5    École de New York : expressionnisme abstrait a...
# 6    Action/abstraction : Pollock, de Kooning, and ...
# 7    Burri : lo spazio di materia - tra Europa e US...
# 8    Willem De Kooning : the late paintings, the 19...
# 9                                    Willem de Kooning
# 10   American vanguards : Graham, Davis, Gorky, De ...
# 11                                    De Kooning, vite
# 12                                    De Kooning, vite
# 13   The impact of Chaim Soutine (1893-1943) : de K...
# 14                        Between sense and De Kooning
# 15       Willem de Kooning nonstop : cherchez la femme
# 16   Willem De Kooning : Whitney museum of American...
# 17   Willem de Kooning : Retrospektive, Zeichnungen...
# 18   Willem de Kooning : drawings, paintings, sculp...
# 19   Willem De Kooning : late paintings, [mostra, R...
# 20   L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 21   Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 22          Willem de Kooning : the artist's materials
# 23   Willem De Kooning : paintings, [exhibition, Na...
# 24   De Kooning paintings : 1960-1980, Kunstmuseum ...
# 25   American masters : the voice and the myth in m...
# 26   De Kooning : a retrospective, [exhibition, Mus...
# 27   A generous vision : the creative life of Elain...
# 28   Abstract expressionist women painters : an ann...
# 29   Willem De Kooning : Nordatlantens ljus, [utstä...
# 30   Willem de Kooning : from the Hirshhorn museum ...
# 31   Willem de Kooning, recent paintings, 1983-1986...
# 32   Deadline : Martin Kippenberger, Absalon, Hans ...
# 33   Pintura al desnudo : Picasso, Dubuffet, De Koo...
# 34       Willem de Kooning : reflections in the studio
# 35   Et maintenant je veux parler de Willem de Kooning
# 36   De Kooning : petit journal de l'exposition, 28...
# 37   Guerrero, De Kooning : la sabiduría del color,...
# 38   Chaïm Soutine, Willem de Kooning, La peinture ...
# 39   Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 40   Willem De Kooning : de late schilderijen, 1981...
# 41   The New York schools of music and visual arts ...
# 42   Maskierung der Malerei : Jasper Johns nach Wil...
# 43   Willem de Kooning : tracing the figure, [exhib...
# 44   Willem de Kooning : [exposición] Institut vale...
# 45                                   Willem De Kooning
# 46   L'art contemporain : de l'informel aux recherc...
# 47   Willem De Kooning, 1904-1997 : les contenus, i...
# 48                              De Kooning : 1904-1997
# 49                                   Willem de Kooning
# 50                                   Willem de Kooning
# 51                      Willem de Kooning, een portret
# 52   Chaïm Soutine, Willem de Kooning, La peinture ...
# 53   Willem De Kooning : works, writings and interv...
# 54                                   Willem de Kooning
# 55              De Kooning, dipinti, disegni, sculture
# 56                                          De Kooning
# 57                                   Willem De Kooning
# 58                                          De Kooning
# 59                                   Willem de Kooning
# 60                                   Willem de Kooning
# 61                        Willem de Kooning, 1904-1997
# 62                         Willem de Kooning and Italy
# 63                                   Willem de Kooning
# 64                                   Willem De Kooning
# 65                                   Willem de Kooning
# 66                                          De Kooning
# 67                           Willem de Kooning Nonstop
# 68                                          De Kooning
# 69                                   Willem de Kooning
# 70                                          De Kooning
# 71                                   Willem de Kooning
# 72                                   Willem de Kooning
# 73      Willem de Kooning : an Exhibition of Paintings
# 74                                   Willem De Kooning
# 75                                          De Kooning
# 76                                   Willem De Kooning
# 77                                          De Kooning
# 78                                   Willem de Kooning
# 79                                 De Kooning, 1969-78
# 80                                   Willem de Kooning
# 81                                   Willem de Kooning
# 82                                   Willem de Kooning
# 83                                   Willem de Kooning
# 84                                   Willem de Kooning
# 85                             De Kooning - Zao Wou-KI
# 86                        De Kooning; Recent Paintings
# 87                   Willem de Kooning in East Hampton
# 88                                   Willem De Kooning
# 89                     The Essential Willem de Kooning
# 90                                   Willem de Kooning
# 91                        Willem de Kooning, 1941-1959
# 92                                   Willem de Kooning
# 93                       Get to Know Willem de Kooning
# 94                                   Willem De Kooning
# 95                                   Willem de Kooning
# 96                                   Willem de Kooning
# 97                                   Willem de Kooning
# 98                                   Willem de Kooning
# 99                                          De Kooning
# 100            Willem de Kooning, Works from 1951-1981
# 101                               De Kooning; Drawings
# 102                                  Willem de Kooning
# 103         Druckgraphische Werk Von Willem de Kooning
# 104                   Willem De Kooning, Jean Dubuffet
# 105                             De Kooning/Chamberlain
# 106     The American Critics of Pollock and De Kooning
# 107                                  Willem de Kooning
# 108   Willem De Kooning, Jean Dubuffet, the Late Works
# 109                                  Willem De Kooning
# 110                De Kooning, January 1968-March 1969
# 111                                  Willem de Kooning
# 112  Willem de Kooning. - New York: Braziller 1959....
# 113                                  Willem De Kooning
# 114                                  Willem de Kooning
# 115  Six Painters: Mondrian, Guston, Kline, De Koon...
# 116                                         De Kooning
# 117                                  Willem de Kooning
# 118                               De Kooning's Bicycle
# 119                                  Willem De Kooning
# 120                                  Willem de Kooning
# 121                       Between Sense and De Kooning
# 122                            De Kooning, Lithographs
# 123                                  Willem de Kooning
# 124                                  Willem de Kooning
# 125                             THE DE KOONING AFFAIR.
# 126                      De Kooning. L'uomo, l'artista
# 127                             Better than de Kooning
# 128                         Willem de Kooning: Vellums
# 129                                 De Kooning/Shiraga
# 130                         Willem de Kooning Drawings
# 131   Willem De Kooning. Jean Dubuffet. The Late Works
# 132        The Collected Writings of Willem de Kooning
# 133                                  Willem de Kooning
# 134                                  Willem de Kooning
# 135                                         De Kooning
# 136                                 Wilhelm De Kooning
# 137                                  Willem de Kooning
# 138  Drawings by Five Abstract Expressionist Painte...
# 139                    Chaïm Soutine/Willem de Kooning
# 140                          Willem de Kooning's Women
# 141   Willem De Kooning, Jean Dubuffet, the Late Works
# 142                                  Willem de Kooning
# 143                                  Willem De Kooning
# 144                    A House for de Kooning's Friend
# 145                  The House for de Kooning's Friend
# 146                                         De Kooning
# 147                         Willem de Kooning Drawings
# 148  I Love Willem De Kooning More Than Chocolate (...
# 149                     Willem De Kooning's Paintbrush
# 150                                     Say de Kooning
# 151                                         De Kooning
# 152                           I Love Willem de Kooning
# 153        Willem De Kooning, Jean Dubuffet. The Women
# 154              Willem de Kooning. Englische Ausgabe.
# 155                 Williem de Kooning Standing Figure
# 156  De Kooning [for] Horn, Percussion, Piano, Viol...
# 157                                  Willem de Kooning
# 158              Écrits et propos de Willem De Kooning
# 159  Six Painters: Mondrian, Guston, Kline, De Koon...
# 160                                         De Kooning
#
#                                               Subtitle  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 38                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 N/A
# 56                                                 N/A
# 57                                      late paintings
# 58                                     A Retrospective
# 59                                                 N/A
# 60                              The Artist's Materials
# 61                                Content as a Glimpse
# 62                                                 N/A
# 63                                                 N/A
# 64   Paintings : [mostra Itinerante], Washington, N...
# 65                          An Exhibition of Paintings
# 66                                                 N/A
# 67                                   Cherchez la femme
# 68                                                 N/A
# 69                                                 N/A
# 70                                  An American Master
# 71                                                 N/A
# 72                                  Tracing the Figure
# 73                                                 N/A
# 74                                  Tracing the Figure
# 75                                                 N/A
# 76                                          A Portrait
# 77                                                 N/A
# 78                                    Recent Paintings
# 79                                                 N/A
# 80                       The Late Paintings, the 1980s
# 81   An Exhibition Organized Under the Auspices of ...
# 82                                                 N/A
# 83                                                 N/A
# 84                                                 N/A
# 85                                                 N/A
# 86                                                 N/A
# 87                                                 N/A
# 88                         Works, Writings, Interviews
# 89                                                 N/A
# 90   The Figure : Movement and Gesture : Paintings,...
# 91                                                 N/A
# 92                From the Hirshhorn Museum Collection
# 93                                                 N/A
# 94                                                 N/A
# 95                      Abstract Landscapes, 1955-1963
# 96                               Drawings & Sculptures
# 97                       Drawing Seeing/seeing Drawing
# 98                                 Paintings 1967-1984
# 99                                Sculptures 1972-1974
# 100                                                N/A
# 101                                                N/A
# 102                                                N/A
# 103
# 104      The Women : November 30, 1990-January 5, 1991
# 105  Influence and Transformation : September 21-Oc...
# 75            OCLC:963159077
# 76                1532883374
# 77                383654962X
# 78              OCLC:8235904
# 79             UCAL:B3908958
# 80       UCSD:31822021615752
# 81              OCLC:1284557
# 82             LCCN:73015620
# 83            OCLC:471898377
# 84                8434308347
# 85                1944379126
# 86             UCAL:B3287209
# 87        UOM:39015012225143
# 88        UOM:39015074249122
# 89          PSU:000053458285
# 90                1935410202
# 91              OCLC:2055976
# 92        UOM:39015026855877
# 93                0766072401
# 94            OCLC:217267406
# 95       UCSD:31822035267962
# 96             OCLC:78840227
# 97        UOM:39015047491660
# 98   STANFORD:36105023689982
# 99                0988930099
# 100  STANFORD:36105031900587
# 101       UOM:39015007566907
# 102           OCLC:935599869
# 103       UOM:39015032446455
# 104       UOM:39015021859486
# 105      UCSD:31822030290308
# 106       UFL:31262046285739
# 107               1932598510
# 108  STANFORD:36105009567517
# 109       UOM:39015055199601
# 110            UCAL:B4116838
# 111               0714873160
# 112           UVA:X001533734
# 113               101440813X
# 114          OCLC:1005883038
# 115       UOM:39015010991100
# 116               372040160X
# 117  STANFORD:36105012423104
# 118            9781429921695
# 119          OCLC:1317842581
# 120            OCLC:46452963
# 121               1861898533
# 122           OCLC:173516539
# 123            OCLC:23006550
# 124           OCLC:501278385
# 125           OCLC:263511675
# 126               8860100224
# 127               3864421373
# 128           OCLC:316861140
# 129               173410595X
# 130               1932608176
# 131          OCLC:1419335561
# 132               0937815136
# 133       UOM:39015015683421
# 134               1258170477
# 135      UCSC:32106016797521
# 136               084785759X
# 137               1932608036
# 138       UOM:39015041096390
# 139               2354333331
# 140               1956864199
# 141           OCLC:741479429
# 142  STANFORD:36105028780083
# 143               1588210332
# 144           OCLC:747408553
# 145               1599160560
# 146          OCLC:1087464322
# 147               1944929290
# 148               1070430358
# 149               1443435775
# 150           OCLC:150625313
# 151               2858502552
# 152               1717883427
# 153          OCLC:1419315490
# 154               379131551X
# 155               0909873496
# 156          OCLC:1423041809
# 157          OCLC:1025933765
# 158            9782852296558
# 159          OCLC:1414760875
# 160       UOM:39015010988510
#
#                                                Authors  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 38                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                   Willem De Kooning
# 56                                                 N/A
# 57              Willem De Kooning, Museo Carlo Bilotti
# 58   Willem De Kooning, John Elderfield, Lauren Mah...
# 59                                    Carolyn Lanchner
# 60                                          Susan Lake
# 61                     Barbara Hess, Willem De Kooning
# 62                                                 N/A
# 63                                     David Cateforis
# 64   David Sylvester, Richard Shiff, Marla Prather,...
# 65   Willem De Kooning, Klaus Kertess, Robert Rosen...
# 66                   Harry F. Gaugh, Willem De Kooning
# 67                                  Rosalind E. Krauss
# 68                                        Barbara Hess
# 69                                                 N/A
# 70                          Mark Stevens, Annalyn Swan
# 71                   Willem De Kooning, Thomas B. Hess
# 72   Willem De Kooning, Cornelia H. Butler, Paul Sc...
# 73                                   Willem De Kooning
# 74                                                 N/A
# 75                                                 N/A
# 76                                     Bert Schierbeek
# 77                     Barbara Hess, Willem De Kooning
# 78                                   Willem De Kooning
# 79   Willem De Kooning, Jack Cowart, Sanford Sivitz...
# 80   Willem De Kooning, Gary Garrels, Robert Storr,...
# 81                   Thomas B. Hess, Willem De Kooning
# 82                                   Willem De Kooning
# 83                                                 N/A
# 84                       Sally Yard, Willem De Kooning
# 85                                                 N/A
# 86   Willem De Kooning, Thomas B. Hess, M. Knoedler...
# 87                    Willem De Kooning, Diane Waldman
# 88                                          Sally Yard
# 89                                    Catherine Morris
# 90                                       Richard Shiff
# 91                                   Willem De Kooning
# 92   Judith Zilczer, Hirshhorn Museum and Sculpture...
# 93                                    Charlotte Taylor
# 94              Allan Stone Gallery, Willem De Kooning
# 95                 Willem De Kooning, Gagosian Gallery
# 96                Willem De Kooning, Walker Art Center
# 97   Willem De Kooning, Klaus Kertess, Drawing Cent...
# 98                                   Willem De Kooning
# 99                                                 N/A
# 100      Judith Lynn Wolfe, Guild Hall of East Hampton
# 101                                  Willem De Kooning
# 102                                                N/A
# 103                F. Lanier Graham, Willem De Kooning
# 104  Willem De Kooning, Jean Dubuffet, Mildred Glim...
# 105  Bernice Rose, Willem De Kooning, PaceWildenste...
# 106                             Charles Frank Thompson
# 107                                  Willem De Kooning
# 108  Willem De Kooning, Peter Schjeldahl, Pace Gallery
# 109               Willem De Kooning, Brenda Richardson
# 110                   M. Knoedler & Co, Thomas B. Hess
# 111                                     Judith Zilczer
# 112                                     Thomas B. Hess
# 113                                   Thomas B Cn Hess
# 114                                   Harold Resenberg
# 115  University of St. Thomas (Houston, Tex.). Art ...
# 116           Bernhard Bürgi, Klaus Kertess, Ralph Ubl
# 117                                  Willem De Kooning
# 118                                        Robert Long
# 119                                                N/A
# 120            Willem De Kooning, Robert Pincus-Witten
# 121                   Richard Shiff, Willem De Kooning
# 122                                  Willem De Kooning
# 123                Willem De Kooning, Henry Geldzahler
# 124  Robert Rosenblum, Whitney Museum of American A...
# 125                                  Willem De Kooning
# 126                         Mark Stevens, Annalyn Swan
# 127                         Andreas Baur, Marcus Weber
# 128  Willem De Kooning, Brenda Richardson, Mitchell...
# 129                      Pepe Karmel, Fergus McCaffrey
# 130             Willem De Kooning, Allan Stone Gallery
# 131                                                N/A
# 132                                  Willem De Kooning
# 133                                     Thomas B. Hess
# 134                                     Thomas B. Hess
# 135                                     Morton Feldman
# 136                                          Cateforis
# 137                                        Allan Stone
# 138         Museum of Contemporary Art (Chicago, Ill.)
# 139                                                N/A
# 140                                   Graeme J. Taylor
# 141                                                N/A
# 142                Willem De Kooning, F. Lanier Graham
# 143                                                N/A
# 144                                       Roger Connah
# 145                                       Roger Connah
# 146                    Philip Larson, Peter Schjeldahl
# 147                                   Peter Schjeldahl
# 148                                Gorgeous Gift Books
# 149                                   Kerry Lee Powell
# 150                                     Lanford Wilson
# 151  Claire Stoullig, Catherine Bompuis, Akademie d...
# 152                                     Perfect Papers
# 153                                   Mildred Glimcher
# 154                                  Willem de Kooning
# 155                                                N/A
# 156                                     Morton Feldman
# 157  Fundación Juan March, Willem De Kooning, Diane...
# 158                         Encyclopaedia Universalis,
# 159                                                N/A
# 160  Harriet Grossman Janis, Harriet Janis, Rudi Blesh
#
#                                            Description
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 38                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 N/A
# 56                                                 N/A
# 57   A publication displaying the late works of one...
# 58   This publication offers an unparalleled opport...
# 59   Willem de Kooning was a pioneering figure amon...
# 60   This in-depth study of the paintings of Willem...
# 61   This volume covers the most prominent pieces o...
# 62                                                 N/A
# 63                                                 N/A
# 64                                                 N/A
# 65                                                 N/A
# 66   Willem de Kooning had a restless, probing crea...
# 67   In the early 1950s, Willem de Kooning’s Woman ...
# 68                                                 N/A
# 69                                                 N/A
# 70   Traces the career of abstract expressionist Wi...
# 71                                                 N/A
# 72   Willem de Kooning, one of the great pioneers o...
# 73                                                 N/A
# 74                                                 N/A
# 75                                                 N/A
# 76   In 1967 the Dutch author Bert Schierbeek flew ...
# 77                                                 N/A
# 78                                                 N/A
# 79                                                 N/A
# 80   Published in conjunction with an exhibition of...
# 81                                                 N/A
# 82                                                 N/A
# 83                                                 N/A
# 84                                                 N/A
# 85   This volume explores the parallel careers of t...
# 86                                                 N/A
# 87                                                 N/A
# 88   Text by Sally Yard. Interview by Harold Rosenb...
# 89   Examines the work and career of Willem de Koon...
# 90                                                 N/A
# 91                                                 N/A
# 92   In the early 1960s, and established his art wi...
# 93   Although born in the Netherlands, Willem de Ko...
# 94                                                 N/A
# 95                                                 N/A
# 96                                                 N/A
# 97   Willem de Kooning (1904-1997) created several ...
# 98                                                 N/A
# 99                                                 N/A
# 100                                                N/A
# 101  From the dust jacket: This volume reproduces i...
# 102                                                N/A
# 103                                                N/A
# 104                                                N/A
# 105                                                N/A
# 106                                                N/A
# 107  Willem de Kooning arrived in the United States...
# 108                                                N/A
# 109  This catalog is the first to examine in depth ...
# 110                                                N/A
# 111  In a new format, the bestselling monograph on ...
# 112  A complete illustrated documentation of the ca...
# 113  This work has been selected by scholars as bei...
# 114                                                N/A
# 115                                                N/A
# 116  Overview: Willem de Kooning is celebrated in t...
# 117                                                N/A
# 118  Some of the twentieth century's most important...
# 119                                                N/A
# 120                                                N/A
# 121  "'Order to me is to be ordered about", Willem ...
# 122                                                N/A
# 123                                                N/A
# 124                                                N/A
# 125                                                N/A
# 126                                                N/A
# 127  »STONED AGIN« »Better than de Kooning«, this t...
# 128                                                N/A
# 129                                                N/A
# 130                                                N/A
# 131                                                N/A
# 132                                                N/A
# 133  A complete illustrated documentation of the ca...
# 134                                                N/A
# 135                                                N/A
# 136                                                N/A
# 137  Printed on the occasion of the exhibition "Wil...
# 138                                                N/A
# 139                                                N/A
# 140                                                N/A
# 141                                                N/A
# 142                                                N/A
# 143                                                N/A
# 144                                                N/A
# 145                                                N/A
# 146                                                N/A
# 147                                                N/A
# 148  I Love Willem De Kooning More Than Chocolate: ...
# 149  LONGLISTED FOR THE SCOTIABANK GILLER PRIZE “Po...
# 150                                                N/A
# 151                                                N/A
# 152  I Love Willem De Kooning: Willem De Kooning De...
# 153                                                N/A
# 154                                                N/A
# 155                                                N/A
# 156                                                N/A
# 157                                                N/A
# 158  Bienvenue dans la collection Les Fiches de lec...
# 159                                                N/A
# 160                                                N/A

# %%
import pandas as pd

# Assuming df is your DataFrame

# Count total rows of the DataFrame
total_rows = len(new_df)

# Count rows where 'title', 'subtitle', or 'description' contain specified keywords
keyword_rows = new_df[new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) |
                  new_df['Subtitle'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) ]

# Get the count of rows containing the specified keywords
keyword_rows_count = len(keyword_rows)

print("Total rows in DataFrame:", total_rows)
print("Rows containing specified keywords:", keyword_rows_count)
# Out:
# Total rows in DataFrame: 161
# Rows containing specified keywords: 28

# %%
import pandas as pd

# Assuming df is your original DataFrame

# Create a mask for rows containing specified keywords in 'title', 'subtitle', or 'description' columns
mask = new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue |catalogo|exposition|retrospective|Ausstellung', case=False, na=False) | \
       new_df['Subtitle'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) 

# Create the exhibitions DataFrame containing rows where keywords are present
exhibitions_dataframe = new_df[mask]

# Remove the rows where keywords are present from the original DataFrame
dfbooks = new_df[~mask]

# Reset index of the original DataFrame
dfbooks.reset_index(drop=True, inplace=True)

# Reset index of the exhibitions DataFrame
exhibitions_dataframe.reset_index(drop=True, inplace=True)


# Display the exhibitions DataFrame containing rows where keywords are present
print("\nExhibitions DataFrame:")
exhibitions_dataframe
# Out:
# Exhibitions DataFrame:
#                                                 title  \
# 0   Hartung et les peintres lyriques : Schneider, ...
# 1   Willem de Kooning : drawing seeing-seeing draw...
# 2   École de New York : expressionnisme abstrait a...
# 3   Action/abstraction : Pollock, de Kooning, and ...
# 4   Burri : lo spazio di materia - tra Europa e US...
# 5   Willem De Kooning : the late paintings, the 19...
# 6   American vanguards : Graham, Davis, Gorky, De ...
# 7   The impact of Chaim Soutine (1893-1943) : de K...
# 8   Willem de Kooning : drawings, paintings, sculp...
# 9   Willem De Kooning : late paintings, [mostra, R...
# 10  L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 11  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 12  Willem De Kooning : paintings, [exhibition, Na...
# 13  De Kooning : a retrospective, [exhibition, Mus...
# 14  Willem de Kooning, recent paintings, 1983-1986...
# 15  Deadline : Martin Kippenberger, Absalon, Hans ...
# 16  De Kooning : petit journal de l'exposition, 28...
# 17  Chaïm Soutine, Willem de Kooning, La peinture ...
# 18  Willem de Kooning : tracing the figure, [exhib...
# 19                                         De Kooning
# 20                                  Willem De Kooning
# 21                                  Willem de Kooning
# 22     Willem de Kooning : an Exhibition of Paintings
# 23                                  Willem de Kooning
# 24                                  Willem de Kooning
# 25                De Kooning, January 1968-March 1969
# 26  Drawings by Five Abstract Expressionist Painte...
# 27  Six Painters: Mondrian, Guston, Kline, De Koon...
#
#                                              Subtitle  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                    A Retrospective
# 20  Paintings : [mostra Itinerante], Washington, N...
# 21                         An Exhibition of Paintings
# 22                                                N/A
# 23  An Exhibition Organized Under the Auspices of ...
# 24  The Last Beginning : Exhibition in Cooperation...
# 25  Exhibition M. Knoedler & Co., Inc., March 4-Ma...
# 26                                                N/A
# 27  Exhibition. Catalogue. Houston, Texas, Februar...
#
#                                             publisher  date  \
# 0   Landerneau : Fonds Hélène & Édouard Leclerc po...  2016
# 1                             New York : Arena , 1998  1998
# 2                   [Nice] : Nice musées , impr. 2005  2005
# 3            New York : the Jewish museum , cop. 2008  2008
# 4   Città di Castello : Fondazione Palazzo Albizzi...  2016
# 5   San Francisco : San Francisco museum of modern...  1995
# 6   Andover (Mass.) : Addison gallery of American ...  2011
# 7           Ostfildern-Ruit : Hatje Cantz , cop. 2002  2002
# 8   New York : Whitney museum of American art ; Mu...  1983
# 9                         Milano : Electa , cop. 2006  2006
# 10                            Paris : B. Lebon , 1991  1991
# 11                              New York : Lévy Gorvy  2017
# 12  Washington : National gallery of art ; New Hav...  1994
# 13             New York : Museum of modern art , 2011  2011
# 14            London : Anthony d'Offay gallery , 1986  1986
# 15  Paris : Musée d'art moderne de la Ville de Par...  2009
# 16             Paris : Centre Georges Pompidou , 1984  1984
# 17            Paris : Musée d'Orsay : Hazan , DL 2021  2021
# 18  Los Angeles : Museum of contemporary art ; Pri...  2002
# 19                           The Museum of Modern Art  2011
# 20                                                N/A  1994
# 21                                                N/A  1990
# 22                                                N/A  1990
# 23                                                N/A  1968
# 24                                                N/A  2007
# 25                                                N/A  1969
# 26                                                N/A  1976
# 27                                                N/A  1967
#
#                        isbn  \
# 0             9791096209002
# 1                0965728080
# 2                2913548695
# 3             9780300122152
# 4                8894063984
# 5                0935640479
# 6                0300121679
# 7                3775791035
# 8                0393018407
# 9                8837049404
# 10               2876880148
# 11               1944379126
# 12               0894682040
# 13            9780500093634
# 14               094756408X
# 15            9782759601080
# 16               285850234X
# 17            9782354333331
# 18               069109618X
# 19            9780870707971
# 20               0300060114
# 21  STANFORD:36105001689053
# 22          OCLC:1334620202
# 23             OCLC:1284557
# 24               1932598510
# 25            UCAL:B4116838
# 26       UOM:39015041096390
# 27          OCLC:1414760875
#
#                                               Authors  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  Willem De Kooning, John Elderfield, Lauren Mah...
# 20  David Sylvester, Richard Shiff, Marla Prather,...
# 21  Willem De Kooning, Klaus Kertess, Robert Rosen...
# 22                                  Willem De Kooning
# 23                  Thomas B. Hess, Willem De Kooning
# 24                                  Willem De Kooning
# 25                   M. Knoedler & Co, Thomas B. Hess
# 26         Museum of Contemporary Art (Chicago, Ill.)
# 27                                                N/A
#
#                                           Description
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  This publication offers an unparalleled opport...
# 20                                                N/A
# 21                                                N/A
# 22                                                N/A
# 23                                                N/A
# 24  Willem de Kooning arrived in the United States...
# 25                                                N/A
# 26                                                N/A
# 27                                                N/A
