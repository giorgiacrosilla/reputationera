# %% [markdown]
# webscraping collections data and general bibliography
#
#
# # query on data.bnf
#
# it's not possible to do a query directly using python, so this query:
# ```PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX bnf-onto: <http://data.bnf.fr/ontology/bnf-onto/>
# SELECT *
# WHERE {
#   ?work dct:title ?title ;
#         dct:publisher ?publisher;
#         dct:date ?date;
#         rdfs:seeAlso ?uri ;
#         bnf-onto:isbn ?isbn
#   FILTER (bif:contains(?title, "De_Kooning"))}```
#
# has been done on the web endpoint and then the CSV was downloaded.

# %%
import pandas as pd
getty2 = pd.read_csv("databnf_KLI.csv")

getty2.head()
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45532401k#about
# 1  http://data.bnf.fr/ark:/12148/cb45532401k#about
# 2  http://data.bnf.fr/ark:/12148/cb35356100b#about
# 3  http://data.bnf.fr/ark:/12148/cb37494522j#about
# 4  http://data.bnf.fr/ark:/12148/cb39124684p#about
#
#                                                title  \
# 0  Klimt and Schiele : drawings from the Albertin...
# 1  Klimt and Schiele : drawings from the Albertin...
# 2  Art in Vienna, 1898-1918 : Klimt, Kokoschka, S...
# 3  Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...
# 4  Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...
#
#                                            publisher  date  \
# 0  Boston, MA : Museum of Fine Arts, Boston : D.A...  2018
# 1  Boston, MA : Museum of Fine Arts, Boston : D.A...  2018
# 2                            London : Phaidon , 1975  1975
# 3                            London : Phaidon , 1993  1993
# 4                            London : Phaidon , 2001  2001
#
#                                                uri           isbn
# 0  https://catalogue.bnf.fr/ark:/12148/cb45532401k     0878468528
# 1  https://catalogue.bnf.fr/ark:/12148/cb45532401k  9780878468522
# 2  https://catalogue.bnf.fr/ark:/12148/cb35356100b  0-7148-1600-0
# 3  https://catalogue.bnf.fr/ark:/12148/cb37494522j  0-7148-1600-0
# 4  https://catalogue.bnf.fr/ark:/12148/cb39124684p  0-7148-2967-6

# %%
for column_name in getty2.columns:
    if column_name == "isbn":
        for i, value in enumerate(getty2[column_name]):
            if "-" in value:
                # Replacing hyphens with empty string
                getty2.at[i, column_name] = value.replace("-", "")
getty2.head()
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45532401k#about
# 1  http://data.bnf.fr/ark:/12148/cb45532401k#about
# 2  http://data.bnf.fr/ark:/12148/cb35356100b#about
# 3  http://data.bnf.fr/ark:/12148/cb37494522j#about
# 4  http://data.bnf.fr/ark:/12148/cb39124684p#about
#
#                                                title  \
# 0  Klimt and Schiele : drawings from the Albertin...
# 1  Klimt and Schiele : drawings from the Albertin...
# 2  Art in Vienna, 1898-1918 : Klimt, Kokoschka, S...
# 3  Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...
# 4  Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...
#
#                                            publisher  date  \
# 0  Boston, MA : Museum of Fine Arts, Boston : D.A...  2018
# 1  Boston, MA : Museum of Fine Arts, Boston : D.A...  2018
# 2                            London : Phaidon , 1975  1975
# 3                            London : Phaidon , 1993  1993
# 4                            London : Phaidon , 2001  2001
#
#                                                uri           isbn
# 0  https://catalogue.bnf.fr/ark:/12148/cb45532401k     0878468528
# 1  https://catalogue.bnf.fr/ark:/12148/cb45532401k  9780878468522
# 2  https://catalogue.bnf.fr/ark:/12148/cb35356100b     0714816000
# 3  https://catalogue.bnf.fr/ark:/12148/cb37494522j     0714816000
# 4  https://catalogue.bnf.fr/ark:/12148/cb39124684p     0714829676

# %% [markdown]
# # query on google books api

# %%
import requests
import json

def fetch_books(query, max_results=40):
    base_url = "https://www.googleapis.com/books/v1/volumes"
    start_index = 0
    all_results = []

    while True:
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results
        }
        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])
            if not items:
                break
            all_results.extend(items)
            start_index += max_results
        else:
            print("Failed to retrieve data. Status code:", response.status_code)
            break

    return all_results

# Search for books related to Cezanne
cezanne_books = fetch_books("Klimt")

# Saving JSON data to a file
with open("klimt_books.json", "w") as json_file:
    json.dump(cezanne_books, json_file, indent=4)

print("JSON data saved to klimt_books.json")
# Out:
# JSON data saved to klimt_books.json

# %%
import json
import pandas as pd

# Load JSON data from file
with open("klimt_books.json", "r") as json_file:
    cezanne_books_data = json.load(json_file)

# Extract relevant fields from each book item
books_list = []
for book in cezanne_books_data:
    book_info = {
        "Title": book["volumeInfo"].get("title", "N/A"),
        "Subtitle": book["volumeInfo"].get("subtitle", "N/A"),
        "Authors": ", ".join(book["volumeInfo"].get("authors", ["N/A"])),
        "Publisher": book["volumeInfo"].get("publisher", "N/A"),
        "PublishedDate": book["volumeInfo"].get("publishedDate", "N/A"),
        "Description": book["volumeInfo"].get("description", "N/A"),
        "isbn": book["volumeInfo"].get("industryIdentifiers", [{}])[0].get("identifier", "N/A"),  # Retrieving ISBN
    }
    books_list.append(book_info)

# Create DataFrame
books_df = pd.DataFrame(books_list)

# Display DataFrame
books_df.head()
# Out:
#                                                Title  \
# 0                                       Gustav Klimt
# 1                                              Klimt
# 2                      Gustav Klimt. Tutti i dipinti
# 3                                              Klimt
# 4  Klimt. L'uomo, l'artista, il suo mondo. Ediz. ...
#
#                    Subtitle                           Authors Publisher  \
# 0                       N/A                      Gustav Klimt       N/A
# 1  la secessione e l'Italia                               N/A       N/A
# 2                       N/A                  Tobias G. Natter       N/A
# 3                       N/A  Gustav Klimt, Cecilia Bernardini       N/A
# 4                       N/A  Gabriella Belli, Elena Pontiggia       N/A
#
#   PublishedDate Description                 isbn
# 0          1981         N/A           8820204649
# 1          2021         N/A           8857246574
# 2          2018         N/A           383656291X
# 3          1980         N/A  UCSC:32106008329085
# 4          2022         N/A           8857247511

# %%
liss = []
for column_name in books_df.columns:
    if column_name == "Title":
        for value in books_df[column_name]:
            if "Klimt" in value or "Klimt" in value:
                liss.append(value)
print(len(liss))
# Out:
# 209

# %%
import pandas as pd

# Assuming books_df is your DataFrame
new_dataframe = books_df[books_df["Title"].str.contains("Klimt", case=False)]

new_dataframe.reset_index(drop=True, inplace=True)

new_dataframe.head()
# Out:
#                                                Title  \
# 0                                       Gustav Klimt
# 1                                              Klimt
# 2                      Gustav Klimt. Tutti i dipinti
# 3                                              Klimt
# 4  Klimt. L'uomo, l'artista, il suo mondo. Ediz. ...
#
#                    Subtitle                           Authors Publisher  \
# 0                       N/A                      Gustav Klimt       N/A
# 1  la secessione e l'Italia                               N/A       N/A
# 2                       N/A                  Tobias G. Natter       N/A
# 3                       N/A  Gustav Klimt, Cecilia Bernardini       N/A
# 4                       N/A  Gabriella Belli, Elena Pontiggia       N/A
#
#   PublishedDate Description                 isbn
# 0          1981         N/A           8820204649
# 1          2021         N/A           8857246574
# 2          2018         N/A           383656291X
# 3          1980         N/A  UCSC:32106008329085
# 4          2022         N/A           8857247511

# %%
import pandas as pd

# Assuming df1 and df2 are your two DataFrames with the same column header 'ISBN'

# Merge the two DataFrames on the 'ISBN' column
df_combined = pd.merge(getty2, new_dataframe, on='isbn', how='inner')

# Display the new DataFrame with rows where ISBN is found in both DataFrames
df_combined
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb46858502q#about
# 1  http://data.bnf.fr/ark:/12148/cb46858502q#about
# 2  http://data.bnf.fr/ark:/12148/cb46855667v#about
# 3  http://data.bnf.fr/ark:/12148/cb371857458#about
# 4  http://data.bnf.fr/ark:/12148/cb43818271g#about
# 5  http://data.bnf.fr/ark:/12148/cb43818271g#about
# 6  http://data.bnf.fr/ark:/12148/cb442786023#about
# 7  http://data.bnf.fr/ark:/12148/cb472430726#about
# 8  http://data.bnf.fr/ark:/12148/cb40941041p#about
#
#                                                title  \
# 0  Klimt e i maestri "segreti" della Ricci Oddi :...
# 1  Klimt e i maestri "segreti" della Ricci Oddi :...
# 2  Klimt : la secessione e l'Italia, [mostra al P...
# 3                            Gustav Klimt, 1862-1918
# 4  Klimt : alle origini di un mito, [mostra, Mila...
# 5  Klimt : alle origini di un mito, [mostra, Mila...
# 6  Klimt : up close and personal, paintings, lett...
# 7  Klimt e l'arte italiana : [mostra, Museo d'art...
# 8  Schiele, Klimt, Kokoschka e gli amici viennesi...
#
#                                            publisher  date  \
# 0  Piacenza : Galleria d'arte moderna Ricci Oddi ...  2021
# 1  Piacenza : Galleria d'arte moderna Ricci Oddi ...  2021
# 2                              Milano : Skira , 2021  2021
# 3  Köln ; London ; Paris [etc.] : Taschen , cop. ...  2000
# 4               Milano : 24 ore cultura , impr. 2014  2014
# 5               Milano : 24 ore cultura , impr. 2014  2014
# 6                   Wien : Brandstätter , cop. 2012  2012
# 7     Cinisello Balsamo, Milano : Silvana editoriale  2023
# 8  Milano : Skira ; Trento : MART, Museo di arte ...  2006
#
#                                                uri           isbn  \
# 0  https://catalogue.bnf.fr/ark:/12148/cb46858502q  9791259580344
# 1  https://catalogue.bnf.fr/ark:/12148/cb46858502q  9791259580344
# 2  https://catalogue.bnf.fr/ark:/12148/cb46855667v     8857246574
# 3  https://catalogue.bnf.fr/ark:/12148/cb371857458     3822859400
# 4  https://catalogue.bnf.fr/ark:/12148/cb43818271g     8866481939
# 5  https://catalogue.bnf.fr/ark:/12148/cb43818271g     8866481939
# 6  https://catalogue.bnf.fr/ark:/12148/cb442786023     3850336298
# 7  https://catalogue.bnf.fr/ark:/12148/cb472430726     8836654703
# 8  https://catalogue.bnf.fr/ark:/12148/cb40941041p     8876249508
#
#                                                Title  \
# 0  Klimt e i maestri «segreti» della Ricci Oddi. ...
# 1  Klimt e i maestri «segreti» della Ricci Oddi. ...
# 2                                              Klimt
# 3                             Gustav Klimt 1862-1918
# 4                                              Klimt
# 5                                              Klimt
# 6                                              Klimt
# 7          Klimt e l'arte italiana. Ediz. illustrata
# 8  Schiele, Klimt, Kokoschka e gli amici viennesi...
#
#                                             Subtitle  \
# 0                                                N/A
# 1                                                N/A
# 2                           la secessione e l'Italia
# 3                                                N/A
# 4                            alle origini di un mito
# 5                            alle origini di un mito
# 6  Up Close and Personal : Paintings, Letters, In...
# 7                                                N/A
# 8                                                N/A
#
#                                              Authors               Publisher  \
# 0                                       E. Pontiggia                     N/A
# 1                                       E. Pontiggia                     N/A
# 2                                                N/A                     N/A
# 3                         Gilles Néret, Gustav Klimt                     N/A
# 4                                   Alfred Weidinger          24 Ore Cultura
# 5                                   Alfred Weidinger          24 Ore Cultura
# 6  Gustav Klimt, Tobias Günter Natter, Franz Smol...  Christian Brandstatter
# 7                         Beatrice Avanzi, V. Sgarbi                     N/A
# 8  Tobias Günter Natter, Tomas Sharman, Thomas Tr...                     N/A
#
#   PublishedDate                                        Description
# 0          2021                                                N/A
# 1          2021                                                N/A
# 2          2021                                                N/A
# 3          2000                                                N/A
# 4          2014  The career of an Austrian artist who has becom...
# 5          2014  The career of an Austrian artist who has becom...
# 6          2012  The work of Gustav Klimt is world famous, but ...
# 7          2023                                                N/A
# 8          2006                                                N/A

# %%
import pandas as pd

# Assuming df1 and df2 are your two DataFrames

# Rename the 'Title' column in df2 to 'title'
new_dataframe.rename(columns={'Title': 'title'}, inplace=True)
new_dataframe.rename(columns={'PublishedDate': 'date'}, inplace=True)
new_dataframe.rename(columns={'Publisher': 'publisher'}, inplace=True)
# Concatenate the DataFrames vertically
combined_df = pd.concat([getty2, new_dataframe], ignore_index=True)

# Drop duplicates based on 'isbn' column
new_df = combined_df.drop_duplicates(subset='isbn')
new_df = combined_df.drop_duplicates(subset=['title', 'publisher', 'date'], keep='first')
# Reset index of the new DataFrame
new_df.reset_index(drop=True, inplace=True)
new_df.drop(columns=['work', 'uri'], inplace=True)
index_column = new_df.columns.get_loc('Subtitle')

# Move the column to position 2
new_column_order = list(new_df.columns)
new_column_order.insert(1, new_column_order.pop(index_column))
new_df = new_df[new_column_order]

# Display the new DataFrame with unique rows based on ISBN and consistent column name 'title'
new_df
# Out:
# C:\Users\crosi\AppData\Local\Temp\ipykernel_29488\627457357.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe.rename(columns={'Title': 'title'}, inplace=True)
# C:\Users\crosi\AppData\Local\Temp\ipykernel_29488\627457357.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe.rename(columns={'PublishedDate': 'date'}, inplace=True)
# C:\Users\crosi\AppData\Local\Temp\ipykernel_29488\627457357.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_dataframe.rename(columns={'Publisher': 'publisher'}, inplace=True)
# C:\Users\crosi\AppData\Local\Temp\ipykernel_29488\627457357.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['work', 'uri'], inplace=True)
#                                                  title Subtitle  \
# 0    Klimt and Schiele : drawings from the Albertin...      NaN
# 1    Art in Vienna, 1898-1918 : Klimt, Kokoschka, S...      NaN
# 2    Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...      NaN
# 3    Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...      NaN
# 4    Art in Vienna 1898-1918 : Klimt, Kokoschka, Sc...      NaN
# ..                                                 ...      ...
# 304                        Tout l'œuvre peint de Klimt      N/A
# 305                             Gustav Klimt, Drawings      N/A
# 306  Gustav Klimt. La storia illustrata dei grandi ...      N/A
# 307                                              Klimt      N/A
# 308    Klimt. La realtà trasfigurata. Ediz. illustrata      N/A
#
#                                              publisher  \
# 0    Boston, MA : Museum of Fine Arts, Boston : D.A...
# 1                              London : Phaidon , 1975
# 2                              London : Phaidon , 1993
# 3                              London : Phaidon , 2001
# 4                              London : Phaidon , 2015
# ..                                                 ...
# 304                                                N/A
# 305                                                N/A
# 306                                      24Ore Cultura
# 307                                     Giunti Editore
# 308                                                N/A
#
#                           date                isbn  \
# 0                         2018          0878468528
# 1                         1975          0714816000
# 2                         1993          0714816000
# 3                         2001          0714829676
# 4                         2015          0714868787
# ..                         ...                 ...
# 304                       1983  UOM:39015042493455
# 305                       1983  UOM:39015027868796
# 306  2020-08-05T00:00:00+02:00       9788866484851
# 307                       1988          8809760832
# 308                       2019          8854042218
#
#                                  Authors  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 304      Gustav Klimt, Sergio Coradeschi
# 305         Gustav Klimt, Serge Sabarsky
# 306  Stefano Zuffi, Massimiliano Aurelio
# 307                       Eva Di Stefano
# 308                Sylvie Girard-Lagorce
#
#                                            Description
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 304                                                N/A
# 305                                                N/A
# 306  Un coloratissimo volume monografico per raccon...
# 307                                                N/A
# 308                                                N/A
#
# [309 rows x 7 columns]

# %%
import pandas as pd

# Assuming df is your DataFrame

# Count total rows of the DataFrame
total_rows = len(new_df)

# Count rows where 'title', 'subtitle', or 'description' contain specified keywords
keyword_rows = new_df[new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) |
                  new_df['Subtitle'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) ]

# Get the count of rows containing the specified keywords
keyword_rows_count = len(keyword_rows)

print("Total rows in DataFrame:", total_rows)
print("Rows containing specified keywords:", keyword_rows_count)
# Out:
# Total rows in DataFrame: 309
# Rows containing specified keywords: 36

# %%
import pandas as pd

# Assuming df is your original DataFrame

# Create a mask for rows containing specified keywords in 'title', 'subtitle', or 'description' columns
mask = new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue |catalogo|exposition|retrospective|Ausstellung', case=False, na=False) | \
       new_df['Subtitle'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) 

# Create the exhibitions DataFrame containing rows where keywords are present
exhibitions_dataframe = new_df[mask]

# Remove the rows where keywords are present from the original DataFrame
dfbooks = new_df[~mask]

# Reset index of the original DataFrame
dfbooks.reset_index(drop=True, inplace=True)

# Reset index of the exhibitions DataFrame
exhibitions_dataframe.reset_index(drop=True, inplace=True)


# Display the exhibitions DataFrame containing rows where keywords are present
print("\nExhibitions DataFrame:")
exhibitions_dataframe
# Out:
# Exhibitions DataFrame:
#                                                 title  \
# 0   Klimt and Schiele : drawings from the Albertin...
# 1   Gustav Klimt : papiers érotiques, [exposition,...
# 2   Il simbolismo : da Moreau a Gauguin a Klimt, m...
# 3   Heiliger Frühling : Gustav Klimt und die Anfän...
# 4   Klimt e i maestri "segreti" della Ricci Oddi :...
# 5   Klimt, Kokoschka, Schiele : dall'art nouveau a...
# 6   Vienna 1900 : Klimt, Schiele, Moser, Kokoschka...
# 7   Klimt : la secessione e l'Italia, [mostra al P...
# 8   De la scène au tableau : David, Füssli, Klimt,...
# 9   Vienna 1900 : Klimt, Schiele, and their times,...
# 10  À fleur de peau : Vienne 1900, de Klimt à Schi...
# 11  Gustav Klimt : disegni dalla collezione Sabars...
# 12  L'abbraccio di Vienna : Klimt, Schiele e i cap...
# 13  Gustav Klimt : painting, design and modern lif...
# 14  De la scène au tableau : David, Füssli, Klimt,...
# 15  Il disegno del nostro secolo : prima parte, da...
# 16  Klimt : alle origini di un mito, [mostra, Mila...
# 17  Say it with flowers! : Viennese flower paintin...
# 18  Faszination Japan : Monet, Van Gogh, Klimt, [A...
# 19  Klimt und die Frauen : [Ausstellung, Österreic...
# 20  L'ossessione nordica : Böcklin, Klimt, Munch ...
# 21  Vienne 1900 : Klimt, Schiele, Moser, Kokoschka...
# 22  Gustav Klimt : d'or et de couleurs, [expositio...
# 23  Gustav Klimt : Erwartung und Erfüllung, Entwu...
# 24  Klimt e l'arte italiana : [mostra, Museo d'art...
# 25  Au temps de Klimt : la sécession à Vienne, [ex...
# 26  Klimt persönlich : Bilder, Briefe, Einblicke,...
# 27  Schiele, Klimt, Kokoschka e gli amici viennesi...
# 28  Gustav Klimt, Oskar Kokoschka, Egon Schiele : ...
# 29  Vienne 1900 : Klimt, Schiele, Moser, Kokoschka...
# 30  Klimt e i maestri «segreti» della Ricci Oddi. ...
# 31  Schiele, Klimt, Kokoschka e gli amici viennesi...
# 32                      Gustav Klimt and Egon Schiele
# 33                                       Gustav Klimt
# 34                                       Gustav Klimt
# 35                  Gustav Klimt, 1862-1918: Drawings
#
#                                              Subtitle  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                N/A
# 31                                                N/A
# 32               Exhibition 65/1, February-April 1965
# 33  Paintings and Drawings : [exhibition], October...
# 34  Paintings and Drawings : (exhibition) October-...
# 35  Exhibition March - April 1970, the Galerie St....
#
#                                             publisher  date  \
# 0   Boston, MA : Museum of Fine Arts, Boston : D.A...  2018
# 1   [Paris] : Gallimard : Fondation Dina Vierny-Mu...  2005
# 2                 Ferrara : Ferrara arte , impr. 2007  2007
# 3             Wien ; München : C. Brandstätter , 1999  1999
# 4   Piacenza : Galleria d'arte moderna Ricci Oddi ...  2021
# 5                            Milano : Mazzotta , 2001  2001
# 6   Paris : Réunion des musées nationaux , impr. 2005  2005
# 7                               Milano : Skira , 2021  2021
# 8   Paris : Skira-Flammarion ; [Marseille] : MM ; ...  2009
# 9    Ostfildern (Allemagne) : Hatje Cantz , cop. 2010  2010
# 10  Paris : Hazan ; Lausanne : Musée cantonal des ...  2020
# 11                      Torino : Ed. GAM , impr. 2004  2004
# 12        Cinisello Balsamo (Milano) : Silvana , 2008  2008
# 13            London : Tate gallery publishing , 2008  2008
# 14  Paris : Skira-Flammarion ; [Marseille] : MM ; ...  2009
# 15                          Milano : Mazzotta , 1994-  1994
# 16               Milano : 24 ore cultura , impr. 2014  2014
# 17                          Vienna : Belvedere , 2018  2018
# 18                              [Heidelberg] : Kehrer  2018
# 19                             [Köln] : DuMont , 2002  2002
# 20                          Venezia : Marsilio , 2014  2014
# 21  Paris : Réunion des musées nationaux , impr. 2005  2005
# 22                            Paris : Hazan , DL 2020  2020
# 23               Ostfildern : Hatje Cantz , cop. 2012  2012
# 24     Cinisello Balsamo, Milano : Silvana editoriale  2023
# 25  Milan : 24 Ore cultura ; Paris : Pinacothèque ...  2015
# 26                  Wien : Brandtstätter , cop. 2012  2012
# 27  Milano : Skira ; Trento : MART, Museo di arte ...  2006
# 28               Kaiserslautern : Pfalzgalerie , 1984  1984
# 29  Paris : Réunion des musées nationaux , impr. 2005  2005
# 30                                                N/A  2021
# 31                                                N/A  2006
# 32                                                N/A  1965
# 33                                                N/A  1966
# 34                                                N/A  1965
# 35                                                N/A  1970
#
#                    isbn                                            Authors  \
# 0            0878468528                                                NaN
# 1            2070118053                                                NaN
# 2            8889793066                                                NaN
# 3            3854478569                                                NaN
# 4         9791259580344                                                NaN
# 5            8820215020                                                NaN
# 6            271185003X                                                NaN
# 7            8857246574                                                NaN
# 8         9782081236912                                                NaN
# 9            3775726853                                                NaN
# 10        9782754111386                                                NaN
# 11           8888103295                                                NaN
# 12        9788836610846                                                NaN
# 13        9781854377357                                                NaN
# 14        9782081229440                                                NaN
# 15           8820210908                                                NaN
# 16           8866481939                                                NaN
# 17        9783791357928                                                NaN
# 18           3868288821                                                NaN
# 19           3832172718                                                NaN
# 20           8831717847                                                NaN
# 21           2711850560                                                NaN
# 22        9782754111799                                                NaN
# 23           3775733051                                                NaN
# 24           8836654703                                                NaN
# 25           8866482552                                                NaN
# 26           385033628X                                                NaN
# 27           8876249508                                                NaN
# 28           8820205866                                                NaN
# 29           2711849244                                                NaN
# 30        9791259580344                                       E. Pontiggia
# 31           8876249508  Tobias Günter Natter, Tomas Sharman, Thomas Tr...
# 32   UOM:39015006624137                       Solomon R. Guggenheim Museum
# 33   UOM:39015028411422             Gustav Klimt, Marlborough Fine Art Ltd
# 34      OCLC:1193524386                  Marlborough Fine Art (London) Ltd
# 35  UCSC:32106001453866                                       Gustav Klimt
#
#    Description
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# 30         N/A
# 31         N/A
# 32         N/A
# 33         N/A
# 34         N/A
# 35         N/A
