# %% [markdown]
# webscraping collections data and general bibliography
#
#
# ### query on data.bnf
#
# it's not possible to do a query directly using python, so this query was performed here <a href="https://data.bnf.fr/sparql/">data.bnf</a>:
# ```
# PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX bnf-onto: <http://data.bnf.fr/ontology/bnf-onto/>
# SELECT *
# WHERE {
#   ?work dct:title ?title ;
#         dct:publisher ?publisher;
#         dct:date ?date;
#         rdfs:seeAlso ?uri ;
#         bnf-onto:isbn ?isbn;
#
#   FILTER (bif:contains(?title, "De_Kooning"))}
#
# ```
#
# has been done on the web endpoint and then the CSV was downloaded, this query searches data both in bnf catalogue and bnf.data.
#
#
# ```
# PREFIX rdarelationships: <http://rdvocab.info/RDARelationshipsWEMI/>
# PREFIX foaf: <http://xmlns.com/foaf/0.1/>
# PREFIX dc: <http://purl.org/dc/elements/1.1/>
# PREFIX dct: <http://purl.org/dc/terms/>
# PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
# PREFIX bnf-onto: <http://data.bnf.fr/ontology/bnf-onto/>
# SELECT distinct ?work ?title ?creatorname ?date ?isbn
# WHERE {
#   ?work dct:title ?title;
#         dct:creator ?creator.
# 		?creator foaf:name ?creatorname.
#   ?work dct:date ?date.
#   ?work rdarelationships:expressionOfWork ?expression.
# ?manifestation rdarelationships:expressionManifested ?expression.
# ?manifestation bnf-onto:isbn ?isbn.
#   FILTER (bif:contains(?title, "De_Kooning"))}
# ```
#
# questa query ritorna anche l'autore, assieme ad ISBN, il problema è che i risultati tra la prima e la seconda query non corrispondono. Penso perchè si lavora a livello di expression (?)

# %%
import pandas as pd
bnf = pd.read_csv("databnf_DK.csv")
pd.set_option('display.max_rows', None)
bnf
# Out:
#                                                work  \
# 0   http://data.bnf.fr/ark:/12148/cb45692271m#about
# 1   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 2   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 3   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 4   http://data.bnf.fr/ark:/12148/cb45292173b#about
# 5   http://data.bnf.fr/ark:/12148/cb45317929s#about
# 6   http://data.bnf.fr/ark:/12148/cb37053892s#about
# 7   http://data.bnf.fr/ark:/12148/cb47258002f#about
# 8   http://data.bnf.fr/ark:/12148/cb40103400g#about
# 9   http://data.bnf.fr/ark:/12148/cb41263375n#about
# 10  http://data.bnf.fr/ark:/12148/cb45241886b#about
# 11  http://data.bnf.fr/ark:/12148/cb45241886b#about
# 12  http://data.bnf.fr/ark:/12148/cb37225082g#about
# 13  http://data.bnf.fr/ark:/12148/cb37047286z#about
# 14  http://data.bnf.fr/ark:/12148/cb42562001p#about
# 15  http://data.bnf.fr/ark:/12148/cb42562001p#about
# 16  http://data.bnf.fr/ark:/12148/cb349979951#about
# 17  http://data.bnf.fr/ark:/12148/cb41133627t#about
# 18  http://data.bnf.fr/ark:/12148/cb38802554n#about
# 19  http://data.bnf.fr/ark:/12148/cb424991989#about
# 20  http://data.bnf.fr/ark:/12148/cb44524427d#about
# 0                               Le rire de De Kooning
# 1      A way of living : the art of Willem De Kooning
# 2      A way of living : the art of Willem De Kooning
# 3      A way of living : the art of Willem De Kooning
# 4      A way of living : the art of Willem De Kooning
# 5   Hartung et les peintres lyriques : Schneider, ...
# 6   Willem de Kooning : drawing seeing-seeing draw...
# 7   Les irascibles : Pollock, De Kooning, Rothko e...
# 8   École de New York : expressionnisme abstrait a...
# 9   Action/abstraction : Pollock, de Kooning, and ...
# 10  Burri : lo spazio di materia - tra Europa e US...
# 11  Burri : lo spazio di materia - tra Europa e US...
# 12  Willem De Kooning : the late paintings, the 19...
# 13                                  Willem de Kooning
# 14  American vanguards : Graham, Davis, Gorky, De ...
# 15  American vanguards : Graham, Davis, Gorky, De ...
# 16                                   De Kooning, vite
# 17                                   De Kooning, vite
# 18  The impact of Chaim Soutine (1893-1943) : de K...
# 19                       Between sense and De Kooning
# 20      Willem de Kooning nonstop : cherchez la femme
# 21      Willem de Kooning nonstop : cherchez la femme
# 22  Willem De Kooning : Whitney museum of American...
# 23  Willem de Kooning : Retrospektive, Zeichnungen...
# 24  Willem de Kooning : drawings, paintings, sculp...
# 25  Willem De Kooning : late paintings, [mostra, R...
# 26  L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 27  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 28  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 29         Willem de Kooning : the artist's materials
# 30         Willem de Kooning : the artist's materials
# 31  Willem De Kooning : paintings, [exhibition, Na...
# 32  De Kooning paintings : 1960-1980, Kunstmuseum ...
# 33  De Kooning paintings : 1960-1980, Kunstmuseum ...
# 34  American masters : the voice and the myth in m...
# 35  De Kooning : a retrospective, [exhibition, Mus...
# 36  A generous vision : the creative life of Elain...
# 37  A generous vision : the creative life of Elain...
# 38  Abstract expressionist women painters : an ann...
# 39  Willem De Kooning : Nordatlantens ljus, [utstä...
# 40  Willem de Kooning : from the Hirshhorn museum ...
# 41  Willem de Kooning, recent paintings, 1983-1986...
# 42  Deadline : Martin Kippenberger, Absalon, Hans ...
# 43  Pintura al desnudo : Picasso, Dubuffet, De Koo...
# 44      Willem de Kooning : reflections in the studio
# 45  Et maintenant je veux parler de Willem de Kooning
# 46  De Kooning : petit journal de l'exposition, 28...
# 47  Guerrero, De Kooning : la sabiduría del color,...
# 48  Chaïm Soutine, Willem de Kooning, La peinture ...
# 49  Chaïm Soutine, Willem de Kooning, La peinture ...
# 50  Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 51  Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 52  Willem De Kooning : de late schilderijen, 1981...
# 53  The New York schools of music and visual arts ...
# 54  The New York schools of music and visual arts ...
# 55  Maskierung der Malerei : Jasper Johns nach Wil...
# 56  Maskierung der Malerei : Jasper Johns nach Wil...
# 57  Willem de Kooning : tracing the figure, [exhib...
# 58  Willem de Kooning : [exposición] Institut vale...
# 59  Willem de Kooning : [exposición] Institut vale...
# 60                                  Willem De Kooning
# 51                      München : Hirmer , cop. 2012  2012
# 52   Rotterdam : Boijmans Van Beuningen museum , 1996  1996
# 53         New York, N.Y. ; London : Routledge , 2002  2002
# 54         New York, N.Y. ; London : Routledge , 2002  2002
# 55                     München : W. Fink , cop. 2008  2008
# 56                     München : W. Fink , cop. 2008  2008
# 57  Los Angeles : Museum of contemporary art ; Pri...  2002
# 58  Valencia : Institut valencià d'art modern ; Ma...  2001
# 59  Valencia : Institut valencià d'art modern ; Ma...  2001
# 60                           Paris : l'Échoppe , 1994  1994
# 61                            Paris : Gründ , DL 2008  2008
# 62  Köln ; London ; Paris [etc.] : Taschen , cop. ...  2004
# 63                        Paris : Cercle d'art , 1998  1998
# 64             New York : Abbeville press , cop. 1983  1983
# 65                     Lyon : Fage éditions , DL 2022  2022
# 66           Leiden : Menken Kasander & Wigman , 2005  2005
# 67            Paris : "Beaux-arts" éditions , DL 2021  2021
# 68                   Barcelona : Ed. Polígrafa , 2007  2007
# 69                            Paris : Hazan , DL 2006  2007
#
#                                                 uri               isbn
# 0   https://catalogue.bnf.fr/ark:/12148/cb45692271m  978-2-9557550-6-8
# 1   https://catalogue.bnf.fr/ark:/12148/cb45292173b         0714845817
# 2   https://catalogue.bnf.fr/ark:/12148/cb45292173b         0714873160
# 3   https://catalogue.bnf.fr/ark:/12148/cb45292173b      9780714845814
# 4   https://catalogue.bnf.fr/ark:/12148/cb45292173b      9780714873169
# 5   https://catalogue.bnf.fr/ark:/12148/cb45317929s  979-10-96209-00-2
# 6   https://catalogue.bnf.fr/ark:/12148/cb37053892s      0-9657280-8-0
# 7   https://catalogue.bnf.fr/ark:/12148/cb47258002f  978-2-7491-7670-3
# 8   https://catalogue.bnf.fr/ark:/12148/cb40103400g      2-913548-69-5
# 9   https://catalogue.bnf.fr/ark:/12148/cb41263375n  978-0-300-12215-2
# 10  https://catalogue.bnf.fr/ark:/12148/cb45241886b         8894063984
# 11  https://catalogue.bnf.fr/ark:/12148/cb45241886b      9788894063981
# 12  https://catalogue.bnf.fr/ark:/12148/cb37225082g      0-935640-47-9
# 13  https://catalogue.bnf.fr/ark:/12148/cb37047286z      2-7324-2507-9
# 14  https://catalogue.bnf.fr/ark:/12148/cb42562001p      0-300-12167-9
# 15  https://catalogue.bnf.fr/ark:/12148/cb42562001p  978-0-300-12167-4
# 16  https://catalogue.bnf.fr/ark:/12148/cb349979951      2-7291-0270-1
# 17  https://catalogue.bnf.fr/ark:/12148/cb41133627t  978-2-7291-1705-4
# 18  https://catalogue.bnf.fr/ark:/12148/cb38802554n      3-7757-9103-5
# 19  https://catalogue.bnf.fr/ark:/12148/cb424991989  978-1-86189-853-1
# 20  https://catalogue.bnf.fr/ark:/12148/cb44524427d         022626744X
# 21  https://catalogue.bnf.fr/ark:/12148/cb44524427d      9780226267449
# 22  https://catalogue.bnf.fr/ark:/12148/cb347640459      2-85850-255-2
# 23  https://catalogue.bnf.fr/ark:/12148/cb374930625      3-7913-0659-6
# 62  https://catalogue.bnf.fr/ark:/12148/cb39220415h      3-8228-2134-9
# 63  https://catalogue.bnf.fr/ark:/12148/cb367039389      2-7022-0500-6
# 64  https://catalogue.bnf.fr/ark:/12148/cb374805947      1-55859-248-2
# 65  https://catalogue.bnf.fr/ark:/12148/cb47124975c  978-2-84975-687-4
# 66  https://catalogue.bnf.fr/ark:/12148/cb399985699      90-74622-53-4
# 67  https://catalogue.bnf.fr/ark:/12148/cb46970628b  979-10-204-0639-2
# 68  https://catalogue.bnf.fr/ark:/12148/cb41066822t  978-84-343-1138-1
# 69  https://catalogue.bnf.fr/ark:/12148/cb41040899j  978-2-7541-0176-9

# %%
for column_name in bnf.columns:
    if column_name == "isbn":
        for i, value in enumerate(bnf[column_name]):
            if "-" in value:
                # Replacing hyphens with empty string
                bnf.at[i, column_name] = value.replace("-", "")
bnf.head()
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45692271m#about
# 1  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 2  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 3  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 4  http://data.bnf.fr/ark:/12148/cb45292173b#about
#
#                                             title  \
# 0                           Le rire de De Kooning
# 1  A way of living : the art of Willem De Kooning
# 2  A way of living : the art of Willem De Kooning
# 3  A way of living : the art of Willem De Kooning
# 4  A way of living : the art of Willem De Kooning
#
#                                publisher  date  \
# 0            Bordeaux : Olympique , 2019  2019
# 1  London : Phaidon Press Limited , 2017  2014
# 2  London : Phaidon Press Limited , 2017  2014
# 3  London : Phaidon Press Limited , 2017  2014
# 4  London : Phaidon Press Limited , 2017  2014
#
#                                                uri           isbn
# 0  https://catalogue.bnf.fr/ark:/12148/cb45692271m  9782955755068
# 1  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714845817
# 2  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714873160
# 3  https://catalogue.bnf.fr/ark:/12148/cb45292173b  9780714845814
# 4  https://catalogue.bnf.fr/ark:/12148/cb45292173b  9780714873169

# %% [markdown]
# ### query on google books api

# %%
import requests
import json

def fetch_books(query, max_results=40):
    base_url = "https://www.googleapis.com/books/v1/volumes"
    start_index = 0
    all_results = []

    while True:
        params = {
            "q": query,
            "startIndex": start_index,
            "maxResults": max_results
        }
        response = requests.get(base_url, params=params)

        if response.status_code == 200:
            data = response.json()
            items = data.get("items", [])
            if not items:
                break
            all_results.extend(items)
            start_index += max_results
        else:
            print("Failed to retrieve data. Status code:", response.status_code)
            break

    return all_results

cezanne_books = fetch_books("De Kooning")

# Saving JSON data to a file
with open("dkbooks.json", "w") as json_file:
    json.dump(cezanne_books, json_file, indent=4)

print("JSON data saved to dkbooks.json")
# Out:
# JSON data saved to dkbooks.json

# %%
import json
import pandas as pd

# Load JSON data from file
with open("dkbooks.json", "r") as json_file:
    cezanne_books_data = json.load(json_file)

# Extract relevant fields from each book item
books_list = []
for book in cezanne_books_data:
    book_info = {
        "Title": book["volumeInfo"].get("title", "N/A"),
        "Subtitle": book["volumeInfo"].get("subtitle", "N/A"),
        "Authors": ", ".join(book["volumeInfo"].get("authors", ["N/A"])),
        "Publisher": book["volumeInfo"].get("publisher", "N/A"),
        "PublishedDate": book["volumeInfo"].get("publishedDate", "N/A"),
        "isbn": book["volumeInfo"].get("industryIdentifiers", [{}])[0].get("identifier", "N/A"),  # Retrieving ISBN
    }
    books_list.append(book_info)

# Create DataFrame
books_df = pd.DataFrame(books_list)
books_df.replace('N/A', np.nan, inplace=True) #modficato oggi 

# Display DataFrame
books_df.head()
# Out:
#                                     Title         Subtitle  \
# 0  De Kooning, dipinti, disegni, sculture              NaN
# 1                              De Kooning              NaN
# 2                       Willem De Kooning   late paintings
# 3                              De Kooning              NaN
# 4                              De Kooning  A Retrospective
#
#                                              Authors  \
# 0                                  Willem De Kooning
# 1                                                NaN
# 2             Willem De Kooning, Museo Carlo Bilotti
# 3                 Willem De Kooning, Gabriella Drudi
# 4  Willem De Kooning, John Elderfield, Lauren Mah...
#
#                   Publisher PublishedDate                isbn
# 0                       NaN          1985  UOM:39015015825683
# 1                       NaN          1985       OCLC:12250843
# 2          Mondadori Electa          2006  UOM:39015066851935
# 3                       NaN          1972  UOM:39015045652768
# 4  The Museum of Modern Art          2011       9780870707971

# %%
liss = []
for column_name in books_df.columns:
    if column_name == "Title":
        for value in books_df[column_name]:
            if "de Kooning" in value or "De Kooning" in value:
                liss.append(value)
print(len(liss))
# Out:
# 148

# %%
import pandas as pd

# Assuming books_df is your DataFrame
new_dataframe = books_df[books_df["Title"].str.contains("de Kooning", case=False) & ~books_df["Title"].str.contains("Elaine de Kooning", case=False)].copy()

new_dataframe.reset_index(drop=True, inplace=True)

new_dataframe.head()
# Out:
#                                     Title         Subtitle  \
# 0  De Kooning, dipinti, disegni, sculture              NaN
# 1                              De Kooning              NaN
# 2                       Willem De Kooning   late paintings
# 3                              De Kooning              NaN
# 4                              De Kooning  A Retrospective
#
#                                              Authors  \
# 0                                  Willem De Kooning
# 1                                                NaN
# 2             Willem De Kooning, Museo Carlo Bilotti
# 3                 Willem De Kooning, Gabriella Drudi
# 4  Willem De Kooning, John Elderfield, Lauren Mah...
#
#                   Publisher PublishedDate                isbn
# 0                       NaN          1985  UOM:39015015825683
# 1                       NaN          1985       OCLC:12250843
# 2          Mondadori Electa          2006  UOM:39015066851935
# 3                       NaN          1972  UOM:39015045652768
# 4  The Museum of Modern Art          2011       9780870707971

# %%
import pandas as pd

# Merge the two DataFrames on the 'ISBN' column
df_combined = pd.merge(bnf, new_dataframe, on='isbn', how='inner')

# Display the new DataFrame with rows where ISBN is found in both DataFrames
df_combined
# Out:
#                                               work  \
# 0  http://data.bnf.fr/ark:/12148/cb45292173b#about
# 1  http://data.bnf.fr/ark:/12148/cb347640459#about
# 2  http://data.bnf.fr/ark:/12148/cb37526494b#about
# 3  http://data.bnf.fr/ark:/12148/cb45288067c#about
# 4  http://data.bnf.fr/ark:/12148/cb42265321b#about
# 5  http://data.bnf.fr/ark:/12148/cb34982520m#about
# 6  http://data.bnf.fr/ark:/12148/cb347686735#about
# 7  http://data.bnf.fr/ark:/12148/cb38841654h#about
# 8  http://data.bnf.fr/ark:/12148/cb356992193#about
#
#                                                title  \
# 0     A way of living : the art of Willem De Kooning
# 1  Willem De Kooning : Whitney museum of American...
# 2  Willem de Kooning : drawings, paintings, sculp...
# 3  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 4         Willem de Kooning : the artist's materials
# 5  Willem de Kooning, recent paintings, 1983-1986...
# 6  De Kooning : petit journal de l'exposition, 28...
# 7  Willem de Kooning : tracing the figure, [exhib...
# 8                                  Willem De Kooning
#
#                                            publisher  date  \
# 0              London : Phaidon Press Limited , 2017  2014
# 1             Paris : Centre Georges-Pompidou , 1984  1984
# 2  New York : Whitney museum of American art ; Mu...  1983
# 3                              New York : Lévy Gorvy  2017
# 4  Los Angeles : Getty conservation institute , c...  2010
# 5            London : Anthony d'Offay gallery , 1986  1986
# 6             Paris : Centre Georges Pompidou , 1984  1984
# 7  Los Angeles : Museum of contemporary art ; Pri...  2002
# 8                           Paris : l'Échoppe , 1994  1994
#
#                                                uri           isbn  \
# 0  https://catalogue.bnf.fr/ark:/12148/cb45292173b     0714873160
# 1  https://catalogue.bnf.fr/ark:/12148/cb347640459     2858502552
# 2  https://catalogue.bnf.fr/ark:/12148/cb37526494b     0393018407
# 3  https://catalogue.bnf.fr/ark:/12148/cb45288067c     1944379126
# 4  https://catalogue.bnf.fr/ark:/12148/cb42265321b  9781606060216
# 5  https://catalogue.bnf.fr/ark:/12148/cb34982520m     094756408X
# 6  https://catalogue.bnf.fr/ark:/12148/cb347686735     285850234X
# 7  https://catalogue.bnf.fr/ark:/12148/cb38841654h     069109618X
# 8  https://catalogue.bnf.fr/ark:/12148/cb356992193     2840680297
#
#                      Title                                           Subtitle  \
# 0        Willem de Kooning                                    A Way of Living
# 1               De Kooning
# 2        Willem de Kooning  Drawings, Paintings, Sculpture, [mostra Itiner...
# 3  De Kooning - Zao Wou-KI                                                NaN
# 4        Willem de Kooning                             The Artist's Materials
# 5        Willem de Kooning                        Recent Paintings, 1983-1986
# 6               De Kooning  petit journal de l'exposition : Musee national...
# 7        Willem de Kooning                                 Tracing the Figure
# 8        Willem De Kooning                                                NaN
#
#                                              Authors  \
# 0                                     Judith Zilczer
# 1  Claire Stoullig, Catherine Bompuis, Akademie d...
# 2                   Paul Cummings, Willem De Kooning
# 3                                                NaN
# 4                                         Susan Lake
# 5                                  Willem De Kooning
# 6  Musée national d'art moderne (Paris), Whitney ...
# 7  Willem De Kooning, Cornelia H. Butler, Paul Sc...
# 8                                        Edwin Denby
#
#                     Publisher PublishedDate
# 0               Phaidon Press    2017-05-22
# 1                         NaN          1984
# 2                         NaN          1983
# 3      Dominique Levy Gallery    2017-03-28
# 4          Getty Publications          2010
# 5     Anthony D'Offay Gallery    1986-01-01
# 6                         NaN          1984
# 7  Princeton University Press          2002
# 8                         NaN          1994

# %% [markdown]
# da qua in giù tutto modificato oggi

# %%
# Rename the 'Title' column in df2 to 'title'
new_dataframe.rename(columns={'Title': 'title'}, inplace=True)
new_dataframe.rename(columns={'PublishedDate': 'date'}, inplace=True)
new_dataframe.rename(columns={'Publisher': 'publisher'}, inplace=True)
# Concatenate the DataFrames vertically
combined_df = pd.concat([bnf, new_dataframe], ignore_index=True)

# Drop duplicates based on 'isbn' column
new_df = combined_df.drop_duplicates(subset='isbn')
new_df = combined_df.drop_duplicates(subset=['title', 'publisher', 'date'], keep='first')
# Reset index of the new DataFrame
new_df.reset_index(drop=True, inplace=True)
new_df.drop(columns=['work', 'uri'], inplace=True)
index_column = new_df.columns.get_loc('Subtitle')

# Move the column to position 2
new_column_order = list(new_df.columns)
new_column_order.insert(1, new_column_order.pop(index_column))
new_df = new_df[new_column_order]

for i, date_value in enumerate(new_df['date']):
    # Convert integer to string before splitting
    date_str = str(date_value)
    # Split the date string by '-'
    date_components = date_str.split('-')[0]
    if '*' in date_components:
        date_components = date_components.replace('*', '')  # Update here
    # Update the 'date' column with the list of components
    new_df.at[i, 'date'] = date_components
    
for i in new_df['Subtitle']:
    if pd.isna(i):
        new_df['Subtitle'].replace({pd.NA: ''}, inplace=True)

# Merge the values of 'title' and 'Subtitle' columns
new_df['title'] = new_df['title'] + '. ' + new_df['Subtitle']
new_df.drop(columns=['Subtitle'], inplace=True)


new_df.to_csv('bibliographic_data_DK.csv', index=False)
new_df
# Out:
# C:\Users\crosi\AppData\Local\Temp\ipykernel_24676\1119876414.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.drop(columns=['work', 'uri'], inplace=True)
#                                                  title  \
# 0                              Le rire de De Kooning.
# 1     A way of living : the art of Willem De Kooning.
# 2    Hartung et les peintres lyriques : Schneider, ...
# 3    Willem de Kooning : drawing seeing-seeing draw...
# 4    Les irascibles : Pollock, De Kooning, Rothko e...
# 5    École de New York : expressionnisme abstrait a...
# 6    Action/abstraction : Pollock, de Kooning, and ...
# 7    Burri : lo spazio di materia - tra Europa e US...
# 8    Willem De Kooning : the late paintings, the 19...
# 9                                  Willem de Kooning.
# 10   American vanguards : Graham, Davis, Gorky, De ...
# 11                                  De Kooning, vite.
# 12                                  De Kooning, vite.
# 13   The impact of Chaim Soutine (1893-1943) : de K...
# 14                      Between sense and De Kooning.
# 15     Willem de Kooning nonstop : cherchez la femme.
# 16   Willem De Kooning : Whitney museum of American...
# 17   Willem de Kooning : Retrospektive, Zeichnungen...
# 18   Willem de Kooning : drawings, paintings, sculp...
# 19   Willem De Kooning : late paintings, [mostra, R...
# 20   L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 21   Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 22        Willem de Kooning : the artist's materials.
# 23   Willem De Kooning : paintings, [exhibition, Na...
# 24   De Kooning paintings : 1960-1980, Kunstmuseum ...
# 25   American masters : the voice and the myth in m...
# 26   De Kooning : a retrospective, [exhibition, Mus...
# 27   A generous vision : the creative life of Elain...
# 28   Abstract expressionist women painters : an ann...
# 29   Willem De Kooning : Nordatlantens ljus, [utstä...
# 30   Willem de Kooning : from the Hirshhorn museum ...
# 31   Willem de Kooning, recent paintings, 1983-1986...
# 32   Deadline : Martin Kippenberger, Absalon, Hans ...
# 33   Pintura al desnudo : Picasso, Dubuffet, De Koo...
# 34     Willem de Kooning : reflections in the studio.
# 35   Et maintenant je veux parler de Willem de Koon...
# 36   De Kooning : petit journal de l'exposition, 28...
# 37   Guerrero, De Kooning : la sabiduría del color,...
# 38   Chaïm Soutine, Willem de Kooning, La peinture ...
# 39   Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 40   Willem De Kooning : de late schilderijen, 1981...
# 41   The New York schools of music and visual arts ...
# 42   Maskierung der Malerei : Jasper Johns nach Wil...
# 43   Willem de Kooning : tracing the figure, [exhib...
# 44   Willem de Kooning : [exposición] Institut vale...
# 45                                 Willem De Kooning.
# 46   L'art contemporain : de l'informel aux recherc...
# 47   Willem De Kooning, 1904-1997 : les contenus, i...
# 48                            De Kooning : 1904-1997.
# 49                                 Willem de Kooning.
# 50                                 Willem de Kooning.
# 51                    Willem de Kooning, een portret.
# 52   Chaïm Soutine, Willem de Kooning, La peinture ...
# 53   Willem De Kooning : works, writings and interv...
# 54                                 Willem de Kooning.
# 55            De Kooning, dipinti, disegni, sculture.
# 56                                        De Kooning.
# 57                   Willem De Kooning. late paintings
# 58                                        De Kooning.
# 59                         De Kooning. A Retrospective
# 60           Willem de Kooning. The Artist's Materials
# 61                                 Willem de Kooning.
# 62                                 Willem de Kooning.
# 63                       Willem de Kooning and Italy.
# 64   Willem de Kooning, 1904-1997. Content as a Gli...
# 65       Willem de Kooning. An Exhibition of Paintings
# 66                        Willem de Kooning. Paintings
# 67                                        De Kooning.
# 68        Willem de Kooning Nonstop. Cherchez la femme
# 69                                 Willem de Kooning.
# 70                      De Kooning. An American Master
# 71                                 Willem de Kooning.
# 72                                        De Kooning.
# 73                                 Willem de Kooning.
# 74               Willem de Kooning. Tracing the Figure
# 75    Willem de Kooning : an Exhibition of Paintings.
# 76                                        De Kooning.
# 77                 Willem de Kooning in East Hampton.
# 78                       Willem De Kooning. A Portrait
# 79   Willem de Kooning, the First Twenty-six Years ...
# 80                               De Kooning, 1969-78.
# 81                      De Kooning; Recent Paintings.
# 82                                        De Kooning.
# 83    Willem de Kooning. The Late Paintings, the 1980s
# 84   Willem de Kooning. An Exhibition Organized Und...
# 85                                 Willem de Kooning.
# 86                           De Kooning - Zao Wou-KI.
# 87      Willem De Kooning. Works, Writings, Interviews
# 88                   The Essential Willem de Kooning.
# 89                      Willem de Kooning, 1941-1959.
# 90                                 Willem De Kooning.
# 91            Willem de Kooning. Drawings & Sculptures
# 92                                 Willem De Kooning.
# 93                                 Willem De Kooning.
# 94   Robert Rauschenberg's »Erased de Kooning Drawi...
# 95              Willem de Kooning. Paintings 1967-1984
# 96        Willem De Kooning. Reflections in the Studio
# 97   Willem de Kooning. The Last Beginning : Exhibi...
# 98   Willem de Kooning. Abstract Landscapes, 1955-1963
# 99   The Sculptures of De Kooning with Related Pain...
# 100           Willem de Kooning. The Life of an Artist
# 101  Willem De Kooning. Mostly Women : Drawings and...
# 102                               De Kooning. Drawings
# 103  Willem de Kooning. From the Hirshhorn Museum C...
# 104        Willem de Kooning. Ten Paintings, 1983-1985
# 105  Willem De Kooning. Vellums : March 21-April 21...
# 106     Willem de Kooning. Recent Paintings, 1983-1986
# 107                                       De Kooning.
# 108                   De Kooning. Sculptures 1972-1974
# 109                                Willem De Kooning.
# 110                                Willem de Kooning.
# 111  Willem de Kooning. Pittsburgh International Se...
# 112  Willem De Kooning, Jean Dubuffet, the Late Wor...
# 113  De Kooning. Drawings, Sculptures : an Exhibiti...
# 114                            De Kooning, 1935-1953.
# 115   Willem de Kooning. Drawing Seeing/seeing Drawing
# 116                 Willem de Kooning. A Way of Living
# 117             Willem de Kooning. Ten Works 1936-1974
# 118                    Willem de Kooning 1981 - 1986.
# 119             Willem de Kooning. Paintings 1975-1978
# 120                   Willem De Kooning (1904-1997)..
# 121                    De Kooning. L'uomo, l'artista.
# 122  Willem De Kooning, Jean Dubuffet. The Women : ...
# 123                                Willem de Kooning.
# 124  Willem de Kooning. Transcending Landscape : Pa...
# 125  Willem de Kooning. Selected Paintings and Scul...
# 126                   Willem De Kooning. Untitled XXI.
# 127  Willem de Kooning. Abstract Landscapes, 1955-1963
# 128                          De Kooning, Lithographs.
# 129                    Get to Know Willem de Kooning.
# 130  De Kooning's Bicycle. Artists and Writers in t...
# 131                     Between Sense and De Kooning.
# 132                                Willem de Kooning.
# 133                       Willem de Kooning Drawings.
# 134                           Better than de Kooning.
# 135                               De Kooning/Shiraga.
# 136                       Willem de Kooning: Vellums.
# 137  Willem de Kooning. Drawings, Paintings, Sculpt...
# 138      The Collected Writings of Willem de Kooning.
# 139            Willem de Kooning Drawings. 1920s-1970s
# 140  Willem De Kooning. Jean Dubuffet. The Late Wor...
# 141               Willem de Kooning. Liquefying Cubism
# 142                           THE DE KOONING AFFAIR..
# 143       Willem de Kooning. The Great American Artist
# 144                                       De Kooning.
# 145                               Wilhelm De Kooning.
# 146          Willem de Kooning, Works from 1951-1981.
# 147                             De Kooning; Drawings.
# 148       Druckgraphische Werk Von Willem de Kooning.
# 149  Chaïm Soutine/Willem de Kooning. La peinture i...
# 150   The American Critics of Pollock and De Kooning.
# 151  De Kooning, January 1968-March 1969. Exhibitio...
# 152  Willem De Kooning, Jean Dubuffet, the Late Wor...
# 153  Willem de Kooning. - New York: Braziller 1959....
# 154  Six Painters: Mondrian, Guston, Kline, De Koon...
# 155                                Willem de Kooning.
# 156                                       De Kooning.
# 157                   De Kooning. Drawings, Sculptures
# 158  Willem de Kooning. Printer's Proofs from the C...
# 159  Drawings by Five Abstract Expressionist Painte...
# 160            Willem De Kooning. The Printer's Proofs
# 161  Willem de Kooning's Women. A Psychoanalytic Ex...
# 162  In Honor of De Kooning. Bacon, Balthus, Baseli...
# 45                            Paris : l'Échoppe , 1994  1994
# 46                             Paris : Gründ , DL 2008  2008
# 47   Köln ; London ; Paris [etc.] : Taschen , cop. ...  2004
# 48                         Paris : Cercle d'art , 1998  1998
# 49              New York : Abbeville press , cop. 1983  1983
# 50                      Lyon : Fage éditions , DL 2022  2022
# 51            Leiden : Menken Kasander & Wigman , 2005  2005
# 52             Paris : "Beaux-arts" éditions , DL 2021  2021
# 53                    Barcelona : Ed. Polígrafa , 2007  2007
# 54                             Paris : Hazan , DL 2006  2007
# 55                                                 NaN  1985
# 56                                                 NaN  1985
# 57                                    Mondadori Electa  2006
# 58                                                 NaN  1972
# 59                            The Museum of Modern Art  2011
# 60                                  Getty Publications  2010
# 61                            The Museum of Modern Art  2011
# 62                  Rizzoli International Publications  1994
# 63                                    Marsilio Editori  2024
# 64                                             Taschen  2004
# 65                                                 NaN  1990
# 66                               Yale University Press  1994
# 67                          New York : Abbeville Press  1983
# 68                         University of Chicago Press  2016
# 69                                                 NaN  1965
# 70                                               Knopf  2004
# 71                                                 NaN  1999
# 72                                                 NaN  2007
# 73                                                 NaN  2003
# 74                          Princeton University Press  2002
# 75                                                 NaN  1990
# 76                                                 NaN  1975
# 77                                   Guggenheim Museum  1978
# 78         Createspace Independent Publishing Platform  2016
# 79                                     Dissertations-G  1986
# 80      University of Northern Iowa, Department of Art  1978
# 81                                                 NaN  1968
# 82                                                 NaN  2017
# 83                                   Walker Art Center  1995
# 84                                                 NaN  1968
# 85                                                 NaN  1997
# 86                              Dominique Levy Gallery  2017
# 87                            Ediciones Polígrafa S.A.  2007
# 88                                         Cader Books  1999
# 89                                                 NaN  1974
# 90                                                 NaN  1994
# 91                                                 NaN  1974
# 92                                                 NaN  1962
# 93                                Hassell Street Press  2021
# 94                                  Hatje Cantz Verlag  2023
# 95                                                 NaN  2002
# 96                                                 NaN  2000
# 97                                                 NaN  2007
# 98                                                 NaN  2004
# 99                                                 NaN  1977
# 100                                  Enslow Publishing  2002
# 101                                                NaN  2000
# 102                                                NaN  1967
# 103                 Rizzoli International Publications  1993
# 104                               Rizzoli Publications  2014
# 105                                                NaN  2001
# 106                            Anthony D'Offay Gallery  1986
# 107                                                NaN  1969
# 108                                                NaN  2015
# 109                                                NaN  1994
# 110                                                NaN  1978
# 111                                                NaN  1979
# 112                              Australian Geographic  1993
# 113                                       Dutton Adult  1974
# 114                                                NaN  1953
# 115                                                NaN  1998
# 116                                      Phaidon Press  2017
# 117                                                NaN  2005
# 118                                                NaN  2007
# 119                                                NaN  2006
# 120                                                NaN  1997
# 121                               Johan & Levi Editore  2006
# 122                              Australian Geographic  1990
# 123                                                NaN  1973
# 124                                                NaN  1993
# 125                                                NaN  2000
# 126                                                NaN  2022
# 127                                                NaN  1987
# 128                                                NaN  1985
# 129                                                NaN  2016
# 130                          Farrar, Straus and Giroux  2005
# 131                                                NaN  2011
# 132                                                NaN  1984
# 133                                                NaN  2021
# 134                                             Snoeck  2015
# 135                                                NaN  2022
# 136                                                NaN  2001
# 137                                                NaN  1983
# 138                                                NaN  1988
# 139                                                NaN  2007
# 140                                                NaN  1993
# 141                                                NaN  1994
# 142                                                NaN   nan
# 143                                                NaN  2011
# 144                                                NaN  1960
# 145                 Rizzoli International Publications  1994
# 146                                                NaN  1981
# 147                                                NaN  1968
# 148                                                NaN  1991
# 149                                                NaN  2021
# 150                                                NaN  1962
# 151                                                NaN  1969
# 152                                                NaN  1993
# 153                                                NaN  1959
# 154                                                NaN  1968
# 155                                                NaN  1959
# 156                                                NaN  1963
# 157                                                NaN  1974
# 158                                                NaN  1991
# 159                                                NaN  1976
# 160                               Salander Oreilly Pub  1991
# 161                                                NaN  2022
# 162                                                NaN  1984
# 163                                       HarperAvenue  2016
# 164                                                NaN  1990
# 165                                                NaN  1984
# 166                                                NaN  1990
# 167                                                NaN  2006
# 168                                                NaN  2009
# 169                                                NaN  1963
# 170                                                NaN  1987
# 171                                                NaN  2001
# 172                                                NaN  1996
# 173                          Encyclopaedia Universalis  2015
# 174                                                NaN  2003
#
#                         isbn  \
# 0              9782955755068
# 1                 0714845817
# 2              9791096209002
# 3                 0965728080
# 4              9782749176703
# 5                 2913548695
# 6              9780300122152
# 7                 8894063984
# 8                 0935640479
# 9                 2732425079
# 10                0300121679
# 11                2729102701
# 12             9782729117054
# 13                3775791035
# 14             9781861898531
# 15                022626744X
# 16                2858502552
# 17                3791306596
# 18                0393018407
# 19                8837049404
# 20                2876880148
# 21                1944379126
# 22                160606021X
# 23                0894682040
# 24                3775716297
# 25                0525480005
# 26             9780500093634
# 27                0190498471
# 28                0810829983
# 29                9171002367
# 30                0847817695
# 31                094756408X
# 32             9782759601080
# 33                8487184596
# 34                0810945606
# 35                2840680688
# 36                285850234X
# 37                8478072942
# 38             9782354333331
# 39                3777455210
# 40                9069181673
# 41                0415936942
# 42                3770546679
# 43                069109618X
# 44                8448228626
# 45                2840680297
# 46             9782700024203
# 47                3822821349
# 48                2702205006
# 49                1558592482
# 50             9782849756874
# 51                9074622534
# 52             9791020406392
# 53             9788434311381
# 54             9782754101769
# 55        UOM:39015015825683
# 56             OCLC:12250843
# 57        UOM:39015066851935
# 58        UOM:39015045652768
# 59             9780870707971
# 60             9781606060216
# 61             9780870707889
# 62   STANFORD:36105016413267
# 63             9791254631690
# 64                3822821357
# 65   STANFORD:36105001689053
# 66                0300060114
# 67        UOM:39015016616644
# 68             9780226267586
# 69        UOM:39015041624720
# 70        UOM:39015058741425
# 71            OCLC:922655841
# 72                3822835455
# 73            OCLC:228439249
# 74                069109618X
# 75           OCLC:1334620202
# 76            OCLC:963159077
# 77        UOM:39015012225143
# 78                1532883374
# 79        UOM:39015015825857
# 80             UCAL:B3908958
# 81             UCAL:B3287209
# 82                383654962X
# 83       UCSD:31822021615752
# 84              OCLC:1284557
# 85                8434308347
# 86                1944379126
# 87        UOM:39015074249122
# 88          PSU:000053458285
# 89              OCLC:2055976
# 90                0933793316
# 91             OCLC:78840227
# 92            OCLC:217267406
# 93                101440813X
# 94             9783775755030
# 95   STANFORD:36105023689982
# 96        UOM:39015050036196
# 97                1932598510
# 98       UCSD:31822035267962
# 99                0728701421
# 100               0766018849
# 101      UCSD:31822036217131
# 102           UVA:X030810127
# 103       UOM:39015026855877
# 104            9780847843916
# 105       UOM:39015055199601
# 106               094756408X
# 107           OCLC:950182543
# 108               0988930099
# 109               2840680297
# 110          OCLC:1005883038
# 111       UOM:39015020382548
# 112  STANFORD:36105009567517
# 113       UOM:39015006749876
# 114            OCLC:80699819
# 115       UOM:39015047491660
# 116               0714873160
# 117      UCSD:31822034288597
# 118               0979094216
# 119               0974424978
# 120               0908298625
# 121               8860100224
# 122       UOM:39015021859486
# 123           OCLC:935599869
# 124  STANFORD:36105012423104
# 125            OCLC:46452963
# 126          OCLC:1317842581
# 127            OCLC:23006550
# 128           OCLC:173516539
# 129               0766072428
# 130            9781429921695
# 131               1861898533
# 132           OCLC:501278385
# 133               1944929290
# 134               3864421373
# 135               173410595X
# 136           OCLC:316861140
# 137               0393018407
# 138               0937815136
# 139               1932608176
# 140          OCLC:1419335561
# 141               1932608036
# 142           OCLC:263511675
# 143               1258170477
# 144       UOM:39015027877201
# 145               084785759X
# 146  STANFORD:36105031900587
# 147       UOM:39015007566907
# 148       UOM:39015032446455
# 149               2354333331
# 150       UFL:31262046285739
# 151            UCAL:B4116838
# 152           OCLC:741479429
# 153           UVA:X001533734
# 154       UOM:39015010991100
# 155       UOM:39015015683421
# 156      UCSC:32106016797521
# 157          OCLC:1087464322
# 158  STANFORD:36105028780083
# 159       UOM:39015041096390
# 160               1588210332
# 161               1956864199
# 162            OCLC:14821230
# 163               1443435775
# 164            OCLC:47715266
# 165               2858502552
# 166          OCLC:1419315490
# 167               1599160560
# 168           OCLC:747408553
# 169          OCLC:1423041809
# 170               0909873496
# 171      UCSD:31822030290308
# 172               9069181681
# 173            9782852296558
# 174               3793093239
#
#                                                Authors
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# 30                                                 NaN
# 31                                                 NaN
# 32                                                 NaN
# 33                                                 NaN
# 34                                                 NaN
# 35                                                 NaN
# 36                                                 NaN
# 37                                                 NaN
# 38                                                 NaN
# 39                                                 NaN
# 40                                                 NaN
# 41                                                 NaN
# 42                                                 NaN
# 43                                                 NaN
# 44                                                 NaN
# 45                                                 NaN
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 52                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                   Willem De Kooning
# 56                                                 NaN
# 57              Willem De Kooning, Museo Carlo Bilotti
# 58                  Willem De Kooning, Gabriella Drudi
# 59   Willem De Kooning, John Elderfield, Lauren Mah...
# 60                                          Susan Lake
# 61                                    Carolyn Lanchner
# 62                                     David Cateforis
# 63                                                 NaN
# 64                     Barbara Hess, Willem De Kooning
# 65   Willem De Kooning, Klaus Kertess, Robert Rosen...
# 66   Marla Prather, David Sylvester, Richard Shiff,...
# 67                   Harry F. Gaugh, Willem De Kooning
# 68                                  Rosalind E. Krauss
# 69   Willem De Kooning, Dore Ashton, Smith College....
# 70                          Mark Stevens, Annalyn Swan
# 71                                                 NaN
# 72                                        Barbara Hess
# 73                                                 NaN
# 74   Willem De Kooning, Cornelia H. Butler, Paul Sc...
# 75                                   Willem De Kooning
# 76                                                 NaN
# 77                    Willem De Kooning, Diane Waldman
# 78                                     Bert Schierbeek
# 79                                          Sally Yard
# 80   Willem De Kooning, Jack Cowart, Sanford Sivitz...
# 81   Willem De Kooning, Thomas B. Hess, M. Knoedler...
# 82                     Barbara Hess, Willem De Kooning
# 83   Willem De Kooning, Gary Garrels, Robert Storr,...
# 84                   Thomas B. Hess, Willem De Kooning
# 85                       Sally Yard, Willem De Kooning
# 86                                                 NaN
# 87                                          Sally Yard
# 88                                    Catherine Morris
# 89                                   Willem De Kooning
# 90                                       Klaus Kertess
# 91                Willem De Kooning, Walker Art Center
# 92              Allan Stone Gallery, Willem De Kooning
# 93                                    Thomas B Cn Hess
# 94                                    Gregor Stemmrich
# 95                                   Willem De Kooning
# 96                    Edvard Lieber, Willem De Kooning
# 97                                   Willem De Kooning
# 98                 Willem De Kooning, Gagosian Gallery
# 99                                   Willem De Kooning
# 100                                       Louise Hawes
# 101                                  Willem De Kooning
# 102                                  Willem De Kooning
# 103  Judith Zilczer, Hirshhorn Museum and Sculpture...
# 104                                                NaN
# 105               Willem De Kooning, Brenda Richardson
# 106                                  Willem De Kooning
# 107                                                NaN
# 108                                                NaN
# 109                                        Edwin Denby
# 110                                   Harold Resenberg
# 111  Willem De Kooning, Carnegie Institute. Museum ...
# 112  Willem De Kooning, Peter Schjeldahl, Pace Gallery
# 113  Willem De Kooning, Philip Larson, Peter Schjel...
# 114                                  Willem De Kooning
# 115  Willem De Kooning, Klaus Kertess, Drawing Cent...
# 116                                     Judith Zilczer
# 117                                  Willem De Kooning
# 118                                                NaN
# 119                      Willem De Kooning, L & M Arts
# 120                                                NaN
# 121                         Mark Stevens, Annalyn Swan
# 122  Willem De Kooning, Jean Dubuffet, Mildred Glim...
# 123                                                NaN
# 124                                  Willem De Kooning
# 125            Willem De Kooning, Robert Pincus-Witten
# 126                                                NaN
# 127                Willem De Kooning, Henry Geldzahler
# 128                                  Willem De Kooning
# 129                                   Charlotte Taylor
# 130                                        Robert Long
# 131                   Richard Shiff, Willem De Kooning
# 132  Robert Rosenblum, Whitney Museum of American A...
# 133                                   Peter Schjeldahl
# 134                         Andreas Baur, Marcus Weber
# 135                      Pepe Karmel, Fergus McCaffrey
# 136  Willem De Kooning, Brenda Richardson, Mitchell...
# 137                   Paul Cummings, Willem De Kooning
# 138                                  Willem De Kooning
# 139             Willem De Kooning, Allan Stone Gallery
# 140                                                NaN
# 141                                        Allan Stone
# 142                                  Willem De Kooning
# 143                                     Thomas B. Hess
# 144                 Harriet Grossman Janis, Rudi Blesh
# 145                                          Cateforis
# 146      Judith Lynn Wolfe, Guild Hall of East Hampton
# 147                                  Willem De Kooning
# 148                F. Lanier Graham, Willem De Kooning
# 149                                                NaN
# 150                             Charles Frank Thompson
# 151                   M. Knoedler & Co, Thomas B. Hess
# 152                                                NaN
# 153                                     Thomas B. Hess
# 154  University of St. Thomas (Houston, Tex.). Art ...
# 155                                     Thomas B. Hess
# 156                                     Morton Feldman
# 157                    Philip Larson, Peter Schjeldahl
# 158                Willem De Kooning, F. Lanier Graham
# 159         Museum of Contemporary Art (Chicago, Ill.)
# 160                                                NaN
# 161                                   Graeme J. Taylor
# 162                                                NaN
# 163                                   Kerry Lee Powell
# 164                                      Pablo Picasso
# 165  Claire Stoullig, Catherine Bompuis, Akademie d...
# 166                                   Mildred Glimcher
# 167                                       Roger Connah
# 168                                       Roger Connah
# 169                                     Morton Feldman
# 170                                                NaN
# 171  Bernice Rose, Willem De Kooning, PaceWildenste...
# 172                                                NaN
# 173                         Encyclopaedia Universalis,
# 174                                      Tobias Lander

# %% [markdown]
# Check how many bibliographic records are actually exhibition catalogues.

# %%
import pandas as pd

total_rows = len(new_df)

# Count rows where 'title', 'subtitle', or 'description' contain specified keywords
keyword_rows = new_df[new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue|catalogo|exposition|retrospective|Ausstellung', case=False, na=False) ]

# Get the count of rows containing the specified keywords
keyword_rows_count = len(keyword_rows)

print("Total rows in DataFrame:", total_rows)
print("Rows containing specified keywords:", keyword_rows_count)
# Out:
# Total rows in DataFrame: 175
# Rows containing specified keywords: 30

# %%
# Create a mask for rows containing specified keywords in 'title', 'subtitle', or 'description' columns
mask = new_df['title'].str.contains(r'exhibition|exhib\.|mostra|catalogue |catalogo|exposition|retrospective|Ausstellung', case=False, na=False) 

# Create the exhibitions DataFrame containing rows where keywords are present
exhibitions_dataframe = new_df[mask]

# Remove the rows where keywords are present from the original DataFrame
dfbooks = new_df[~mask]

# Reset index of the original DataFrame
dfbooks.reset_index(drop=True, inplace=True)

# Reset index of the exhibitions DataFrame
exhibitions_dataframe.reset_index(drop=True, inplace=True)

print("\nExhibitions DataFrame:")
exhibitions_dataframe
# Out:
# Exhibitions DataFrame:
#                                                 title  \
# 0   Hartung et les peintres lyriques : Schneider, ...
# 1   Willem de Kooning : drawing seeing-seeing draw...
# 2   École de New York : expressionnisme abstrait a...
# 3   Action/abstraction : Pollock, de Kooning, and ...
# 4   Burri : lo spazio di materia - tra Europa e US...
# 5   Willem De Kooning : the late paintings, the 19...
# 6   American vanguards : Graham, Davis, Gorky, De ...
# 7   The impact of Chaim Soutine (1893-1943) : de K...
# 8   Willem de Kooning : Retrospektive, Zeichnungen...
# 9   Willem de Kooning : drawings, paintings, sculp...
# 10  Willem De Kooning : late paintings, [mostra, R...
# 11  L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 12  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 13  Willem De Kooning : paintings, [exhibition, Na...
# 14  De Kooning : a retrospective, [exhibition, Mus...
# 15  Willem de Kooning, recent paintings, 1983-1986...
# 16  Deadline : Martin Kippenberger, Absalon, Hans ...
# 17  De Kooning : petit journal de l'exposition, 28...
# 18  Chaïm Soutine, Willem de Kooning, La peinture ...
# 19  Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 20  Willem de Kooning : tracing the figure, [exhib...
# 21                        De Kooning. A Retrospective
# 22      Willem de Kooning. An Exhibition of Paintings
# %%
import pandas as pd
import spacy
import numpy as np

nlp = spacy.load("en_core_web_sm")


# Process Text and Extract Location Names
def extract_location(text):
    doc = nlp(text)
    locations = [entity.text for entity in doc.ents if entity.label_ == 'GPE']
    return locations

# Apply the extract_location function to the 'title' and 'Subtitle' columns and store the result in a new column 'locations'
exhibitions_dataframe['Exhibit locations'] = exhibitions_dataframe.apply(lambda row: extract_location(row['title']), axis=1)

# Convert the list of extracted locations into a comma-separated string
exhibitions_dataframe['Exhibit locations'] = exhibitions_dataframe['Exhibit locations'].apply(lambda x: ', '.join(x))

exhibitions_dataframe.to_csv('exhibitions_data_DK.csv', index=False)
exhibitions_dataframe
# Out:
# C:\Users\crosi\AppData\Local\Temp\ipykernel_24676\1060364620.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exhibitions_dataframe['Exhibit locations'] = exhibitions_dataframe.apply(lambda row: extract_location(row['title']), axis=1)
# C:\Users\crosi\AppData\Local\Temp\ipykernel_24676\1060364620.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exhibitions_dataframe['Exhibit locations'] = exhibitions_dataframe['Exhibit locations'].apply(lambda x: ', '.join(x))
#                                                 title  \
# 0   Hartung et les peintres lyriques : Schneider, ...
# 1   Willem de Kooning : drawing seeing-seeing draw...
# 2   École de New York : expressionnisme abstrait a...
# 3   Action/abstraction : Pollock, de Kooning, and ...
# 4   Burri : lo spazio di materia - tra Europa e US...
# 5   Willem De Kooning : the late paintings, the 19...
# 6   American vanguards : Graham, Davis, Gorky, De ...
# 7   The impact of Chaim Soutine (1893-1943) : de K...
# 8   Willem de Kooning : Retrospektive, Zeichnungen...
# 9   Willem de Kooning : drawings, paintings, sculp...
# 10  Willem De Kooning : late paintings, [mostra, R...
# 11  L'oeuvre gravé de Willem De Kooning 1 : catalo...
# 12  Willem De Kooning, Zao Wou-Ki : [exposition Lé...
# 13  Willem De Kooning : paintings, [exhibition, Na...
# 14  De Kooning : a retrospective, [exhibition, Mus...
# 15  Willem de Kooning, recent paintings, 1983-1986...
# 16  Deadline : Martin Kippenberger, Absalon, Hans ...
# 17  De Kooning : petit journal de l'exposition, 28...
# 18  Chaïm Soutine, Willem de Kooning, La peinture ...
# 19  Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 20  Willem de Kooning : tracing the figure, [exhib...
# 21                        De Kooning. A Retrospective
# 22      Willem de Kooning. An Exhibition of Paintings
# 23   Willem de Kooning : an Exhibition of Paintings.
# 24  Willem de Kooning. An Exhibition Organized Und...
# 25  Willem de Kooning. The Last Beginning : Exhibi...
# 26  De Kooning. Drawings, Sculptures : an Exhibiti...
# 27  Willem de Kooning. Drawings, Paintings, Sculpt...
# 28  De Kooning, January 1968-March 1969. Exhibitio...
# 29  Drawings by Five Abstract Expressionist Painte...
#
#                                             publisher  date  \
# 0   Landerneau : Fonds Hélène & Édouard Leclerc po...  2016
# 1                             New York : Arena , 1998  1998
# 2                   [Nice] : Nice musées , impr. 2005  2005
# 3            New York : the Jewish museum , cop. 2008  2008
# 4   Città di Castello : Fondazione Palazzo Albizzi...  2016
# 5   San Francisco : San Francisco museum of modern...  1995
# 6   Andover (Mass.) : Addison gallery of American ...  2011
# 7           Ostfildern-Ruit : Hatje Cantz , cop. 2002  2002
# 8                       München : Prestel , cop. 1984  1984
# 9   New York : Whitney museum of American art ; Mu...  1983
# 10                        Milano : Electa , cop. 2006  2006
# 11                            Paris : B. Lebon , 1991  1991
# 12                              New York : Lévy Gorvy  2017
# 13  Washington : National gallery of art ; New Hav...  1994
# 14             New York : Museum of modern art , 2011  2011
# 15            London : Anthony d'Offay gallery , 1986  1986
# 16  Paris : Musée d'art moderne de la Ville de Par...  2009
# 17             Paris : Centre Georges Pompidou , 1984  1984
# 18            Paris : Musée d'Orsay : Hazan , DL 2021  2021
# 19                      München : Hirmer , cop. 2012  2012
# 20  Los Angeles : Museum of contemporary art ; Pri...  2002
# 21                           The Museum of Modern Art  2011
# 22                                                NaN  1990
# 23                                                NaN  1990
# 24                                                NaN  1968
# 25                                                NaN  2007
# 26                                       Dutton Adult  1974
# 27                                                NaN  1983
# 28                                                NaN  1969
# 29                                                NaN  1976
#
#                        isbn  \
# 0             9791096209002
# 1                0965728080
# 2                2913548695
# 3             9780300122152
# 4                8894063984
# 5                0935640479
# 6                0300121679
# 7                3775791035
# 8                3791306596
# 9                0393018407
# 10               8837049404
# 11               2876880148
# 12               1944379126
# 13               0894682040
# 14            9780500093634
# 15               094756408X
# 16            9782759601080
# 17               285850234X
# 18            9782354333331
# 19               3777455210
# 20               069109618X
# 21            9780870707971
# 22  STANFORD:36105001689053
# 23          OCLC:1334620202
# 24             OCLC:1284557
# 25               1932598510
# 26       UOM:39015006749876
# 27               0393018407
# 28            UCAL:B4116838
# 29       UOM:39015041096390
#
#                                               Authors  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  Willem De Kooning, John Elderfield, Lauren Mah...
# 22  Willem De Kooning, Klaus Kertess, Robert Rosen...
# 23                                  Willem De Kooning
# 24                  Thomas B. Hess, Willem De Kooning
# 25                                  Willem De Kooning
# 26  Willem De Kooning, Philip Larson, Peter Schjel...
# 27                   Paul Cummings, Willem De Kooning
# 28                   M. Knoedler & Co, Thomas B. Hess
# 29         Museum of Contemporary Art (Chicago, Ill.)
#
#                                     Exhibit locations
# 0   Gottlieb, De Kooning, Degottex, Mathieu, Polke...
# 1            New York, Andover, Mass., Ohio, Columbus
# 2                                                Nice
# 3                New York, Saint Louis, Buffalo, N.Y.
# 4   Afro, Andre, Arman, Beuys, Capograssi, Castell...
# 5                San Francisco, Minneapolis, New York
# 6              N.Y., Fort Worth, Tex., Andover, Mass.
# 7                                             Cologne
# 8                Ausstellung, New York, Berlin, Paris
# 9                   New York, Berlin, Paris, New York
# 10                                               Roma
# 11
# 12                                           New York
# 13         Washington, Metropolitan, New York, London
# 14                                           New York
# 15                                             London
# 16
# 17                                     juin-24, Paris
# 18                                              Paris
# 19                    New York, Ausstellung, New York
# 20  Los Angeles, San Francisco, San Francisco, Was...
# 21
# 22
# 23
# 24
# 25
# 26                                        Minneapolis
# 27                                           New York
# 28                                               Inc.
# 29
