# %%
import pandas as pd

df = pd.read_csv('bibliographic_data_DK.csv')


filtered_df = df[df['date'].notnull() & df['date'].astype(str).str.strip().str.replace('*', '').str.replace('-', '').str.isnumeric()]

# Filter out rows with invalid 'date' values (including '*')
filtered_df['date'] = filtered_df['date'].str.replace('*', '')

# Convert 'date' column to integer type
filtered_df['date'] = filtered_df['date'].astype(int)

# Filter rows based on the date column
filtered_df = filtered_df[filtered_df['date'].between(2008, 2014)]
filtered_df.reset_index(drop=True, inplace=True)

filtered_df
# Out:
# C:\Users\crosi\AppData\Local\Temp\ipykernel_7180\1916491569.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['date'] = filtered_df['date'].str.replace('*', '')
# C:\Users\crosi\AppData\Local\Temp\ipykernel_7180\1916491569.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['date'] = filtered_df['date'].astype(int)
#                                                 title  \
# 0      A way of living : the art of Willem De Kooning
# 1   Action/abstraction : Pollock, de Kooning, and ...
# 2   American vanguards : Graham, Davis, Gorky, De ...
# 3                        Between sense and De Kooning
# 4          Willem de Kooning : the artist's materials
# 5   De Kooning : a retrospective, [exhibition, Mus...
# 6   Deadline : Martin Kippenberger, Absalon, Hans ...
# 7   Von Dürer bis de Kooning : 100 Meisterzeichnu...
# 8   Maskierung der Malerei : Jasper Johns nach Wil...
# 9   L'art contemporain : de l'informel aux recherc...
# 10                                         De Kooning
# 11                                  Willem de Kooning
# 12                                  Willem de Kooning
# 13                                  Willem de Kooning
# 14                                  Willem de Kooning
# 15                       Between Sense and De Kooning
# 16                    A House for de Kooning's Friend
#
#                      Subtitle  \
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8                         NaN
# 9                         NaN
# 10            A Retrospective
# 11                        NaN
# 12     The Artist's Materials
# 13  The Great American Artist
# 14   Ten Paintings, 1983-1985
# 15                        NaN
# 16                        NaN
#
#                                             publisher  date            isbn  \
# 0               London : Phaidon Press Limited , 2017  2014      0714845817
# 1            New York : the Jewish museum , cop. 2008  2008   9780300122152
# 2   Andover (Mass.) : Addison gallery of American ...  2011      0300121679
# 3                 London : Reaktion books , cop. 2011  2011   9781861898531
# 4   Los Angeles : Getty conservation institute , c...  2010      160606021X
# 5              New York : Museum of modern art , 2011  2011   9780500093634
# 6   Paris : Musée d'art moderne de la Ville de Par...  2009   9782759601080
# 7                       München : Hirmer , cop. 2012  2012      3777455210
# 8                      München : W. Fink , cop. 2008  2008      3770546679
# 9                             Paris : Gründ , DL 2008  2008   9782700024203
# 10                           The Museum of Modern Art  2011   9780870707971
# 11                           The Museum of Modern Art  2011   9780870707889
# 12                                 Getty Publications  2010   9781606060216
# 13                                                NaN  2011      1258170477
# 14                               Rizzoli Publications  2014   9780847843916
# 15                                                NaN  2011      1861898533
# 16                                                NaN  2009  OCLC:747408553
#
#                                               Authors
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  Willem De Kooning, John Elderfield, Lauren Mah...
# 11                                   Carolyn Lanchner
# 12                                         Susan Lake
# 13                                     Thomas B. Hess
# 14                                                NaN
# 15                   Richard Shiff, Willem De Kooning
# 16                                       Roger Connah

# %%
import pandas as pd

df = pd.read_csv('exhibitions_data_DK.csv')


filtered_df = df[df['date'].notnull() & df['date'].astype(str).str.strip().str.replace('*', '').str.replace('-', '').str.isnumeric()]

# Convert 'date' column to integer type
filtered_df['date'] = filtered_df['date'].astype(int)

# Filter rows based on the date column
filtered_df = filtered_df[filtered_df['date'].between(2008, 2014)]
filtered_df.reset_index(drop=True, inplace=True)

filtered_df
# Out:
#                                                title         Subtitle  \
# 0  Action/abstraction : Pollock, de Kooning, and ...              NaN
# 1  American vanguards : Graham, Davis, Gorky, De ...              NaN
# 2  De Kooning : a retrospective, [exhibition, Mus...              NaN
# 3  Deadline : Martin Kippenberger, Absalon, Hans ...              NaN
# 4  Von Dürer bis de Kooning : 100 Meisterzeichnu...              NaN
# 5                                         De Kooning  A Retrospective
#
#                                            publisher  date           isbn  \
# 0           New York : the Jewish museum , cop. 2008  2008  9780300122152
# 1  Andover (Mass.) : Addison gallery of American ...  2011     0300121679
# 2             New York : Museum of modern art , 2011  2011  9780500093634
# 3  Paris : Musée d'art moderne de la Ville de Par...  2009  9782759601080
# 4                      München : Hirmer , cop. 2012  2012     3777455210
# 5                           The Museum of Modern Art  2011  9780870707971
#
#                                              Authors  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5  Willem De Kooning, John Elderfield, Lauren Mah...
#
#                         Exhibit locations
# 0    New York, Saint Louis, Buffalo, N.Y.
# 1  N.Y., Fort Worth, Tex., Andover, Mass.
# 2                                New York
# 3                                     NaN
# 4         New York, Ausstellung, New York
# 5                                     NaN
