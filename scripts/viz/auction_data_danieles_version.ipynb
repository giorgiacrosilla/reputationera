# %% [markdown]
# ### Auctions data
#
# The auction dataset has been taken from this <a href="https://github.com/jasonshi10/art_auction_valuation">repository</a> which has taken data webscraping the old website of Blouin Art Sales index. During 2014 that website made available a lot of auction data for free <a href="https://web.archive.org/web/20141018210450/http://artsalesindex.artinfo.com/asi/search/artistLanding.ai">(see here)</a>, now data is available only under subscription as other websites like Artsy.

# %%
import pandas as pd
pd.set_option('display.max_columns', None)
getty2 = pd.read_csv("auctions.csv", sep=";", encoding="iso-8859-1")

getty2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
#       2 pd.set_option('display.max_columns', None)
# ----> 3 getty2 = pd.read_csv("auctions.csv", sep=";", encoding="iso-8859-1")
#       5 getty2
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\parsers\readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File c:\Users\danie\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\io\common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'auctions.csv'

# %%
from collections import Counter
liss = {}
for column_name in getty2.columns:
    if column_name == "artist":
        for value in getty2[column_name]:
            if value not in liss:
                liss[value] = 1
            else:
                liss[value] += 1
k = Counter(liss)

# sobstitute nan with "nan"
x = list(liss.keys())

for i in x:
    if type(i) != str:
      liss['nan'] = liss[i]  
      liss.pop(i)

 
# Finding 3 highest values
high = k.most_common(4) 
 
print("Initial Dictionary:")
print(liss, "\n")
 
 
print("Dictionary with 3 highest values:")
print("Keys: Values")
 
for i in high:
    print(i[0]," :",i[1]," ")
# Out:
# Initial Dictionary:
# {'Mario A': 2, 'A E Cremer': 1, 'A G Schultz & Co.': 2, 'A H': 1, 'A H G': 1, 'A K': 1, 'A Kassen': 1, 'A Lao': 4, 'A M': 1, 'A Sun Wu': 4, "Maria A'Becket": 4, "A'erbai": 1, 'A-One': 2, 'A.CE': 1, 'A1one': 6, 'Dirk van der Aa': 6, 'Jorgen Aabye': 5, 'Christian Aabye-Talge': 1, 'Attributed to  Hans von Aachen': 2, 'Circle of  Hans von Aachen': 2, 'Studio of  Hans von Aachen': 1, 'After  Hans von Aachen': 1, 'Hans von Aachen': 1, 'Peder Pedersen Aadnes': 1, 'Arvid Aae': 2, 'Carl Frederic Aagaard': 4, 'Martin Aagaard': 2, 'H P Aaland': 1, 'Alvar Aalto': 11, 'Ilmari Aalto': 4, 'Veikko Aaltona': 5, 'Aarre Aaltonen': 2, 'Waino Aaltonen': 7, 'Martin Aalund': 3, 'Asbjorn Aamodt': 2, 'Susanne Aamund': 1, 'Jos Aanraad': 3, 'Leny Aardse': 1, 'Eero Aarnio': 7, 'Jessie Aaron': 9, 'John Aaron': 1, 'Joseph Aaron': 5, 'Michel Aaron': 1, 'George Aarons': 4, 'Slim Aarons': 2, 'Carl Aarsleff': 2, 'Hans Aarsman': 1, 'Nicolaas Aartmann': 4, 'Pieter Jan Aarts': 1, 'Alf Jorgen Aas': 1, 'Nils Aas': 3, 'Walther Aas': 2, 'Astri Aasen': 1, 'Lennart Aasling': 2, 'Ab the Flagman': 10, 'Vilmos Aba-Novak': 4, 'Attributed to  Vilmos Aba-Novak': 2, 'T Abacchi': 1, 'Pacita Abad': 7, 'Francisco Abad Doblas': 1, 'Jorge Abade': 1, 'Juan Martinez Abades': 3, 'Juan de la Abadia the Elder': 2, 'Jean Abadie': 6, 'Pierre Abadie-Landel': 4, 'Stanko Abadzic': 1, 'Magdalena Abakanowicz': 2, 'Tomas Abal': 1, 'Fernando Abalo': 1, 'Eduardo Abaroa': 2, 'Franz Abart': 2, 'Felipe Abarzuza y Rodriguez Arias': 1, 'Abascal': 5, 'Carlos Abascal': 2, 'Felipe Barantes Abascal': 1, 'Chingiz Abassov': 1, 'Alberto Abate': 6, 'Claudio Abate': 1, 'Gianantonio Abate': 3, 'Goffredo de Abate': 3, 'Serge Abate': 1, 'Teonesto de Abate': 5, 'Pierre Abattuci': 9, 'Nadim Abbas': 1, 'Norma Abbas': 1, "Sa'adi Abbas": 1, 'Salman Abbas': 1, 'After  Riza-i Abbasi': 1, 'School of  Riza-i Abbasi': 1, 'Follower of  Riza-i Abbasi': 1, 'Attributed to  Riza-i Abbasi': 2, 'Style of  Riza-i Abbasi': 1, 'School of  Shaykh Abbasi': 1, 'Shaykh Abbasi': 3, 'Attributed to  Shaykh Abbasi': 1, 'Samira Abbassy': 1, 'Adalberto Abbate': 1, "Niccolo dell' Abbate": 4, 'Alberto Abbati': 3, 'Attributed to  Giuseppe Abbati': 1, 'Giuseppe Abbati': 3, 'Attributed to  Vincenzo Abbati': 1, 'Vincenzo Abbati': 1, 'Agnes Dean Abbatt': 1, 'Albert Abbe': 4, 'Dennis Abbe': 1, 'Salomon van Abbe': 3, 'Jan van den Abbeele': 1, 'Roger vanden Abbeele': 2, 'Louise Abbema': 3, 'Robert Kennedy Abbett': 7, 'Alfred Abbey': 1, 'Edwin Austin Abbey': 5, 'Julius Abbiati': 3, 'Stefano Abbiati': 4, 'Jussuf Abbo': 5, 'Agnes Anne Abbot': 6, 'John Abbot': 1, 'Anne Abbott': 2, 'Arthur Abbott': 2, 'Berenice Abbott': 7, 'C Abbott': 1, 'Douglas Abbott': 2, 'Elenore Plaisted Abbott': 1, 'John T Abbott': 1, 'John White Abbott': 4, 'Lemuel Francis Abbott': 5, 'After  Lemuel Francis Abbott': 1, 'Mary Abbott': 5, 'Mary Odgen Abbott': 1, 'Meredith Brooks Abbott': 10, 'Attributed to  Samuel Nelson Abbott': 1, 'Susan Abbott': 4, 'William Abbott': 1, 'Yarnell Abbott': 3, 'Horace Abbott Hobson': 2, 'Chafik Abboud': 7, 'Jumana Emil Abboud': 1, 'Joe Abbrescia': 6, 'Abd Al-Jabar': 1, 'Hamed Abdallah': 2, 'Abdel-Kerim': 1, 'Mahmoud Abdel-Mawgood': 1, 'Youssef Abdelke': 4, 'Doug Abdell': 5, 'Adel Abdessemed': 9, 'Prince  Abdul-Medijd': 2, 'Naguib Elias Abdula': 1, 'Ian Abdulla': 5, 'Abdullah': 1, 'Nizam Abdullah': 1, 'Raden Basoeki Abdullah': 10, 'Ramlan Abdullah': 2, 'S Abdullah': 1, 'Sudjono Abdullah': 8, 'Suriosubroto Abdullah': 4, 'Abdullah Freres': 1, 'Aman Abdurachman': 1, 'Rowena Meeks Abdy': 5, 'Mizuki Abe': 1, 'Satoru Abe': 6, 'Pinson Abeauvain': 1, 'Raphael Abecassis': 2, 'Zainul Abedin': 9, 'Albijn van den Abeele': 2, 'Jodocus Sebastian van den Abeele': 3, 'Remy van den Abeele': 7, 'Jacques Abeille': 1, 'Jim Abeita': 8, 'Carl Abel': 2, 'Ernst Heinrich Abel': 2, 'Francois Barthelemy Marius Abel': 1, 'Gustav Abel': 1, 'Attributed to  Gustav Abel': 1, 'Jean Marie Abel': 3, 'Jim Allen Abel': 1, 'Joseph Abel': 4, 'Attributed to  Joseph Abel': 1, 'Louise Abel': 3, ...
#
# Dictionary with 3 highest values:
# Keys: Values
# Pablo Picasso  : 8975
# Andy Warhol  : 6976
# nan  : 2837
# Gustav Klimt  : 424

# %%
# Finding 10 highest values
high = k.most_common(10) 
 
print("Initial Dictionary:")
print(liss, "\n")
 
 
print("Dictionary with 3 highest values:")
print("Keys: Values")
 
for i in high:
    print(i[0]," :",i[1]," ")
# Out:
# Initial Dictionary:
# {'Mario A': 2, 'A E Cremer': 1, 'A G Schultz & Co.': 2, 'A H': 1, 'A H G': 1, 'A K': 1, 'A Kassen': 1, 'A Lao': 4, 'A M': 1, 'A Sun Wu': 4, "Maria A'Becket": 4, "A'erbai": 1, 'A-One': 2, 'A.CE': 1, 'A1one': 6, 'Dirk van der Aa': 6, 'Jorgen Aabye': 5, 'Christian Aabye-Talge': 1, 'Attributed to  Hans von Aachen': 2, 'Circle of  Hans von Aachen': 2, 'Studio of  Hans von Aachen': 1, 'After  Hans von Aachen': 1, 'Hans von Aachen': 1, 'Peder Pedersen Aadnes': 1, 'Arvid Aae': 2, 'Carl Frederic Aagaard': 4, 'Martin Aagaard': 2, 'H P Aaland': 1, 'Alvar Aalto': 11, 'Ilmari Aalto': 4, 'Veikko Aaltona': 5, 'Aarre Aaltonen': 2, 'Waino Aaltonen': 7, 'Martin Aalund': 3, 'Asbjorn Aamodt': 2, 'Susanne Aamund': 1, 'Jos Aanraad': 3, 'Leny Aardse': 1, 'Eero Aarnio': 7, 'Jessie Aaron': 9, 'John Aaron': 1, 'Joseph Aaron': 5, 'Michel Aaron': 1, 'George Aarons': 4, 'Slim Aarons': 2, 'Carl Aarsleff': 2, 'Hans Aarsman': 1, 'Nicolaas Aartmann': 4, 'Pieter Jan Aarts': 1, 'Alf Jorgen Aas': 1, 'Nils Aas': 3, 'Walther Aas': 2, 'Astri Aasen': 1, 'Lennart Aasling': 2, 'Ab the Flagman': 10, 'Vilmos Aba-Novak': 4, 'Attributed to  Vilmos Aba-Novak': 2, 'T Abacchi': 1, 'Pacita Abad': 7, 'Francisco Abad Doblas': 1, 'Jorge Abade': 1, 'Juan Martinez Abades': 3, 'Juan de la Abadia the Elder': 2, 'Jean Abadie': 6, 'Pierre Abadie-Landel': 4, 'Stanko Abadzic': 1, 'Magdalena Abakanowicz': 2, 'Tomas Abal': 1, 'Fernando Abalo': 1, 'Eduardo Abaroa': 2, 'Franz Abart': 2, 'Felipe Abarzuza y Rodriguez Arias': 1, 'Abascal': 5, 'Carlos Abascal': 2, 'Felipe Barantes Abascal': 1, 'Chingiz Abassov': 1, 'Alberto Abate': 6, 'Claudio Abate': 1, 'Gianantonio Abate': 3, 'Goffredo de Abate': 3, 'Serge Abate': 1, 'Teonesto de Abate': 5, 'Pierre Abattuci': 9, 'Nadim Abbas': 1, 'Norma Abbas': 1, "Sa'adi Abbas": 1, 'Salman Abbas': 1, 'After  Riza-i Abbasi': 1, 'School of  Riza-i Abbasi': 1, 'Follower of  Riza-i Abbasi': 1, 'Attributed to  Riza-i Abbasi': 2, 'Style of  Riza-i Abbasi': 1, 'School of  Shaykh Abbasi': 1, 'Shaykh Abbasi': 3, 'Attributed to  Shaykh Abbasi': 1, 'Samira Abbassy': 1, 'Adalberto Abbate': 1, "Niccolo dell' Abbate": 4, 'Alberto Abbati': 3, 'Attributed to  Giuseppe Abbati': 1, 'Giuseppe Abbati': 3, 'Attributed to  Vincenzo Abbati': 1, 'Vincenzo Abbati': 1, 'Agnes Dean Abbatt': 1, 'Albert Abbe': 4, 'Dennis Abbe': 1, 'Salomon van Abbe': 3, 'Jan van den Abbeele': 1, 'Roger vanden Abbeele': 2, 'Louise Abbema': 3, 'Robert Kennedy Abbett': 7, 'Alfred Abbey': 1, 'Edwin Austin Abbey': 5, 'Julius Abbiati': 3, 'Stefano Abbiati': 4, 'Jussuf Abbo': 5, 'Agnes Anne Abbot': 6, 'John Abbot': 1, 'Anne Abbott': 2, 'Arthur Abbott': 2, 'Berenice Abbott': 7, 'C Abbott': 1, 'Douglas Abbott': 2, 'Elenore Plaisted Abbott': 1, 'John T Abbott': 1, 'John White Abbott': 4, 'Lemuel Francis Abbott': 5, 'After  Lemuel Francis Abbott': 1, 'Mary Abbott': 5, 'Mary Odgen Abbott': 1, 'Meredith Brooks Abbott': 10, 'Attributed to  Samuel Nelson Abbott': 1, 'Susan Abbott': 4, 'William Abbott': 1, 'Yarnell Abbott': 3, 'Horace Abbott Hobson': 2, 'Chafik Abboud': 7, 'Jumana Emil Abboud': 1, 'Joe Abbrescia': 6, 'Abd Al-Jabar': 1, 'Hamed Abdallah': 2, 'Abdel-Kerim': 1, 'Mahmoud Abdel-Mawgood': 1, 'Youssef Abdelke': 4, 'Doug Abdell': 5, 'Adel Abdessemed': 9, 'Prince  Abdul-Medijd': 2, 'Naguib Elias Abdula': 1, 'Ian Abdulla': 5, 'Abdullah': 1, 'Nizam Abdullah': 1, 'Raden Basoeki Abdullah': 10, 'Ramlan Abdullah': 2, 'S Abdullah': 1, 'Sudjono Abdullah': 8, 'Suriosubroto Abdullah': 4, 'Abdullah Freres': 1, 'Aman Abdurachman': 1, 'Rowena Meeks Abdy': 5, 'Mizuki Abe': 1, 'Satoru Abe': 6, 'Pinson Abeauvain': 1, 'Raphael Abecassis': 2, 'Zainul Abedin': 9, 'Albijn van den Abeele': 2, 'Jodocus Sebastian van den Abeele': 3, 'Remy van den Abeele': 7, 'Jacques Abeille': 1, 'Jim Abeita': 8, 'Carl Abel': 2, 'Ernst Heinrich Abel': 2, 'Francois Barthelemy Marius Abel': 1, 'Gustav Abel': 1, 'Attributed to  Gustav Abel': 1, 'Jean Marie Abel': 3, 'Jim Allen Abel': 1, 'Joseph Abel': 4, 'Attributed to  Joseph Abel': 1, 'Louise Abel': 3, ...
#
# Dictionary with 3 highest values:
# Keys: Values
# Pablo Picasso  : 8975
# Andy Warhol  : 6976
# nan  : 2837
# Gustav Klimt  : 424
# Paul Cezanne  : 384
# Willem de Kooning  : 381
# Edvard Munch  : 371
# After  Pablo Picasso  : 339
# Vincent van Gogh  : 133
# Mark Rothko  : 133

# %%
# Finding 20 highest values
high = k.most_common(20) 
 
print("Initial Dictionary:")
print(liss, "\n")
 
 
print("Dictionary with 3 highest values:")
print("Keys: Values")
 
for i in high:
    print(i[0]," :",i[1]," ")
# Out:
# Initial Dictionary:
# {'Mario A': 2, 'A E Cremer': 1, 'A G Schultz & Co.': 2, 'A H': 1, 'A H G': 1, 'A K': 1, 'A Kassen': 1, 'A Lao': 4, 'A M': 1, 'A Sun Wu': 4, "Maria A'Becket": 4, "A'erbai": 1, 'A-One': 2, 'A.CE': 1, 'A1one': 6, 'Dirk van der Aa': 6, 'Jorgen Aabye': 5, 'Christian Aabye-Talge': 1, 'Attributed to  Hans von Aachen': 2, 'Circle of  Hans von Aachen': 2, 'Studio of  Hans von Aachen': 1, 'After  Hans von Aachen': 1, 'Hans von Aachen': 1, 'Peder Pedersen Aadnes': 1, 'Arvid Aae': 2, 'Carl Frederic Aagaard': 4, 'Martin Aagaard': 2, 'H P Aaland': 1, 'Alvar Aalto': 11, 'Ilmari Aalto': 4, 'Veikko Aaltona': 5, 'Aarre Aaltonen': 2, 'Waino Aaltonen': 7, 'Martin Aalund': 3, 'Asbjorn Aamodt': 2, 'Susanne Aamund': 1, 'Jos Aanraad': 3, 'Leny Aardse': 1, 'Eero Aarnio': 7, 'Jessie Aaron': 9, 'John Aaron': 1, 'Joseph Aaron': 5, 'Michel Aaron': 1, 'George Aarons': 4, 'Slim Aarons': 2, 'Carl Aarsleff': 2, 'Hans Aarsman': 1, 'Nicolaas Aartmann': 4, 'Pieter Jan Aarts': 1, 'Alf Jorgen Aas': 1, 'Nils Aas': 3, 'Walther Aas': 2, 'Astri Aasen': 1, 'Lennart Aasling': 2, 'Ab the Flagman': 10, 'Vilmos Aba-Novak': 4, 'Attributed to  Vilmos Aba-Novak': 2, 'T Abacchi': 1, 'Pacita Abad': 7, 'Francisco Abad Doblas': 1, 'Jorge Abade': 1, 'Juan Martinez Abades': 3, 'Juan de la Abadia the Elder': 2, 'Jean Abadie': 6, 'Pierre Abadie-Landel': 4, 'Stanko Abadzic': 1, 'Magdalena Abakanowicz': 2, 'Tomas Abal': 1, 'Fernando Abalo': 1, 'Eduardo Abaroa': 2, 'Franz Abart': 2, 'Felipe Abarzuza y Rodriguez Arias': 1, 'Abascal': 5, 'Carlos Abascal': 2, 'Felipe Barantes Abascal': 1, 'Chingiz Abassov': 1, 'Alberto Abate': 6, 'Claudio Abate': 1, 'Gianantonio Abate': 3, 'Goffredo de Abate': 3, 'Serge Abate': 1, 'Teonesto de Abate': 5, 'Pierre Abattuci': 9, 'Nadim Abbas': 1, 'Norma Abbas': 1, "Sa'adi Abbas": 1, 'Salman Abbas': 1, 'After  Riza-i Abbasi': 1, 'School of  Riza-i Abbasi': 1, 'Follower of  Riza-i Abbasi': 1, 'Attributed to  Riza-i Abbasi': 2, 'Style of  Riza-i Abbasi': 1, 'School of  Shaykh Abbasi': 1, 'Shaykh Abbasi': 3, 'Attributed to  Shaykh Abbasi': 1, 'Samira Abbassy': 1, 'Adalberto Abbate': 1, "Niccolo dell' Abbate": 4, 'Alberto Abbati': 3, 'Attributed to  Giuseppe Abbati': 1, 'Giuseppe Abbati': 3, 'Attributed to  Vincenzo Abbati': 1, 'Vincenzo Abbati': 1, 'Agnes Dean Abbatt': 1, 'Albert Abbe': 4, 'Dennis Abbe': 1, 'Salomon van Abbe': 3, 'Jan van den Abbeele': 1, 'Roger vanden Abbeele': 2, 'Louise Abbema': 3, 'Robert Kennedy Abbett': 7, 'Alfred Abbey': 1, 'Edwin Austin Abbey': 5, 'Julius Abbiati': 3, 'Stefano Abbiati': 4, 'Jussuf Abbo': 5, 'Agnes Anne Abbot': 6, 'John Abbot': 1, 'Anne Abbott': 2, 'Arthur Abbott': 2, 'Berenice Abbott': 7, 'C Abbott': 1, 'Douglas Abbott': 2, 'Elenore Plaisted Abbott': 1, 'John T Abbott': 1, 'John White Abbott': 4, 'Lemuel Francis Abbott': 5, 'After  Lemuel Francis Abbott': 1, 'Mary Abbott': 5, 'Mary Odgen Abbott': 1, 'Meredith Brooks Abbott': 10, 'Attributed to  Samuel Nelson Abbott': 1, 'Susan Abbott': 4, 'William Abbott': 1, 'Yarnell Abbott': 3, 'Horace Abbott Hobson': 2, 'Chafik Abboud': 7, 'Jumana Emil Abboud': 1, 'Joe Abbrescia': 6, 'Abd Al-Jabar': 1, 'Hamed Abdallah': 2, 'Abdel-Kerim': 1, 'Mahmoud Abdel-Mawgood': 1, 'Youssef Abdelke': 4, 'Doug Abdell': 5, 'Adel Abdessemed': 9, 'Prince  Abdul-Medijd': 2, 'Naguib Elias Abdula': 1, 'Ian Abdulla': 5, 'Abdullah': 1, 'Nizam Abdullah': 1, 'Raden Basoeki Abdullah': 10, 'Ramlan Abdullah': 2, 'S Abdullah': 1, 'Sudjono Abdullah': 8, 'Suriosubroto Abdullah': 4, 'Abdullah Freres': 1, 'Aman Abdurachman': 1, 'Rowena Meeks Abdy': 5, 'Mizuki Abe': 1, 'Satoru Abe': 6, 'Pinson Abeauvain': 1, 'Raphael Abecassis': 2, 'Zainul Abedin': 9, 'Albijn van den Abeele': 2, 'Jodocus Sebastian van den Abeele': 3, 'Remy van den Abeele': 7, 'Jacques Abeille': 1, 'Jim Abeita': 8, 'Carl Abel': 2, 'Ernst Heinrich Abel': 2, 'Francois Barthelemy Marius Abel': 1, 'Gustav Abel': 1, 'Attributed to  Gustav Abel': 1, 'Jean Marie Abel': 3, 'Jim Allen Abel': 1, 'Joseph Abel': 4, 'Attributed to  Joseph Abel': 1, 'Louise Abel': 3, ...
#
# Dictionary with 3 highest values:
# Keys: Values
# Pablo Picasso  : 8975
# Andy Warhol  : 6976
# nan  : 2837
# Gustav Klimt  : 424
# Paul Cezanne  : 384
# Willem de Kooning  : 381
# Edvard Munch  : 371
# After  Pablo Picasso  : 339
# Vincent van Gogh  : 133
# Mark Rothko  : 133
# After  Andy Warhol  : 20
# Charles Eames  : 17
# Rose Cabat  : 14
# Jean-Michel Basquiat  : 12
# Alvar Aalto  : 11
# Garland Adkins  : 11
# Bai Jiao  : 11
# Ab the Flagman  : 10
# Meredith Brooks Abbott  : 10
# Raden Basoeki Abdullah  : 10

# %%
# count the total number of artists in the dataset
total_artists = len(x)

print("total number of artists",total_artists)

# Extract keys with value 1
keys_with_value_1 = [key for key, value in k.items() if value == 1]

# Count of keys with value 1
count_keys_with_value_1 = len(keys_with_value_1)

print("Keys with value 1:", keys_with_value_1)
print("Number of keys with value 1:", count_keys_with_value_1)


# Extract keys with value between 1 and 5
keys_with_value_minor_5 = [key for key, value in k.items() if 1 < value <= 5]


# Count of keys with value 5
count_keys_with_value_minor_5 = len(keys_with_value_minor_5)

print("Keys with value minor than 5:", keys_with_value_minor_5)
print("Number of keys with value minor than 5 :", count_keys_with_value_minor_5)


# extract keys with value between 5 and 10
keys_with_value_minor_10= [key for key, value in k.items() if 5 < value <= 10]


# Count of keys with value minor than 10
count_keys_with_value_minor_10 = len(keys_with_value_minor_10)

print("Keys with value minor than 10:", keys_with_value_minor_10)
print("Number of keys with value minor than 10:", count_keys_with_value_minor_10)


# extract keys with value greater than 10
keys_with_value_minor_10= [key for key, value in k.items() if value > 10]


# Count of keys with value greater than 10
count_keys_with_value_minor_10 = len(keys_with_value_minor_10)

print("Keys with value greater than 10:", keys_with_value_minor_10)
print("Number of keys with value greater than 10:", count_keys_with_value_minor_10)
# Out:
# total number of artists 8619
# Keys with value 1: ['A E Cremer', 'A H', 'A H G', 'A K', 'A Kassen', 'A M', "A'erbai", 'A.CE', 'Christian Aabye-Talge', 'Studio of  Hans von Aachen', 'After  Hans von Aachen', 'Hans von Aachen', 'Peder Pedersen Aadnes', 'H P Aaland', 'Susanne Aamund', 'Leny Aardse', 'John Aaron', 'Michel Aaron', 'Hans Aarsman', 'Pieter Jan Aarts', 'Alf Jorgen Aas', 'Astri Aasen', 'T Abacchi', 'Francisco Abad Doblas', 'Jorge Abade', 'Stanko Abadzic', 'Tomas Abal', 'Fernando Abalo', 'Felipe Abarzuza y Rodriguez Arias', 'Felipe Barantes Abascal', 'Chingiz Abassov', 'Claudio Abate', 'Serge Abate', 'Nadim Abbas', 'Norma Abbas', "Sa'adi Abbas", 'Salman Abbas', 'After  Riza-i Abbasi', 'School of  Riza-i Abbasi', 'Follower of  Riza-i Abbasi', 'Style of  Riza-i Abbasi', 'School of  Shaykh Abbasi', 'Attributed to  Shaykh Abbasi', 'Samira Abbassy', 'Adalberto Abbate', 'Attributed to  Giuseppe Abbati', 'Attributed to  Vincenzo Abbati', 'Vincenzo Abbati', 'Agnes Dean Abbatt', 'Dennis Abbe', 'Jan van den Abbeele', 'Alfred Abbey', 'John Abbot', 'C Abbott', 'Elenore Plaisted Abbott', 'John T Abbott', 'After  Lemuel Francis Abbott', 'Mary Odgen Abbott', 'Attributed to  Samuel Nelson Abbott', 'William Abbott', 'Jumana Emil Abboud', 'Abd Al-Jabar', 'Abdel-Kerim', 'Mahmoud Abdel-Mawgood', 'Naguib Elias Abdula', 'Abdullah', 'Nizam Abdullah', 'S Abdullah', 'Abdullah Freres', 'Aman Abdurachman', 'Mizuki Abe', 'Pinson Abeauvain', 'Jacques Abeille', 'Francois Barthelemy Marius Abel', 'Gustav Abel', 'Attributed to  Gustav Abel', 'Jim Allen Abel', 'Attributed to  Joseph Abel', 'N Abel-Bolineau', 'Attributed to  Angelo Abelardi', 'Johan Abeling', 'Juan Antonio Abellan Julia', 'Martino Abellana', 'Antonio Abelleyra Cabral', 'Abello', 'Corega Abello', 'T Abeloos', 'Attributed to  Jacobus Theodorus Abels', 'Margitta Abels', 'Attributed to  Johann Ludwig Aberli', 'Attributed to  Johann Peter Abesch', 'Adel Abidin', 'Laudi Abilama', 'Mark Abildgaard', 'Abir', 'Lucienne Abit', 'Thomas Robert Ablett', 'Richard Ablott', 'Hephzibah Abney', 'Attributed to  Antonio Abondio', 'Circle of  Antonio Abondio', 'R Abou-Chanab', 'Sami Aboul Azm', 'Ola Aboumausson', 'Arwa Abouon', 'Raoul About', 'Donald Abraham', 'Friedrich Abraham', 'Raimund Abraham', 'Robert Abraham', 'Tancrede Abraham', 'Elie Abrahami', 'Louis Abrahams', 'Rosemary Abrahams', 'Paul Abram Jr.', 'Merab Abramishvili', 'Attributed to  Leon Abramovicz', 'Simon Claude Abramovitsch', 'Albert Abramovitz', 'Bronislaw van Abramowicz', 'Lionel Abrams', 'Per Abramsen', 'Ido Abramsohn', 'Attributed to  Michel Jacob Abramson', 'Ramon Abrantes', 'Victor Abreu', 'Hessam Abrishami', 'Petre Abrudan', 'Absalon', 'Louis Absolon', 'Napoleon Abueva', 'Sultan Acar', 'Bernardus Accama', 'Attributed to  Eugene Accard', 'Jean Pierre Accault', 'Paul Acciari', 'Hans Accola', 'William Accorsi', 'Arturo Acebal y Digoras', 'Hector Acebes', 'Acee Blue Eagle', 'E S Aceto', 'Jose Acevedo', 'Fernando Aceves Humana', 'Xerxes Ach', 'Juan Antonio de Acha', 'Victoria Achache', 'Attributed to  Jean Alexis Achard', 'Jean Georges Pierre Achard', 'Achenbach', 'Gabrielle Achenbach', 'Attributed to  Oswald Achenbach', 'Ernest Acher', 'Oenone Acheson', 'August Achilles', 'Attributed to  Ferdinand Achilles', 'Attributed to  Ahlan Achoy', 'Sujata Achrekar', 'Joseph Achten', 'Herbert Achternbusch', 'Lucas Achtschellinck', 'Attributed to  Johan Axel Gustaf Acke', 'van Ackere', 'Gerald Ackerer', 'Crispin Ackerman', 'Etta Ackerman', 'Ackermann', 'Attributed to  Johann Adam Ackermann', 'Rudolf Werner Ackermann', 'Wilhelm Ackermann', 'E Ackert', 'Carl Axel Acking', 'Leonard Ackley', 'ACKMe', 'Henry Wentworth Dyke Acland', 'Rosa Acle', 'Acoma Pueblo', 'Alvaro Acores', 'Adolfo Agnila Acosta', 'Aguila Acosta', 'David Acosta', 'Eduardo Acosta', 'Scoli Acosta', 'Jacobo Acosta Lozano', 'Miguel Acquaroni', 'Acre', 'John F Acret', 'Gianpiero Actis', 'Ken Acton', 'Zoe Actypi', 'Johnny Aculiak', 'Luis Alberto Acuna', 'Isami Adachi', 'Jiwan Adalja', 'Albert Adam', 'Andre Adam', 'Attrib ...
# Number of keys with value 1: 4044
# Keys with value minor than 5: ['Mario A', 'A G Schultz & Co.', 'A Lao', 'A Sun Wu', "Maria A'Becket", 'A-One', 'Jorgen Aabye', 'Attributed to  Hans von Aachen', 'Circle of  Hans von Aachen', 'Arvid Aae', 'Carl Frederic Aagaard', 'Martin Aagaard', 'Ilmari Aalto', 'Veikko Aaltona', 'Aarre Aaltonen', 'Martin Aalund', 'Asbjorn Aamodt', 'Jos Aanraad', 'Joseph Aaron', 'George Aarons', 'Slim Aarons', 'Carl Aarsleff', 'Nicolaas Aartmann', 'Nils Aas', 'Walther Aas', 'Lennart Aasling', 'Vilmos Aba-Novak', 'Attributed to  Vilmos Aba-Novak', 'Juan Martinez Abades', 'Juan de la Abadia the Elder', 'Pierre Abadie-Landel', 'Magdalena Abakanowicz', 'Eduardo Abaroa', 'Franz Abart', 'Abascal', 'Carlos Abascal', 'Gianantonio Abate', 'Goffredo de Abate', 'Teonesto de Abate', 'Attributed to  Riza-i Abbasi', 'Shaykh Abbasi', "Niccolo dell' Abbate", 'Alberto Abbati', 'Giuseppe Abbati', 'Albert Abbe', 'Salomon van Abbe', 'Roger vanden Abbeele', 'Louise Abbema', 'Edwin Austin Abbey', 'Julius Abbiati', 'Stefano Abbiati', 'Jussuf Abbo', 'Anne Abbott', 'Arthur Abbott', 'Douglas Abbott', 'John White Abbott', 'Lemuel Francis Abbott', 'Mary Abbott', 'Susan Abbott', 'Yarnell Abbott', 'Horace Abbott Hobson', 'Hamed Abdallah', 'Youssef Abdelke', 'Doug Abdell', 'Prince  Abdul-Medijd', 'Ian Abdulla', 'Ramlan Abdullah', 'Suriosubroto Abdullah', 'Rowena Meeks Abdy', 'Raphael Abecassis', 'Albijn van den Abeele', 'Jodocus Sebastian van den Abeele', 'Carl Abel', 'Ernst Heinrich Abel', 'Jean Marie Abel', 'Joseph Abel', 'Louise Abel', 'Louis Abel-Truchet', 'Eduardo Abela', 'Gesner Abelard', 'Angelo Abelardi', 'Alfonso Abelenda Escudero', 'Kim Abeles', 'Michele Abeles', 'Sam Abell', 'Joan Abello Prat', 'Sonia Abeloos', 'Victor Abeloos', 'Jacobus Theodorus Abels', 'Evelyn Abelson', 'Harry Abend', 'John Brown Abercrombie', 'Thomas J Abercrombie', 'Robert Abercromby', 'Alfred Aberdam', 'Robert Aberdein', 'Emil Aberg', 'Gunnar Aberg', 'Martin Aberg', 'Pelle Aberg', 'Ulrike Victoria Aberg', 'Laurence Aberhart', 'Johann Ludwig Aberli', 'Abetz and Drescher', 'Narciso Abeyta', 'Tony Abeyta', 'Nik Zainal Abidin Nik Salleh', 'Mohamed Abla', 'Raymond Abner', 'Erno Abonyi', 'Aboriginal School', 'Aziz Abou Ali', 'Above', 'Artashes Abraamyan', 'Francoise Abraham', 'Ivor Abrahams', 'Emil Abrahamsen', 'Bengt O Abrahamson', 'Ola Abrahamson', 'Leo Abramowicz', 'Lucien Abrams', 'Anoush Abrar', 'Angelo Abrate', 'Christel Abresch', 'Anton Abreu Bastos', 'Ben Abril', 'Salvador Abril y Blasco', 'Leon Eugene Abry', 'Jack Absalom', 'John Absolon', 'Farid Abu Shakra', 'Karim Abu Shakra', 'Aloys Abyberg', 'Charles Louis Acar', 'Kuzgun Acar', 'Nicolo Accame', 'Vincenzo Accame', 'Enrico Accatino', 'Cesare Accetta', 'Guido Acchiardi', 'Giovanni Acci', 'Vito Acconci', 'Ezechiele Acerbi', 'Miguel Acevedo', 'Gustavo Aceves', 'Jose Aceves', 'Tomas Aceves', 'Jean Alexis Achard', 'William Acheff', 'Oscar Achenbach', 'Oswald Achenbach', 'Alice Stanley Acheson', 'Shoshany Achiam', 'Georges Achille-Fould', 'Christos Achilleos', 'Josef Achmann', 'Rene-Charles Acht', 'August Achtenhagen', 'Gerard van Achterberg', 'Milton Achtimichuk', 'Johan Axel Gustaf Acke', 'Marcelle Ackein', 'Florimond van Acker', 'Johannes Baptista van Acker', 'Troy Acker', 'A Ackerberg', 'Ilse Ackerman', 'Paul Ackerman', 'Johann Adam Ackermann', 'Max Ackermann', 'Otto Ackermann', 'Peter Ackermann', 'Rita Ackermann', 'Thomas Ackermann', 'Otto Ackermann-Pasegg', 'Norman Ackroyd', 'Gustavo Acosta', 'Manuel Gregorio Acosta', 'Agostos Acs', 'Ferenc Acs', 'Joe Acs', 'Antonio Acuc', 'Joe Adlaka Aculiak', 'Adam Adach', 'Benno Adam', 'E Adam', 'Edouard Adam', 'Attributed to  Edouard Adam', 'Edouard Victor Charles Adam', 'Emil Adam', 'Eugen Adam', 'Franz Adam', 'Attributed to  Heinrich Adam', 'Heinrich Adam', 'Hippolyte Adam', 'Attributed to  Jacob Sigisbert Adam', 'Josef Adam', 'Joseph Adam', 'Joseph Denovan Adam', 'Victor Adam', 'William Patrick Adam', 'Suzanne Adam-Laurens', 'Antoine Samuel Adam-Salomon', 'Franco Adami', 'Massimiliano Adami', 'H ...
# Number of keys with value minor than 5 : 3363
# Keys with value minor than 10: ['A1one', 'Dirk van der Aa', 'Waino Aaltonen', 'Eero Aarnio', 'Jessie Aaron', 'Ab the Flagman', 'Pacita Abad', 'Jean Abadie', 'Alberto Abate', 'Pierre Abattuci', 'Robert Kennedy Abbett', 'Agnes Anne Abbot', 'Berenice Abbott', 'Meredith Brooks Abbott', 'Chafik Abboud', 'Joe Abbrescia', 'Adel Abdessemed', 'Raden Basoeki Abdullah', 'Sudjono Abdullah', 'Satoru Abe', 'Zainul Abedin', 'Remy van den Abeele', 'Jim Abeita', 'Manuel Abelenda', 'Gertrude Abercrombie', 'Nicolai Abraham Abildgaard', 'William Albert Ablett', 'Mohamed Abouelouakar', 'Clet Abraham', 'Anette Abrahamsson', 'Erik Abrahamsson', 'Israel Abramofsky', 'Marina Abramovic', 'Pinchas Abramovich', 'Leon Abramovicz', 'Larry Abramson', 'Kurt Absolon', 'Otto Abt', 'Zsolnay Porcelain Manufacture', 'Tomma Abts', 'Asim Abu Shakra', 'Francisco Abuja', 'Rodolfo Abularach', 'Marguerite Acarin', 'Eugene Accard', 'Carla Accardi', 'Dhruvi Acharya', 'Georg Achen', 'Andreas Achenbach', 'Angelo Achini', 'Michel Victor Acier', 'Evelyn Ackerman', 'Franz Ackermann', 'Gerald Ackermann', 'Roger Ackling', 'Alfred Ackrill', 'Angel Acosta Leon', 'William Acton', 'Albrecht Adam', 'Julius Adam I', 'Patrick William Adam', 'Robert Adam', 'Sabhan Adam', 'Wilbur Adam', 'William Adam', 'Valerio Adami', 'Ansel Adams', 'Charles Partridge Adams', 'John Clayton Adams', 'Kenneth Miller Adams', 'Norman Adams', 'Peter Adams', 'Robert Adams', 'Wayman Adams', 'Harry Curieux Adamson', 'Robert Adamson', 'Bo Ake Adamsson', 'Louis Emile Adan', 'Natale Addamiano', 'Charles Addams', 'Adek', 'Luigi Ademollo', 'Sergei Adeyev', 'David Adickes', 'Georges Adilon', 'K M Adimoolam', 'Michel Adlen', 'Allan Adler', 'Louis Henry Sullivan', 'Edmund Adler', 'Jules Adler', 'Rose Adler', 'Samuel Marcus Adler', 'Karl Adloff', 'Francoise Adnet', 'Jacques Adnet', 'Gerard Pieter Adolfs', 'Leon Adriaans', 'Ferdinand Adriaenssens', 'Gosta Adrian-Nilsson', 'Lucien Adrion', 'Mary Adshead', 'Fritz Aduatz', 'Gunnvor Advocaat', 'Eva Aeppli', 'Franz Theodor Aerni', 'Marguerite Aers', 'Affandi', 'William Affleck', 'Aldo Affortunati', 'Nasrollah Afjehei', 'Nicholas Africano', 'Afro', 'Yaacov Agam', 'Agapetus', 'Eileen Agar', 'Ermenegildo Agazzi', 'Ernst C L Agerbeek', 'Ayman Baalbaki', 'Hugo Baar', 'Maarten Baas', 'Auguste Babberger', 'Alice Baber', 'Ivan Babij', 'Olivier Babin', 'Patrice Bac', 'Don Bacardy', 'Francois-Xavier Lalanne', 'Antonio Baccarin', 'Baccio Maria Bacci', 'Edmondo Bacci', 'Guido Bach', 'Pierre Bach', 'Auguste Bachelin', 'Lidia Bachis', 'Alfred Bachmann', 'Hermann Bachmann', 'Karl Bachmann', 'Otto Bachmann', 'Robert Back', 'John Philamon Backhouse', 'Elsa Backlund-Celsing', 'Hugo Backmansson', 'Albert Backus', 'Standish Backus Jr.', "Baron Louis Bacler d'Albe", 'Francis Bacon', 'Henry Bacon', 'Irving Lewis Bacon', 'John Henry Frederick Bacon', 'Daniel Joseph Bacque', 'Bada Shanren', 'Jean-Gilles Badaire', 'Douglas Badcock', 'Samuel Finley Morse Badger', 'Herbert Edward Badham', 'Carla Badiali', 'Libero Badii', 'Stanley Roy Badmin', 'Frank Badur', 'Ben Badura', 'Bien-U Bae', 'Donald Baechler', 'John Baeder', 'George Baer', 'Jo Baer', 'Martin Baer', 'Morley Baer', 'Emilius Baerentzen', 'Olle Baertling', 'Emile Baes', 'Firmin Baes', 'Lionel Baes', 'Rachel Baes', 'William Spencer Bagdatopoulos', 'Moses Bagel', 'Cavaliere Giovanni Baglione', 'Joseph Richard Bagshawe', 'Bai Ming', 'Bai Xueshi', 'Jean Baier', 'Ramkinkar Baij', 'Albert E Bailey', 'Beezy Bailey', 'Caroline Bailey', 'David Bailey', 'Frederick Victor Bailey', 'Henrietta Davidson Bailey', 'Herman Bailey', 'Radcliffe Bailey', 'Walter Alexander Bailey', 'William Bailey', 'William James Laidlaw Baillie', 'Edward Hodges Baily', 'Marcel Adolphe Bain', 'Thomas Baines', 'Nathaniel Hughes Baird', 'William Baptiste Baird', 'Bruce Bairnsfather', 'Hermann Baisch', 'Zoma Baitler', 'Eugenie Baizerman', 'Enrico Baj', 'Sujata Bajaj', 'Bronilaw Bak', 'Reinier Sybrand Bakels', 'Alan Douglas Baker', 'Elisha Taylor Baker', 'George Herbert Baker', 'Kristin ...
# Number of keys with value minor than 10: 1195
# Keys with value greater than 10: ['Alvar Aalto', nan, 'Garland Adkins', 'Bai Jiao', 'Rose Cabat', 'Charles Eames', 'Pablo Picasso', 'After  Pablo Picasso', 'Andy Warhol', 'After  Andy Warhol', 'Jean-Michel Basquiat', 'Paul Cezanne', 'Willem de Kooning', 'Gustav Klimt', 'Vincent van Gogh', 'Edvard Munch', 'Mark Rothko']
# Number of keys with value greater than 10: 17

# %%
import matplotlib.pyplot as plt
from collections import Counter


# Create labels for the slices
labels = ['Artists with 1 count', 'Artists with >1 and <5 counts', 'Artists with >5 <10 counts', 'Artists with >10 counts']

# Count for each group
sizes = [count_keys_with_value_1, count_keys_with_value_minor_5, count_keys_with_value_minor_10, count_keys_with_value_minor_10]

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Artists by Count')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter

# Data
labels = ['Artists with 1 count', 'Artists with >1 and <5 counts', 'Artists with >5 <10 counts', 'Artists with >10 counts']
sizes = [count_keys_with_value_1, count_keys_with_value_minor_5, count_keys_with_value_minor_10, count_keys_with_value_minor_10]

# Plotting
plt.figure(figsize=(8, 6))
sns.barplot(x=labels, y=sizes)
plt.title('Distribution of Artists by Count')
plt.xlabel('Count Range')
plt.ylabel('Number of Artists')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 7
#       5 # Data
#       6 labels = ['Artists with 1 count', 'Artists with >1 and <5 counts', 'Artists with >5 <10 counts', 'Artists with >10 counts']
# ----> 7 sizes = [count_keys_with_value_1, count_keys_with_value_minor_5, count_keys_with_value_minor_10, count_keys_with_value_minor_10]
#       9 # Plotting
#      10 plt.figure(figsize=(8, 6))
#
# NameError: name 'count_keys_with_value_1' is not defined

# %%
import matplotlib.pyplot as plt

# Sort keys and values together in descending order based on values
sorted_items = sorted(more_than_10_dict.items(), key=lambda item: item[1], reverse=True)
sorted_keys = [key for key, value in sorted_items]
sorted_values = [value for key, value in sorted_items]

# Creating the bar chart
plt.figure(figsize=(7, 4))
plt.bar(sorted_keys, sorted_values, color='skyblue')
plt.xlabel('Names')
plt.ylabel('Values')
plt.title('Bar Chart of Values (Sorted)')
plt.xticks(rotation=45, fontsize=8)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
import matplotlib.pyplot as plt

# Sort keys and values together in descending order based on values
sorted_items = sorted(more_than_10_dict.items(), key=lambda item: item[1], reverse=True)
sorted_keys = [key for key, value in sorted_items][2:]
sorted_values = [value for key, value in sorted_items][2:]

# Creating the bar chart
plt.figure(figsize=(7, 4))
plt.bar(sorted_keys, sorted_values, color='skyblue')
plt.xlabel('Names')
plt.ylabel('Values')
plt.title('Bar Chart of Values (Sorted)')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %% [markdown]
# # De Kooning
# correggere dataset per ridurre di uno zero

# %%
liss = []
for column_name in getty2.columns:
    if column_name == "artist":
        for value in getty2[column_name]:
            if value == "Willem de Kooning":
                liss.append(value)
print(len(liss))
# Out:
# 381

# %% [markdown]
# Get only results related to sales on De Kooning works. Artworks that do not possess data about price or soldtime have been deleted from the dataset.
# The dataset does not possess any data related to sellers and buyers.
# In this example we notice that 307 works over a total of 381 possess data about price and time of the transaction.

# %%
import pandas as pd

new_dataframe = getty2[["artist", "name", "price", "soldtime"]].copy()
new_dataframe = new_dataframe[new_dataframe["artist"] == "Willem de Kooning"].copy()

new_dataframe.reset_index(drop=True, inplace=True)

for idx, row in new_dataframe.iterrows():
    if pd.isna(row["price"]) and pd.isna(row["soldtime"]):
        new_dataframe.drop(idx, inplace=True)
        
dayy = []
for i in new_dataframe['soldtime']:
    string_representation = str(i)
    split_parts = string_representation.split('-')
    day = split_parts[0]
    dayy.append(day)
new_dataframe['soldtime'] = dayy
        

new_dataframe.reset_index(drop=True, inplace=True)
new_dataframe.to_csv('auctions_data_DK.csv', index=False)
new_dataframe
# Out:
#                 artist                name        price soldtime
# 0    Willem de Kooning            Untitled   1370000.00     2014
# 1    Willem de Kooning            Untitled  20450000.00     2014
# 2    Willem de Kooning            Untitled   1125000.00     2014
# 3    Willem de Kooning      Untitled XVIII  48690000.00     2014
# 4    Willem de Kooning       Untitled XXIV 175250000.00     2014
# ..                 ...                 ...          ...      ...
# 302  Willem de Kooning             Woman V   3130000.00     2008
# 303  Willem de Kooning         Untitled IV 120810000.00     2008
# 304  Willem de Kooning           With love     44000.00     2008
# 305  Willem de Kooning  Untitled (Spoleto)   1210000.00     2008
# 306  Willem de Kooning            Untitled    400000.00     2008
#
# [307 rows x 4 columns]

# %%
#find out if there are duplicates. This table is with unique values.
# Assuming df is your DataFrame and 'column_name' is the name of the column you want to get distinct values from
filtered_df = new_dataframe.drop_duplicates(subset=['name'])

# This will give you an array of unique values from the specified column
filtered_df
# Out:
#                 artist                name        price soldtime
# 0    Willem de Kooning            Untitled   1370000.00     2014
# 3    Willem de Kooning      Untitled XVIII  48690000.00     2014
# 4    Willem de Kooning       Untitled XXIV 175250000.00     2014
# 5    Willem de Kooning        Untitled III 147250000.00     2014
# 6    Willem de Kooning       Two Figures I   8150000.00     2014
# ..                 ...                 ...          ...      ...
# 293  Willem de Kooning  Untitled (Figures)    237500.00     2008
# 302  Willem de Kooning             Woman V   3130000.00     2008
# 303  Willem de Kooning         Untitled IV 120810000.00     2008
# 304  Willem de Kooning           With love     44000.00     2008
# 305  Willem de Kooning  Untitled (Spoleto)   1210000.00     2008
#
# [150 rows x 4 columns]

# %% [markdown]
# # daniele

# %%
#move from date to integer
new_dataframe['soldtime'] = new_dataframe['soldtime'].astype(int)

# Divide all values in the 'price' column by 10
new_dataframe['price'] = new_dataframe['price'] / 10

# %%
values_counts = new_dataframe['name'].value_counts()
values_counts
# Out:
# Untitled                                                       90
# Woman                                                           6
# Love to Wakako                                                  6
# High School Desk                                                6
# Untitled (Woman)                                                5
#                                                                ..
# Torso Of a Man                                                  1
# Figures In Landscape VI                                         1
# Clam Digger (G. 10)                                             1
# Revenge (Graham 1); And Washington Monument (Not In Graham)     1
# Untitled (Spoleto)                                              1
# Name: name, Length: 150, dtype: int64

# %%
import matplotlib.pyplot as plt

# Assuming values_counts is your Series with the value counts

# Exclude the highest count value
values_counts_excluded = values_counts[values_counts != values_counts.max()]

# Calculate the frequency of each count value
count_frequency = values_counts_excluded.value_counts()

# Plot the scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(count_frequency.index, count_frequency.values, color='blue')
plt.title('Frequency of Count Values (Excluding Highest Value)')
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#alternativa a quello di sopra

# Assuming values_counts is your Series with the value counts

# Exclude the highest count value
values_counts_excluded = values_counts[values_counts != values_counts.max()]

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(values_counts_excluded, bins=10, color='blue')  # Adjust the number of bins as needed
plt.title('Frequency of Count Values (Excluding Highest Value)')
plt.xlabel('Count')
plt.ylabel('Frequency')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with the 'soldtime' column

# First, let's count the occurrences of each value in the 'soldtime' column
soldtime_counts = new_dataframe['soldtime'].value_counts().sort_index()

# Now, let's plot the counts as a line chart
plt.figure(figsize=(10, 6))  # Adjust the figure size if needed
soldtime_counts.plot(kind='line', marker='o')  # Use marker 'o' for better visibility of data points
plt.title('Number of Occurrences of each value in "soldtime" column')
plt.xlabel('soldtime')
plt.ylabel('Count')
plt.grid(True)  # Add gridlines for better visualization

# Add some space between the edges of the graph and the line
plt.xlim(soldtime_counts.index.min() - 1, soldtime_counts.index.max() + 1)

plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()

# %%
#media totale, media per anno 

pd.options.display.float_format = '{:.2f}'.format


mean_price = new_dataframe['price'].mean()

print('overall mean:', mean_price)


# Calculate the mean price for each value of 'soldtime'
mean_price_per_year = new_dataframe.groupby('soldtime')['price'].mean()


# Print the mean price for each year
print(mean_price_per_year)
# Out:
# overall mean: 1200612.38762215
# soldtime
# 2008    779880.60
# 2009    760305.76
# 2010    978857.88
# 2011    712840.71
# 2012   1084915.24
# 2013   1507841.98
# 2014   2118624.23
# Name: price, dtype: float64

# %%
pd.options.display.float_format = '{:.2f}'.format

# Plot the variation of mean price per year
plt.figure(figsize=(10, 6))
mean_price_per_year.plot(kind='line', marker='o', color='blue')
plt.title('Mean Price Variation per Year')
plt.xlabel('Year')
plt.ylabel('Mean Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Total income

# Aggregate the data to get the total selling price for each year
total_selling_per_year = new_dataframe.groupby('soldtime')['price'].sum()

# Plot the scatterplot
plt.figure(figsize=(10, 6))
plt.scatter(total_selling_per_year.index, total_selling_per_year.values, color='blue')
plt.title('Total Income per Year')
plt.xlabel('Year')
plt.ylabel('Total Selling Price')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# sold and best sellings

import matplotlib.pyplot as plt

# Find the maximum selling price for each year
max_price_per_year = new_dataframe.groupby('soldtime').apply(lambda x: x.loc[x['price'].idxmax()])

# Plot the scatterplot
plt.figure(figsize=(10, 6))
for year, price in new_dataframe.groupby('soldtime')['price']:
    plt.scatter([year] * len(price), price, color='blue', alpha=0.5)

# Add labels for maximum selling price for each year
for year, max_data in max_price_per_year.iterrows():
    plt.text(year, max_data['price'], max_data['name'], fontsize=8, ha='right', va='bottom')

plt.title('Selling Prices per Year')
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.grid(True)
plt.tight_layout()
plt.show()
